# %% [markdown]
# # Assignment 1: NARMA10 task
# ## TDNN
# Note: as a reference for keras tuner I used the documentation: https://www.tensorflow.org/tutorials/keras/keras_tuner

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
import keras_tuner as kt
from keras import backend as K
import pandas as pd
# Out:
# 2023-06-05 14:05:38.164693: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-05 14:05:38.219326: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-05 14:05:38.220365: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-05 14:05:39.392065: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ---

# %% [markdown]
# # [Load final Results]

# %%
#manually trained hyperparameters (number of epochs, window size)
best_epoch, best_window = np.load('hyperparameters_best_epoch_best_window.npy', allow_pickle=True)
print(f'Number of epochs: {best_epoch}\nBest window size: {best_window}')
#best model
final_model = keras.models.load_model('keras_model_tdnn')

#history variable
history = pd.read_json('history_tdnn.json')
#errors 
errors = np.load('errors_tdnn.npy')
print(f'\nTraining MSE = {errors[0]} \nValidation MSE = {errors[1]} \nTest MSE = {errors[2]}')
# Out:
# Number of epochs: 45
# Best window size: 17
#
# Training MSE = 4.236143468006048e-06
# Validation MSE = 4.605814410751918e-06
# Test MSE = 4.405124400364002e-06

# %% [markdown]
# ---

# %% [markdown]
# function to reshape the dataset to feed the tdnn

# %%
# Prepare the input X and target Y in order to implement the tdnn
def get_XY(x, y, window):
    # Remove the first "window" elements from y array
    Y = y[window:]
    # X will be an array containing "len(Y)" arrays created using the sliding window
    X = []
    rows_x = len(Y)
    j = 0
    for i in range(rows_x):
        X = np.append(X,x[j:j+window])
        j = j + 1

    #reshape X so it can be fed to the Dense layer
    X =  np.reshape(X, (rows_x, 1, window)) 
    return X, Y

# %% [markdown]
# function to plot the learning history

# %%
def history_plot(history,window):
    plt.figure(figsize = (15,5))

    plt.subplot(121)
    plt.plot(history['loss'])
    plt.title(f'Loss (window:{window})')
    plt.xlabel('Epochs')
    plt.ylabel('MSE')
    #plt.yscale('log')

    plt.subplot(122)
    plt.plot(history['val_loss'])
    plt.title(f'Validation Loss (window:{window})')
    plt.xlabel('Epochs')
    plt.ylabel('MSE')
    #plt.yscale('log')
    plt.tight_layout()

    plt.savefig(f"plots/tdnn_loss_{window}.pdf")
    plt.show()

# %% [markdown]
# ### Load the dataset

# %%
#load the data
data = np.loadtxt("MG17.csv", delimiter=",")

#organize input and target 
x = data[:-1]
y = data[1:]
print(data)
# Out:
# [ 0.032164  0.040426  0.057861 ... -0.19556  -0.1368   -0.082192]

# %%
#split the dataset into training, validation and test
x_train = x[:4000]
x_valid = x[4000:5000] #validation
x_test = x[5000:]

y_train = y[:4000]
y_valid = y[4000:5000]
y_test = y[5000:]

#plot the data
t=np.arange(start=0,stop=len(x), step=1)
plt.figure(figsize = (25,7))
ax1 = plt.subplot(211)
plt.title('Input', fontsize=18)
ax1.plot(t,x, color = 'b', linewidth= 0.5)
ax1.axvline(x = 4000, color = 'black', linestyle= '--')
ax1.axvline(x = 5000, color = 'black', linestyle= '--')

ax2 = plt.subplot(212, sharex = ax1)
plt.title('Target', fontsize=18)
ax2.plot(t,y, color = 'r', linewidth = 0.5)
ax2.axvline(x = 4000, color = 'black', linestyle= '--')
ax2.axvline(x = 5000, color = 'black', linestyle= '--')
plt.xlabel('Timesteps', fontsize=14)
plt.tight_layout()

# %% [markdown]
# batch size:

# %%
#batch size 
bs = 1

# %% [markdown]
# # MODEL SELECTION
# In order to do model selection, I proceed in part using keras tuner, and in part manually.
# In fact, with keras tuner it was not possible to set the window size as an hyperparameter, because changing thew window size means changing the dataset structure.
# To solve this problem, i created a for cycle to handle the model selection for the window size, and inside the cycle I use keras tuner to tune the other hyperparameters, i.e:
#
# - number of units of hidden layer [from 50 to 150 at steps of 10]
# - learning rate for the optimizer [1e-2, 1e-3, 1e-4]
# - activation function for the hidden layer ["linear","relu", "tanh"]
# - activation function for the output layer ["linear","relu"]

# %% [markdown]
# For the window size, we explores values: [10,17,20]

# %%
#size of the window we use to buffer the input
windows = [10,17,20] #window sizes to investigate

mse_min = 1e3 #initialize to a high value
for window_size in windows:
    print(f'\n WINDOW SIZE: {window_size} \n')

    #Prepare the dataset to feed the tdnn, accordingly to the selected window size:
    trainX, trainY = get_XY(x_train, y_train, window_size)
    validX, validY = get_XY(x_valid, y_valid, window_size)
    testX, testY = get_XY(x_test, y_test, window_size)

    #Create the model
    #To do model selection, we actually create the "hypermodel",
    #defining the hyperparameter search space as well as the architecture of the model.

    def model_architecture(hidden_units, activation_h, activation_d, lr):
        model = Sequential()
        input_shape = (1, window_size) 
        model.add(Dense(units=hidden_units,input_shape=input_shape, activation=activation_h))
        model.add(Dense(units=1, activation=activation_d))
        model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=lr),metrics=['mean_squared_error'])
        return model

    def create_model(hp):

        # Tune the number of units in the first Dense layer
        # Choose an optimal value between 50-150
        hidden_units = hp.Int('units',  min_value=50, max_value=150, step=10)

        #Tune the activation function of the hidden layer
        activation_h = hp.Choice("activation_h", ["linear","relu", "tanh"])
        #Tune the activation function of the last layer
        activation_d = hp.Choice("activation_d", ["linear","relu"])
        # Tune the learning rate for the optimizer
        lr = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])


        # call model-building code with the hyperparameter values.
        model = model_architecture(
            hidden_units=hidden_units, activation_d=activation_d, activation_h=activation_h, lr=lr
        )
        return model


    # Instantiate hyperparameter tuner
    # use random search to find optimal hyperparameters
    tuner = kt.RandomSearch(
                        hypermodel = create_model,
                        objective='val_mean_squared_error',
                        max_trials=20,
                        #overwrite=True,
                        directory='tuner',
                        project_name=f'tuner_tdnn_{window_size}'
                        )

    tuner.search_space_summary()


    #Create a callback to stop training early after reaching a certain value for the validation loss.
    stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)


    tuner.search(trainX, trainY, epochs=8, batch_size=bs, validation_data = (validX, validY), callbacks=[stop_early])
    # Get the optimal hyperparameters
    best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

    print(f"""
    Completed hyperparameters search for window size: {window_size}.\n
    Otimal number of units of hidden layer = {best_hps.get('units')} \n
    Optimal learning rate for the optimizer = {best_hps.get('learning_rate')} \n
    Optimal activation function for the hidden layer = {best_hps.get('activation_h')} \n
    Optimal activation function for the dense layer = {best_hps.get('activation_d')}
    """)
        
    #instantiate the model
    window_model = tuner.hypermodel.build(best_hps)
    window_model.summary()
    window_model.fit(trainX, trainY, epochs=10, batch_size=bs, verbose=2, validation_data = (validX, validY))
    mse = window_model.evaluate(validX, validY, batch_size=bs)[0]
    print(f'\n mse with window {window_size} is {mse} \n') 
    #window_model.save(f'keras_model_tdnn_{window_size}')
    if mse < mse_min:
        mse_min = mse
        best_window = window_size
        final_hps = best_hps
# Out:
#  WINDOW SIZE: 10
#
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_10/tuner0.json
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_10/tuner0.json
# Search space summary
# Default search space size: 4
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 50, 'max_value': 150, 'step': 10, 'sampling': 'linear'}
# activation_h (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu', 'tanh'], 'ordered': False}
# activation_d (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu'], 'ordered': False}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
#     Completed hyperparameters search for window size: 10.
#
#     Otimal number of units of hidden layer = 90
#
#     Optimal learning rate for the optimizer = 0.0001
#
#     Optimal activation function for the hidden layer = tanh
#
#     Optimal activation function for the dense layer = linear
#
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 1, 90)             990
#
#  dense_9 (Dense)             (None, 1, 1)              91
#
# =================================================================
# Total params: 1,081
# Trainable params: 1,081
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3990/3990 - 6s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - 6s/epoch - 1ms/step
# Epoch 2/10
# 3990/3990 - 5s - loss: 9.1474e-04 - mean_squared_error: 9.1474e-04 - val_loss: 6.4476e-04 - val_mean_squared_error: 6.4476e-04 - 5s/epoch - 1ms/step
# Epoch 3/10
# 3990/3990 - 5s - loss: 5.9092e-04 - mean_squared_error: 5.9092e-04 - val_loss: 4.3723e-04 - val_mean_squared_error: 4.3723e-04 - 5s/epoch - 1ms/step
# Epoch 4/10
# 3990/3990 - 5s - loss: 4.1044e-04 - mean_squared_error: 4.1044e-04 - val_loss: 3.3397e-04 - val_mean_squared_error: 3.3397e-04 - 5s/epoch - 1ms/step
# Epoch 5/10
# 3990/3990 - 5s - loss: 2.9489e-04 - mean_squared_error: 2.9489e-04 - val_loss: 3.0172e-04 - val_mean_squared_error: 3.0172e-04 - 5s/epoch - 1ms/step
# Epoch 6/10
# 3990/3990 - 5s - loss: 2.4522e-04 - mean_squared_error: 2.4522e-04 - val_loss: 1.9708e-04 - val_mean_squared_error: 1.9708e-04 - 5s/epoch - 1ms/step
# Epoch 7/10
# 3990/3990 - 5s - loss: 2.3090e-04 - mean_squared_error: 2.3090e-04 - val_loss: 2.3290e-04 - val_mean_squared_error: 2.3290e-04 - 5s/epoch - 1ms/step
# Epoch 8/10
# 3990/3990 - 5s - loss: 2.1829e-04 - mean_squared_error: 2.1829e-04 - val_loss: 2.1144e-04 - val_mean_squared_error: 2.1144e-04 - 5s/epoch - 1ms/step
# Epoch 9/10
# 3990/3990 - 5s - loss: 2.0952e-04 - mean_squared_error: 2.0952e-04 - val_loss: 1.7321e-04 - val_mean_squared_error: 1.7321e-04 - 5s/epoch - 1ms/step
# Epoch 10/10
# 3990/3990 - 6s - loss: 2.0747e-04 - mean_squared_error: 2.0747e-04 - val_loss: 1.6617e-04 - val_mean_squared_error: 1.6617e-04 - 6s/epoch - 2ms/step
# 990/990 [==============================] - 1s 1ms/step - loss: 1.6617e-04 - mean_squared_error: 1.6617e-04
#
#  mse with window 10 is 0.00016617265646345913
#
#
#  WINDOW SIZE: 17
#
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_17/tuner0.json
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_17/tuner0.json
# Search space summary
# Default search space size: 4
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 50, 'max_value': 150, 'step': 10, 'sampling': 'linear'}
# activation_h (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu', 'tanh'], 'ordered': False}
# activation_d (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu'], 'ordered': False}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
#     Completed hyperparameters search for window size: 17.
#
#     Otimal number of units of hidden layer = 130
#
#     Optimal learning rate for the optimizer = 0.0001
#
#     Optimal activation function for the hidden layer = relu
#
#     Optimal activation function for the dense layer = linear
#
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 1, 130)            2340
#
#  dense_11 (Dense)            (None, 1, 1)              131
#
# =================================================================
# Total params: 2,471
# Trainable params: 2,471
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3983/3983 - 6s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 1.8043e-04 - val_mean_squared_error: 1.8043e-04 - 6s/epoch - 1ms/step
# Epoch 2/10
# 3983/3983 - 6s - loss: 1.0359e-04 - mean_squared_error: 1.0359e-04 - val_loss: 1.3306e-04 - val_mean_squared_error: 1.3306e-04 - 6s/epoch - 1ms/step
# Epoch 3/10
# 3983/3983 - 5s - loss: 5.2781e-05 - mean_squared_error: 5.2781e-05 - val_loss: 4.1395e-05 - val_mean_squared_error: 4.1395e-05 - 5s/epoch - 1ms/step
# Epoch 4/10
# 3983/3983 - 6s - loss: 3.1386e-05 - mean_squared_error: 3.1386e-05 - val_loss: 3.3513e-05 - val_mean_squared_error: 3.3513e-05 - 6s/epoch - 2ms/step
# Epoch 5/10
# 3983/3983 - 5s - loss: 2.3102e-05 - mean_squared_error: 2.3102e-05 - val_loss: 2.6936e-05 - val_mean_squared_error: 2.6936e-05 - 5s/epoch - 1ms/step
# Epoch 6/10
# 3983/3983 - 4s - loss: 2.0236e-05 - mean_squared_error: 2.0236e-05 - val_loss: 2.2846e-05 - val_mean_squared_error: 2.2846e-05 - 4s/epoch - 1ms/step
# Epoch 7/10
# 3983/3983 - 6s - loss: 1.6325e-05 - mean_squared_error: 1.6325e-05 - val_loss: 5.8677e-05 - val_mean_squared_error: 5.8677e-05 - 6s/epoch - 2ms/step
# Epoch 8/10
# 3983/3983 - 6s - loss: 1.4945e-05 - mean_squared_error: 1.4945e-05 - val_loss: 2.1995e-05 - val_mean_squared_error: 2.1995e-05 - 6s/epoch - 2ms/step
# Epoch 9/10
# 3983/3983 - 6s - loss: 1.3925e-05 - mean_squared_error: 1.3925e-05 - val_loss: 9.9557e-06 - val_mean_squared_error: 9.9557e-06 - 6s/epoch - 2ms/step
# Epoch 10/10
# 3983/3983 - 4s - loss: 1.0976e-05 - mean_squared_error: 1.0976e-05 - val_loss: 5.3146e-06 - val_mean_squared_error: 5.3146e-06 - 4s/epoch - 1ms/step
# 983/983 [==============================] - 1s 802us/step - loss: 5.3146e-06 - mean_squared_error: 5.3146e-06
#
#  mse with window 17 is 5.314624559105141e-06
#
#
#  WINDOW SIZE: 20
#
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_20/tuner0.json
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_20/tuner0.json
# Search space summary
# Default search space size: 4
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 50, 'max_value': 150, 'step': 10, 'sampling': 'linear'}
# activation_h (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu', 'tanh'], 'ordered': False}
# activation_d (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu'], 'ordered': False}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
#     Completed hyperparameters search for window size: 20.
#
#     Otimal number of units of hidden layer = 80
#
#     Optimal learning rate for the optimizer = 0.001
#
#     Optimal activation function for the hidden layer = relu
#
#     Optimal activation function for the dense layer = linear
#
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 1, 80)             1680
#
#  dense_13 (Dense)            (None, 1, 1)              81
#
# =================================================================
# Total params: 1,761
# Trainable params: 1,761
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3980/3980 - 5s - loss: 6.8617e-04 - mean_squared_error: 6.8617e-04 - val_loss: 1.6543e-04 - val_mean_squared_error: 1.6543e-04 - 5s/epoch - 1ms/step
# Epoch 2/10
# 3980/3980 - 4s - loss: 2.0786e-04 - mean_squared_error: 2.0786e-04 - val_loss: 4.7352e-05 - val_mean_squared_error: 4.7352e-05 - 4s/epoch - 1ms/step
# Epoch 3/10
# 3980/3980 - 6s - loss: 9.8443e-05 - mean_squared_error: 9.8443e-05 - val_loss: 4.4940e-05 - val_mean_squared_error: 4.4940e-05 - 6s/epoch - 1ms/step
# Epoch 4/10
# 3980/3980 - 5s - loss: 8.1612e-05 - mean_squared_error: 8.1612e-05 - val_loss: 9.1958e-05 - val_mean_squared_error: 9.1958e-05 - 5s/epoch - 1ms/step
# Epoch 5/10
# 3980/3980 - 5s - loss: 7.9381e-05 - mean_squared_error: 7.9381e-05 - val_loss: 1.1949e-04 - val_mean_squared_error: 1.1949e-04 - 5s/epoch - 1ms/step
# Epoch 6/10
# 3980/3980 - 5s - loss: 8.2914e-05 - mean_squared_error: 8.2914e-05 - val_loss: 2.2462e-05 - val_mean_squared_error: 2.2462e-05 - 5s/epoch - 1ms/step
# Epoch 7/10
# 3980/3980 - 5s - loss: 4.8599e-05 - mean_squared_error: 4.8599e-05 - val_loss: 1.0821e-04 - val_mean_squared_error: 1.0821e-04 - 5s/epoch - 1ms/step
# Epoch 8/10
# 3980/3980 - 5s - loss: 5.3221e-05 - mean_squared_error: 5.3221e-05 - val_loss: 2.8110e-05 - val_mean_squared_error: 2.8110e-05 - 5s/epoch - 1ms/step
# Epoch 9/10
# 3980/3980 - 5s - loss: 4.2750e-05 - mean_squared_error: 4.2750e-05 - val_loss: 1.8063e-05 - val_mean_squared_error: 1.8063e-05 - 5s/epoch - 1ms/step
# Epoch 10/10
# 3980/3980 - 4s - loss: 4.2930e-05 - mean_squared_error: 4.2930e-05 - val_loss: 2.5166e-05 - val_mean_squared_error: 2.5166e-05 - 4s/epoch - 1ms/step
# 980/980 [==============================] - 1s 853us/step - loss: 2.5166e-05 - mean_squared_error: 2.5166e-05
#
#  mse with window 20 is 2.516558743081987e-05

# %%
print(f'The best window size is {best_window}')
# Out:
# The best window size is 17

# %% [markdown]
# ### Reinstantiate the model with the best window size

# %%
def model_architecture(hidden_units, activation_h, activation_d, lr):
    model = Sequential()
    input_shape = (1, best_window) 
    model.add(Dense(units=hidden_units,input_shape=input_shape, activation=activation_h))
    model.add(Dense(units=1, activation=activation_d))
    model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=lr),metrics=['mean_squared_error'])
    return model

# %%
#prepare the data again, compatibly with the best window size found
trainX, trainY = get_XY(x_train, y_train, best_window)
validX, validY = get_XY(x_valid, y_valid, best_window)
testX, testY = get_XY(x_test, y_test, best_window)

#check shape
print(trainX.shape,trainY.shape)
# Out:
# (3983, 1, 17) (3983,)

# %% [markdown]
# To ultimate model selection, we find the optimal number of epochs

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
#model = keras.models.load_model(f'keras_model_tdnn_{best_window}')
model = tuner.hypermodel.build(final_hps)
model.summary()
history = model.fit(trainX, trainY, epochs=50, batch_size=bs, verbose=2, validation_data = (validX, validY))
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 1, 130)            2340
#
#  dense_15 (Dense)            (None, 1, 1)              131
#
# =================================================================
# Total params: 2,471
# Trainable params: 2,471
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 3983/3983 - 6s - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 3.9507e-04 - val_mean_squared_error: 3.9507e-04 - 6s/epoch - 2ms/step
# Epoch 2/50
# 3983/3983 - 5s - loss: 1.8134e-04 - mean_squared_error: 1.8134e-04 - val_loss: 1.1113e-04 - val_mean_squared_error: 1.1113e-04 - 5s/epoch - 1ms/step
# Epoch 3/50
# 3983/3983 - 5s - loss: 5.8838e-05 - mean_squared_error: 5.8838e-05 - val_loss: 7.4911e-05 - val_mean_squared_error: 7.4911e-05 - 5s/epoch - 1ms/step
# Epoch 4/50
# 3983/3983 - 4s - loss: 2.7928e-05 - mean_squared_error: 2.7928e-05 - val_loss: 3.2997e-05 - val_mean_squared_error: 3.2997e-05 - 4s/epoch - 957us/step
# Epoch 5/50
# 3983/3983 - 4s - loss: 2.0674e-05 - mean_squared_error: 2.0674e-05 - val_loss: 1.6407e-05 - val_mean_squared_error: 1.6407e-05 - 4s/epoch - 1ms/step
# Epoch 6/50
# 3983/3983 - 4s - loss: 1.8305e-05 - mean_squared_error: 1.8305e-05 - val_loss: 1.8523e-05 - val_mean_squared_error: 1.8523e-05 - 4s/epoch - 1ms/step
# Epoch 7/50
# 3983/3983 - 5s - loss: 1.3007e-05 - mean_squared_error: 1.3007e-05 - val_loss: 5.1475e-05 - val_mean_squared_error: 5.1475e-05 - 5s/epoch - 1ms/step
# Epoch 8/50
# 3983/3983 - 5s - loss: 1.1406e-05 - mean_squared_error: 1.1406e-05 - val_loss: 5.1325e-06 - val_mean_squared_error: 5.1325e-06 - 5s/epoch - 1ms/step
# Epoch 9/50
# 3983/3983 - 5s - loss: 1.0959e-05 - mean_squared_error: 1.0959e-05 - val_loss: 7.8964e-06 - val_mean_squared_error: 7.8964e-06 - 5s/epoch - 1ms/step
# Epoch 10/50
# 3983/3983 - 4s - loss: 1.0478e-05 - mean_squared_error: 1.0478e-05 - val_loss: 2.5441e-05 - val_mean_squared_error: 2.5441e-05 - 4s/epoch - 1ms/step
# Epoch 11/50
# 3983/3983 - 5s - loss: 1.0573e-05 - mean_squared_error: 1.0573e-05 - val_loss: 5.2475e-06 - val_mean_squared_error: 5.2475e-06 - 5s/epoch - 1ms/step
# Epoch 12/50
# 3983/3983 - 7s - loss: 9.1860e-06 - mean_squared_error: 9.1860e-06 - val_loss: 5.8974e-06 - val_mean_squared_error: 5.8974e-06 - 7s/epoch - 2ms/step
# Epoch 13/50
# 3983/3983 - 5s - loss: 1.0393e-05 - mean_squared_error: 1.0393e-05 - val_loss: 5.4027e-06 - val_mean_squared_error: 5.4027e-06 - 5s/epoch - 1ms/step
# Epoch 14/50
# 3983/3983 - 5s - loss: 8.2025e-06 - mean_squared_error: 8.2025e-06 - val_loss: 3.7652e-06 - val_mean_squared_error: 3.7652e-06 - 5s/epoch - 1ms/step
# Epoch 15/50
# 3983/3983 - 5s - loss: 8.0459e-06 - mean_squared_error: 8.0459e-06 - val_loss: 6.9868e-06 - val_mean_squared_error: 6.9868e-06 - 5s/epoch - 1ms/step
# Epoch 16/50
# 3983/3983 - 5s - loss: 7.8395e-06 - mean_squared_error: 7.8395e-06 - val_loss: 3.2189e-05 - val_mean_squared_error: 3.2189e-05 - 5s/epoch - 1ms/step
# Epoch 17/50
# 3983/3983 - 5s - loss: 8.6086e-06 - mean_squared_error: 8.6086e-06 - val_loss: 2.2729e-06 - val_mean_squared_error: 2.2729e-06 - 5s/epoch - 1ms/step
# Epoch 18/50
# 3983/3983 - 5s - loss: 8.5728e-06 - mean_squared_error: 8.5728e-06 - val_loss: 4.6841e-06 - val_mean_squared_error: 4.6841e-06 - 5s/epoch - 1ms/step
# Epoch 19/50
# 3983/3983 - 5s - loss: 7.7477e-06 - mean_squared_error: 7.7477e-06 - val_loss: 3.2362e-06 - val_mean_squared_error: 3.2362e-06 - 5s/epoch - 1ms/step
# Epoch 20/50
# 3983/3983 - 5s - loss: 6.4539e-06 - mean_squared_error: 6.4539e-06 - val_loss: 2.1898e-06 - val_mean_squared_error: 2.1898e-06 - 5s/epoch - 1ms/step
# Epoch 21/50
# 3983/3983 - 5s - loss: 6.8816e-06 - mean_squared_error: 6.8816e-06 - val_loss: 3.4371e-06 - val_mean_squared_error: 3.4371e-06 - 5s/epoch - 1ms/step
# Epoch 22/50
# 3983/3983 - 4s - loss: 9.1322e-06 - mean_squared_error: 9.1322e-06 - val_loss: 4.2169e-06 - val_mean_squared_error: 4.2169e-06 - 4s/epoch - 1ms/step
# Epoch 23/50
# 3983/3983 - 4s - loss: 7.6540e-06 - mean_squared_error: 7.6540e-06 - val_loss: 5.4945e-06 - val_mean_squared_error: 5.4945e-06 - 4s/epoch - 1ms/step
# Epoch 24/50
# 3983/3983 - 5s - loss: 7.4885e-06 - mean_squared_error: 7.4885e-06 - val_loss: 3.7705e-06 - val_mean_squared_error: 3.7705e-06 - 5s/epoch - 1ms/step
# Epoch 25/50
# 3983/3983 - 5s - loss: 7.0960e-06 - mean_squared_error: 7.0960e-06 - val_loss: 2.5420e-06 - val_mean_squared_error: 2.5420e-06 - 5s/epoch - 1ms/step
# Epoch 26/50
# 3983/3983 - 5s - loss: 6.9413e-06 - mean_squared_error: 6.9413e-06 - val_loss: 8.7897e-06 - val_mean_squared_error: 8.7897e-06 - 5s/epoch - 1ms/step
# Epoch 27/50
# 3983/3983 - 5s - loss: 6.3610e-06 - mean_squared_error: 6.3610e-06 - val_loss: 2.9722e-06 - val_mean_squared_error: 2.9722e-06 - 5s/epoch - 1ms/step
# Epoch 28/50
# 3983/3983 - 5s - loss: 6.5346e-06 - mean_squared_error: 6.5346e-06 - val_loss: 5.0170e-06 - val_mean_squared_error: 5.0170e-06 - 5s/epoch - 1ms/step
# Epoch 29/50
# 3983/3983 - 4s - loss: 6.7837e-06 - mean_squared_error: 6.7837e-06 - val_loss: 2.9576e-06 - val_mean_squared_error: 2.9576e-06 - 4s/epoch - 1ms/step
# Epoch 30/50
# 3983/3983 - 4s - loss: 6.1832e-06 - mean_squared_error: 6.1832e-06 - val_loss: 6.4064e-06 - val_mean_squared_error: 6.4064e-06 - 4s/epoch - 1ms/step
# Epoch 31/50
# 3983/3983 - 5s - loss: 6.8257e-06 - mean_squared_error: 6.8257e-06 - val_loss: 1.3057e-05 - val_mean_squared_error: 1.3057e-05 - 5s/epoch - 1ms/step
# Epoch 32/50
# 3983/3983 - 5s - loss: 8.2647e-06 - mean_squared_error: 8.2647e-06 - val_loss: 5.5953e-06 - val_mean_squared_error: 5.5953e-06 - 5s/epoch - 1ms/step
# Epoch 33/50
# 3983/3983 - 5s - loss: 5.2445e-06 - mean_squared_error: 5.2445e-06 - val_loss: 1.8825e-06 - val_mean_squared_error: 1.8825e-06 - 5s/epoch - 1ms/step
# Epoch 34/50
# 3983/3983 - 6s - loss: 6.2464e-06 - mean_squared_error: 6.2464e-06 - val_loss: 4.4638e-06 - val_mean_squared_error: 4.4638e-06 - 6s/epoch - 1ms/step
# Epoch 35/50
# 3983/3983 - 5s - loss: 6.3814e-06 - mean_squared_error: 6.3814e-06 - val_loss: 2.5406e-06 - val_mean_squared_error: 2.5406e-06 - 5s/epoch - 1ms/step
# Epoch 36/50
# 3983/3983 - 6s - loss: 6.0949e-06 - mean_squared_error: 6.0949e-06 - val_loss: 4.6307e-06 - val_mean_squared_error: 4.6307e-06 - 6s/epoch - 2ms/step
# Epoch 37/50
# 3983/3983 - 9s - loss: 5.7466e-06 - mean_squared_error: 5.7466e-06 - val_loss: 6.7569e-06 - val_mean_squared_error: 6.7569e-06 - 9s/epoch - 2ms/step
# Epoch 38/50
# 3983/3983 - 10s - loss: 7.0560e-06 - mean_squared_error: 7.0560e-06 - val_loss: 4.9916e-06 - val_mean_squared_error: 4.9916e-06 - 10s/epoch - 3ms/step
# Epoch 39/50
# 3983/3983 - 9s - loss: 4.8126e-06 - mean_squared_error: 4.8126e-06 - val_loss: 1.2556e-06 - val_mean_squared_error: 1.2556e-06 - 9s/epoch - 2ms/step
# Epoch 40/50
# 3983/3983 - 8s - loss: 6.0959e-06 - mean_squared_error: 6.0959e-06 - val_loss: 2.9662e-06 - val_mean_squared_error: 2.9662e-06 - 8s/epoch - 2ms/step
# Epoch 41/50
# 3983/3983 - 8s - loss: 5.2559e-06 - mean_squared_error: 5.2559e-06 - val_loss: 1.2337e-05 - val_mean_squared_error: 1.2337e-05 - 8s/epoch - 2ms/step
# Epoch 42/50
# 3983/3983 - 8s - loss: 5.5151e-06 - mean_squared_error: 5.5151e-06 - val_loss: 3.2798e-06 - val_mean_squared_error: 3.2798e-06 - 8s/epoch - 2ms/step
# Epoch 43/50
# 3983/3983 - 8s - loss: 4.9324e-06 - mean_squared_error: 4.9324e-06 - val_loss: 1.9284e-06 - val_mean_squared_error: 1.9284e-06 - 8s/epoch - 2ms/step
# Epoch 44/50
# 3983/3983 - 9s - loss: 5.3878e-06 - mean_squared_error: 5.3878e-06 - val_loss: 1.5384e-05 - val_mean_squared_error: 1.5384e-05 - 9s/epoch - 2ms/step
# Epoch 45/50
# 3983/3983 - 8s - loss: 4.9468e-06 - mean_squared_error: 4.9468e-06 - val_loss: 1.2380e-06 - val_mean_squared_error: 1.2380e-06 - 8s/epoch - 2ms/step
# Epoch 46/50
# 3983/3983 - 8s - loss: 5.6467e-06 - mean_squared_error: 5.6467e-06 - val_loss: 1.6759e-06 - val_mean_squared_error: 1.6759e-06 - 8s/epoch - 2ms/step
# Epoch 47/50
# 3983/3983 - 8s - loss: 4.9434e-06 - mean_squared_error: 4.9434e-06 - val_loss: 1.1272e-05 - val_mean_squared_error: 1.1272e-05 - 8s/epoch - 2ms/step
# Epoch 48/50
# 3983/3983 - 8s - loss: 5.4343e-06 - mean_squared_error: 5.4343e-06 - val_loss: 1.7807e-05 - val_mean_squared_error: 1.7807e-05 - 8s/epoch - 2ms/step
# Epoch 49/50
# 3983/3983 - 8s - loss: 5.1136e-06 - mean_squared_error: 5.1136e-06 - val_loss: 4.7905e-06 - val_mean_squared_error: 4.7905e-06 - 8s/epoch - 2ms/step
# Epoch 50/50
# 3983/3983 - 8s - loss: 4.8745e-06 - mean_squared_error: 4.8745e-06 - val_loss: 2.0105e-06 - val_mean_squared_error: 2.0105e-06 - 8s/epoch - 2ms/step

# %% [markdown]
# Find best epoch:

# %%
val_mse_per_epoch = history.history['val_mean_squared_error']
best_epoch = val_mse_per_epoch.index(min(val_mse_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 45

# %% [markdown]
# save into a file the values found for best number of epochs and best window size

# %%
hp = np.array([best_epoch, best_window])
np.save('hyperparameters_best_epoch_best_window',hp, allow_pickle=True)

# %% [markdown]
# # END OF MODEL SELECTION

# %% [markdown]
# to load the best values found for number of epochs and window size:

# %%
#best_epoch, best_window = np.load('hyperparameters_best_epoch_best_window.npy', allow_pickle=True)

# %% [markdown]
# Re-instantiate the hypermodel and train it with the optimal number of epochs from above.

# %%
final_model = tuner.hypermodel.build(final_hps)

# %%
# Retrain the model
history = final_model.fit(trainX, trainY, epochs=best_epoch, batch_size=bs, verbose=2, validation_data = (validX, validY)).history
# Out:
# Epoch 1/45
# 3983/3983 - 11s - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 1.2750e-04 - val_mean_squared_error: 1.2750e-04 - 11s/epoch - 3ms/step
# Epoch 2/45
# 3983/3983 - 9s - loss: 6.2388e-05 - mean_squared_error: 6.2388e-05 - val_loss: 4.3601e-05 - val_mean_squared_error: 4.3601e-05 - 9s/epoch - 2ms/step
# Epoch 3/45
# 3983/3983 - 8s - loss: 3.2454e-05 - mean_squared_error: 3.2454e-05 - val_loss: 2.1704e-05 - val_mean_squared_error: 2.1704e-05 - 8s/epoch - 2ms/step
# Epoch 4/45
# 3983/3983 - 9s - loss: 2.1891e-05 - mean_squared_error: 2.1891e-05 - val_loss: 1.6142e-05 - val_mean_squared_error: 1.6142e-05 - 9s/epoch - 2ms/step
# Epoch 5/45
# 3983/3983 - 10s - loss: 1.8520e-05 - mean_squared_error: 1.8520e-05 - val_loss: 1.5799e-05 - val_mean_squared_error: 1.5799e-05 - 10s/epoch - 2ms/step
# Epoch 6/45
# 3983/3983 - 10s - loss: 1.5098e-05 - mean_squared_error: 1.5098e-05 - val_loss: 8.6555e-06 - val_mean_squared_error: 8.6555e-06 - 10s/epoch - 3ms/step
# Epoch 7/45
# 3983/3983 - 6s - loss: 1.4597e-05 - mean_squared_error: 1.4597e-05 - val_loss: 6.2394e-06 - val_mean_squared_error: 6.2394e-06 - 6s/epoch - 2ms/step
# Epoch 8/45
# 3983/3983 - 7s - loss: 1.2976e-05 - mean_squared_error: 1.2976e-05 - val_loss: 5.7994e-06 - val_mean_squared_error: 5.7994e-06 - 7s/epoch - 2ms/step
# Epoch 9/45
# 3983/3983 - 6s - loss: 1.2243e-05 - mean_squared_error: 1.2243e-05 - val_loss: 4.7730e-06 - val_mean_squared_error: 4.7730e-06 - 6s/epoch - 2ms/step
# Epoch 10/45
# 3983/3983 - 7s - loss: 1.0173e-05 - mean_squared_error: 1.0173e-05 - val_loss: 4.2494e-06 - val_mean_squared_error: 4.2494e-06 - 7s/epoch - 2ms/step
# Epoch 11/45
# 3983/3983 - 7s - loss: 1.1162e-05 - mean_squared_error: 1.1162e-05 - val_loss: 6.4610e-06 - val_mean_squared_error: 6.4610e-06 - 7s/epoch - 2ms/step
# Epoch 12/45
# 3983/3983 - 9s - loss: 1.0066e-05 - mean_squared_error: 1.0066e-05 - val_loss: 4.8839e-06 - val_mean_squared_error: 4.8839e-06 - 9s/epoch - 2ms/step
# Epoch 13/45
# 3983/3983 - 7s - loss: 8.7143e-06 - mean_squared_error: 8.7143e-06 - val_loss: 5.4709e-06 - val_mean_squared_error: 5.4709e-06 - 7s/epoch - 2ms/step
# Epoch 14/45
# 3983/3983 - 6s - loss: 9.5404e-06 - mean_squared_error: 9.5404e-06 - val_loss: 7.3433e-06 - val_mean_squared_error: 7.3433e-06 - 6s/epoch - 2ms/step
# Epoch 15/45
# 3983/3983 - 6s - loss: 9.6033e-06 - mean_squared_error: 9.6033e-06 - val_loss: 9.1028e-06 - val_mean_squared_error: 9.1028e-06 - 6s/epoch - 2ms/step
# Epoch 16/45
# 3983/3983 - 6s - loss: 7.3301e-06 - mean_squared_error: 7.3301e-06 - val_loss: 5.8926e-06 - val_mean_squared_error: 5.8926e-06 - 6s/epoch - 2ms/step
# Epoch 17/45
# 3983/3983 - 7s - loss: 7.6239e-06 - mean_squared_error: 7.6239e-06 - val_loss: 2.5279e-06 - val_mean_squared_error: 2.5279e-06 - 7s/epoch - 2ms/step
# Epoch 18/45
# 3983/3983 - 6s - loss: 9.0036e-06 - mean_squared_error: 9.0036e-06 - val_loss: 4.2963e-06 - val_mean_squared_error: 4.2963e-06 - 6s/epoch - 2ms/step
# Epoch 19/45
# 3983/3983 - 6s - loss: 8.3279e-06 - mean_squared_error: 8.3279e-06 - val_loss: 4.9047e-06 - val_mean_squared_error: 4.9047e-06 - 6s/epoch - 2ms/step
# Epoch 20/45
# 3983/3983 - 7s - loss: 8.9712e-06 - mean_squared_error: 8.9712e-06 - val_loss: 4.5475e-06 - val_mean_squared_error: 4.5475e-06 - 7s/epoch - 2ms/step
# Epoch 21/45
# 3983/3983 - 9s - loss: 7.2112e-06 - mean_squared_error: 7.2112e-06 - val_loss: 1.0029e-05 - val_mean_squared_error: 1.0029e-05 - 9s/epoch - 2ms/step
# Epoch 22/45
# 3983/3983 - 8s - loss: 7.5997e-06 - mean_squared_error: 7.5997e-06 - val_loss: 5.1173e-06 - val_mean_squared_error: 5.1173e-06 - 8s/epoch - 2ms/step
# Epoch 23/45
# 3983/3983 - 9s - loss: 9.4835e-06 - mean_squared_error: 9.4835e-06 - val_loss: 2.1035e-06 - val_mean_squared_error: 2.1035e-06 - 9s/epoch - 2ms/step
# Epoch 24/45
# 3983/3983 - 9s - loss: 8.1010e-06 - mean_squared_error: 8.1010e-06 - val_loss: 1.5115e-05 - val_mean_squared_error: 1.5115e-05 - 9s/epoch - 2ms/step
# Epoch 25/45
# 3983/3983 - 9s - loss: 6.7601e-06 - mean_squared_error: 6.7601e-06 - val_loss: 1.6535e-05 - val_mean_squared_error: 1.6535e-05 - 9s/epoch - 2ms/step
# Epoch 26/45
# 3983/3983 - 8s - loss: 7.4993e-06 - mean_squared_error: 7.4993e-06 - val_loss: 3.9038e-06 - val_mean_squared_error: 3.9038e-06 - 8s/epoch - 2ms/step
# Epoch 27/45
# 3983/3983 - 7s - loss: 6.8123e-06 - mean_squared_error: 6.8123e-06 - val_loss: 3.1388e-06 - val_mean_squared_error: 3.1388e-06 - 7s/epoch - 2ms/step
# Epoch 28/45
# 3983/3983 - 7s - loss: 7.9178e-06 - mean_squared_error: 7.9178e-06 - val_loss: 2.9359e-06 - val_mean_squared_error: 2.9359e-06 - 7s/epoch - 2ms/step
# Epoch 29/45
# 3983/3983 - 8s - loss: 7.2591e-06 - mean_squared_error: 7.2591e-06 - val_loss: 3.4245e-06 - val_mean_squared_error: 3.4245e-06 - 8s/epoch - 2ms/step
# Epoch 30/45
# 3983/3983 - 9s - loss: 7.2016e-06 - mean_squared_error: 7.2016e-06 - val_loss: 2.1121e-06 - val_mean_squared_error: 2.1121e-06 - 9s/epoch - 2ms/step
# Epoch 31/45
# 3983/3983 - 7s - loss: 6.2483e-06 - mean_squared_error: 6.2483e-06 - val_loss: 1.7887e-05 - val_mean_squared_error: 1.7887e-05 - 7s/epoch - 2ms/step
# Epoch 32/45
# 3983/3983 - 8s - loss: 8.2098e-06 - mean_squared_error: 8.2098e-06 - val_loss: 5.2832e-06 - val_mean_squared_error: 5.2832e-06 - 8s/epoch - 2ms/step
# Epoch 33/45
# 3983/3983 - 10s - loss: 6.0003e-06 - mean_squared_error: 6.0003e-06 - val_loss: 2.4997e-06 - val_mean_squared_error: 2.4997e-06 - 10s/epoch - 2ms/step
# Epoch 34/45
# 3983/3983 - 8s - loss: 7.0615e-06 - mean_squared_error: 7.0615e-06 - val_loss: 1.0899e-05 - val_mean_squared_error: 1.0899e-05 - 8s/epoch - 2ms/step
# Epoch 35/45
# 3983/3983 - 9s - loss: 6.3512e-06 - mean_squared_error: 6.3512e-06 - val_loss: 9.3363e-06 - val_mean_squared_error: 9.3363e-06 - 9s/epoch - 2ms/step
# Epoch 36/45
# 3983/3983 - 9s - loss: 6.3602e-06 - mean_squared_error: 6.3602e-06 - val_loss: 1.4513e-06 - val_mean_squared_error: 1.4513e-06 - 9s/epoch - 2ms/step
# Epoch 37/45
# 3983/3983 - 9s - loss: 5.6073e-06 - mean_squared_error: 5.6073e-06 - val_loss: 2.7049e-06 - val_mean_squared_error: 2.7049e-06 - 9s/epoch - 2ms/step
# Epoch 38/45
# 3983/3983 - 10s - loss: 5.8286e-06 - mean_squared_error: 5.8286e-06 - val_loss: 9.1528e-06 - val_mean_squared_error: 9.1528e-06 - 10s/epoch - 2ms/step
# Epoch 39/45
# 3983/3983 - 10s - loss: 7.6375e-06 - mean_squared_error: 7.6375e-06 - val_loss: 2.4725e-06 - val_mean_squared_error: 2.4725e-06 - 10s/epoch - 3ms/step
# Epoch 40/45
# 3983/3983 - 9s - loss: 5.9384e-06 - mean_squared_error: 5.9384e-06 - val_loss: 1.5405e-06 - val_mean_squared_error: 1.5405e-06 - 9s/epoch - 2ms/step
# Epoch 41/45
# 3983/3983 - 8s - loss: 6.9928e-06 - mean_squared_error: 6.9928e-06 - val_loss: 8.8902e-06 - val_mean_squared_error: 8.8902e-06 - 8s/epoch - 2ms/step
# Epoch 42/45
# 3983/3983 - 7s - loss: 5.5013e-06 - mean_squared_error: 5.5013e-06 - val_loss: 3.4562e-06 - val_mean_squared_error: 3.4562e-06 - 7s/epoch - 2ms/step
# Epoch 43/45
# 3983/3983 - 7s - loss: 6.2776e-06 - mean_squared_error: 6.2776e-06 - val_loss: 1.9490e-06 - val_mean_squared_error: 1.9490e-06 - 7s/epoch - 2ms/step
# Epoch 44/45
# 3983/3983 - 7s - loss: 5.1394e-06 - mean_squared_error: 5.1394e-06 - val_loss: 2.9829e-06 - val_mean_squared_error: 2.9829e-06 - 7s/epoch - 2ms/step
# Epoch 45/45
# 3983/3983 - 7s - loss: 5.6406e-06 - mean_squared_error: 5.6406e-06 - val_loss: 4.6058e-06 - val_mean_squared_error: 4.6058e-06 - 7s/epoch - 2ms/step

# %% [markdown]
# ### Make plots of the loss and validation loss

# %%
history_plot(history,best_window)

# %% [markdown]
# Save history data

# %%
hist_df = pd.DataFrame(history) 
# save to json:  
hist_json_file = 'history_RNN.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %% [markdown]
# To load history data use:

# %%
#history = np.load('history_tdnn.npy')

# %% [markdown]
# Save the final model

# %%
final_model.save(f'keras_model_tdnn')
# Out:
# 2023-06-02 20:23:15.851251: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_16_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_16_input}}]]
# 2023-06-02 20:23:15.918019: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_16_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_16_input}}]]
# 2023-06-02 20:23:15.945107: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-06-02 20:23:15.971605: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_16_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_16_input}}]]
# 2023-06-02 20:23:15.994406: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-06-02 20:23:16.014217: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_16_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_16_input}}]]
# 2023-06-02 20:23:16.030619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-06-02 20:23:16.046720: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,130]
# 	 [[{{node inputs}}]]
# 2023-06-02 20:23:16.072762: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-06-02 20:23:16.094678: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-06-02 20:23:16.153332: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_16_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_16_input}}]]
# 2023-06-02 20:23:16.188618: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-06-02 20:23:16.205778: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-06-02 20:23:16.411475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-06-02 20:23:16.486374: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,130]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 2023-06-02 20:23:16.632406: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'serving_default_dense_16_input' with dtype float and shape [?,1,17]
# 	 [[{{node serving_default_dense_16_input}}]]
# INFO:tensorflow:Assets written to: keras_model_tdnn/assets
# INFO:tensorflow:Assets written to: keras_model_tdnn/assets

# %% [markdown]
# Command to (eventually) load the saved model:

# %%
#final_model = keras.models.load_model('keras_model_tdnn')

# %% [markdown]
# # Plots of target and output signals over time (of the best model)

# %%
#training
errors = []

y = final_model.predict(trainX)
mse = final_model.evaluate(trainX, trainY, batch_size=bs)[0]
errors.append(mse)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'training - MSE = {mse:e}')
plt.plot(y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(trainY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('training (first 200 timesteps)')
plt.plot(y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(trainY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig(f"plots/tdnn_training.pdf")

#validation
y = final_model.predict(validX)
mse = final_model.evaluate(validX, validY, batch_size=bs)[0]
errors.append(mse)
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'validation - MSE = {mse:e}')
plt.plot(y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(validY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('validation (first 200 timesteps)')
plt.plot(y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(validY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig(f"plots/tdnn_validation.pdf")

#test
y = final_model.predict(testX)
mse = final_model.evaluate(testX, testY, batch_size=bs)[0]
errors.append(mse)

t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'test - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,testY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('test (first 200 timesteps)')
plt.plot(y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(testY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig(f"plots/tdnn_test.pdf")


np.save('errors_tdnn',errors)
print(f'Training MSE = {errors[0]} \nValidation MSE = {errors[1]} \nTest MSE = {errors[2]}')
# Out:
# 125/125 [==============================] - 1s 3ms/step
# 3983/3983 [==============================] - 9s 2ms/step - loss: 4.2361e-06 - mean_squared_error: 4.2361e-06
# 31/31 [==============================] - 0s 3ms/step
# 983/983 [==============================] - 3s 3ms/step - loss: 4.6058e-06 - mean_squared_error: 4.6058e-06
# 156/156 [==============================] - 0s 3ms/step
# 4982/4982 [==============================] - 13s 3ms/step - loss: 4.4051e-06 - mean_squared_error: 4.4051e-06
# Training MSE = 4.236143468006048e-06
# Validation MSE = 4.605814410751918e-06
# Test MSE = 4.405124400364002e-06
