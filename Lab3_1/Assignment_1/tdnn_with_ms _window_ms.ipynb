# %% [markdown]
# # Assignment 1: NARMA10 task
# ## TDNN
# Note: as a reference for keras tuner I used the documentation: https://www.tensorflow.org/tutorials/keras/keras_tuner

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
import keras_tuner as kt
import pandas as pd
# Out:
# 2023-05-13 14:50:01.231128: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-13 14:50:01.278193: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-13 14:50:01.279235: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-13 14:50:02.401783: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# function to reshape the dataset to feed the tdnn

# %%
# Prepare the input X and target Y in order to implement the tdnn
def get_XY(x, y, window):
    # Remove the first "window" elements from y array
    Y = y[window:]
    # X will be an array containing "len(Y)" arrays created using the sliding window
    X = []
    rows_x = len(Y)
    j = 0
    for i in range(rows_x):
        X = np.append(X,x[j:j+window])
        j = j + 1

    #reshape X so it can be fed to the Dense layer
    X =  np.reshape(X, (rows_x, 1, window)) 
    return X, Y

# %% [markdown]
# function to plot the learning history

# %%
def history_plot(history,window):
    plt.figure(figsize = (15,5))

    plt.subplot(121)
    plt.plot(history['loss'])
    plt.title(f'Loss (window:{window})')
    plt.xlabel('Epochs')
    plt.ylabel('MSE')
    plt.yscale('log')

    plt.subplot(122)
    plt.plot(history['val_loss'])
    plt.title(f'Validation Loss (window:{window})')
    plt.xlabel('Epochs')
    plt.ylabel('MSE')
    plt.yscale('log')
    plt.tight_layout()

    plt.savefig(f"plots/tdnn_loss_{window}.pdf")
    plt.show()

# %% [markdown]
# ### Load the dataset

# %%
#load the data
x, y = np.loadtxt("NARMA10.csv", delimiter=",")


#split the dataset into training, validation and test
x_train = x[:4000]
x_valid = x[4000:5000] #validation
x_test = x[5000:]

y_train = y[:4000]
y_valid = y[4000:5000]
y_test = y[5000:]

#plot the data
t=np.arange(start=0,stop=len(x), step=1)
plt.figure(figsize = (25,7))
ax1 = plt.subplot(211)
plt.title('Input', fontsize=18)
ax1.plot(t,x, color = 'b', linewidth= 0.2)
ax1.axvline(x = 4000, color = 'black', linestyle= '--')
ax1.axvline(x = 5000, color = 'black', linestyle= '--')

ax2 = plt.subplot(212, sharex = ax1)
plt.title('Target', fontsize=18)
ax2.plot(t,y, color = 'r', linewidth = 0.2)
ax2.axvline(x = 4000, color = 'black', linestyle= '--')
ax2.axvline(x = 5000, color = 'black', linestyle= '--')
plt.xlabel('Timesteps', fontsize=14)
plt.tight_layout()

# %% [markdown]
# function to create the hypermodel, defining a list of hyperparameters to take into account:

# %%
def create_model(hp):

    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 50-150
    hidden_units = hp.Int('units',  min_value=50, max_value=150, step=10)

    #Tune the activation function of the hidden layer
    activation_h = hp.Choice("activation_h", ["linear","relu", "tanh"])
    #Tune the activation function of the last layer
    activation_d = hp.Choice("activation_d", ["linear","relu"])
    # Tune the learning rate for the optimizer
    lr = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])


    # call model-building code with the hyperparameter values.
    model = model_architecture(
        hidden_units=hidden_units, activation_d=activation_d, activation_h=activation_h, lr=lr
    )
    return model

# %% [markdown]
# # COME MAI FUNZIONA SOLO CON BS = 1 ???

# %% [markdown]
# batch size:

# %%
#batch size 
bs = 1

# %% [markdown]
# # MODEL SELECTION
# In order to do model selection, I proceed in part using keras tuner, and in part manually.
# In fact, with keras tuner it was not possible to set the window size as an hyperparameter, because changing thew window size means changing the dataset structure.
# To solve this problem, i created a for cycle to handle the model selection for the window size, and inside the cycle I use keras tuner to tune the other hyperparameters, i.e:
# - number of units of hidden layer
# - learning rate for the optimizer
# - activation function for the hidden layer
# - activation function for the dense layer

# %%
#size of the window we use to buffer the input
windows = [10,15,20] #window sizes to investigate

mse_min = 1e3 #initialize to a high value
for window_size in windows:
    print(f'\n WINDOW SIZE: {window_size} \n')

    #Prepare the dataset to feed the tdnn, accordingly to the selected window size:
    trainX, trainY = get_XY(x_train, y_train, window_size)
    validX, validY = get_XY(x_valid, y_valid, window_size)
    testX, testY = get_XY(x_test, y_test, window_size)

    #Create the model
    #To do model selection, we actually create the "hypermodel",
    #defining the hyperparameter search space as well as the architecture of the model.

    def model_architecture(hidden_units, activation_h, activation_d, lr):
        model = Sequential()
        input_shape = (1, window_size) 
        model.add(Dense(units=hidden_units,input_shape=input_shape, activation=activation_h))
        model.add(Dense(units=1, activation=activation_d))
        model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=lr),metrics=['mean_squared_error'])
        return model


    # Instantiate hyperparameter tuner
    # use random search to find optimal hyperparameters
    tuner = kt.RandomSearch(
                        hypermodel = create_model,
                        objective='val_mean_squared_error',
                        max_trials=20,
                        #overwrite=True,
                        directory='tuner',
                        project_name=f'tuner_tdnn_{window_size}'
                        )

    tuner.search_space_summary()


    #Create a callback to stop training early after reaching a certain value for the validation loss.
    stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)


    tuner.search(trainX, trainY, epochs=8, batch_size=bs, validation_data = (validX, validY), callbacks=[stop_early])
    # Get the optimal hyperparameters
    best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

    print(f"""
    Completed hyperparameters search for window size: {window_size}.\n
    Otimal number of units of hidden layer = {best_hps.get('units')} \n
    Optimal learning rate for the optimizer = {best_hps.get('learning_rate')} \n
    Optimal activation function for the hidden layer = {best_hps.get('activation_h')} \n
    Optimal activation function for the dense layer = {best_hps.get('activation_d')}
    """)
        
    #instantiate the model
    window_model = tuner.hypermodel.build(best_hps)
    window_model.summary()
    window_model.fit(trainX, trainY, epochs=10, batch_size=bs, verbose=2, validation_data = (validX, validY))
    mse = window_model.evaluate(validX, validY, batch_size=bs)[0]
    print(f'\n mse with window {window_size} is {mse} \n') 
    window_model.save(f'keras_model_tdnn_{window_size}')
    if mse < mse_min:
        mse_min = mse
        best_window = window_size
# Out:
# WINDOW SIZE: 10
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_10/tuner0.json
# Search space summary
# Default search space size: 4
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 50, 'max_value': 150, 'step': 10, 'sampling': 'linear'}
# activation_h (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu', 'tanh'], 'ordered': False}
# activation_d (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu'], 'ordered': False}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# INFO:tensorflow:Oracle triggered exit
#
#     Completed hyperparameters search for window size: 10.
#
#     Otimal number of units of hidden layer = 60
#
#     Optimal learning rate for the optimizer = 0.001
#
#     Optimal activation function for the hidden layer = relu
#
#     Optimal activation function for the dense layer = relu
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1, 60)             660
#
#  dense_1 (Dense)             (None, 1, 1)              61
#
# =================================================================
# Total params: 721
# Trainable params: 721
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3990/3990 - 5s - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 7.0939e-04 - val_mean_squared_error: 7.0939e-04 - 5s/epoch - 1ms/step
# Epoch 2/10
# 3990/3990 - 6s - loss: 7.4519e-04 - mean_squared_error: 7.4519e-04 - val_loss: 5.5072e-04 - val_mean_squared_error: 5.5072e-04 - 6s/epoch - 1ms/step
# Epoch 3/10
# 3990/3990 - 7s - loss: 6.3578e-04 - mean_squared_error: 6.3578e-04 - val_loss: 5.8334e-04 - val_mean_squared_error: 5.8334e-04 - 7s/epoch - 2ms/step
# Epoch 4/10
# 3990/3990 - 6s - loss: 6.0163e-04 - mean_squared_error: 6.0163e-04 - val_loss: 5.2568e-04 - val_mean_squared_error: 5.2568e-04 - 6s/epoch - 1ms/step
# Epoch 5/10
# 3990/3990 - 5s - loss: 5.7015e-04 - mean_squared_error: 5.7015e-04 - val_loss: 4.9365e-04 - val_mean_squared_error: 4.9365e-04 - 5s/epoch - 1ms/step
# Epoch 6/10
# 3990/3990 - 5s - loss: 5.4015e-04 - mean_squared_error: 5.4015e-04 - val_loss: 5.3982e-04 - val_mean_squared_error: 5.3982e-04 - 5s/epoch - 1ms/step
# Epoch 7/10
# 3990/3990 - 5s - loss: 5.4114e-04 - mean_squared_error: 5.4114e-04 - val_loss: 4.7433e-04 - val_mean_squared_error: 4.7433e-04 - 5s/epoch - 1ms/step
# Epoch 8/10
# 3990/3990 - 5s - loss: 5.1484e-04 - mean_squared_error: 5.1484e-04 - val_loss: 5.5637e-04 - val_mean_squared_error: 5.5637e-04 - 5s/epoch - 1ms/step
# Epoch 9/10
# 3990/3990 - 5s - loss: 4.9804e-04 - mean_squared_error: 4.9804e-04 - val_loss: 4.8730e-04 - val_mean_squared_error: 4.8730e-04 - 5s/epoch - 1ms/step
# Epoch 10/10
# 3990/3990 - 5s - loss: 4.9611e-04 - mean_squared_error: 4.9611e-04 - val_loss: 4.7472e-04 - val_mean_squared_error: 4.7472e-04 - 5s/epoch - 1ms/step
# 990/990 [==============================] - 1s 1ms/step - loss: 4.7472e-04 - mean_squared_error: 4.7472e-04
# mse with window 10 is 0.00047472454025410116
# 2023-05-13 14:51:00.671706: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_input' with dtype float and shape [?,1,10]
# 	 [[{{node dense_input}}]]
# 2023-05-13 14:51:00.700858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_input' with dtype float and shape [?,1,10]
# 	 [[{{node dense_input}}]]
# 2023-05-13 14:51:00.714713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,10]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:00.729042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_input' with dtype float and shape [?,1,10]
# 	 [[{{node dense_input}}]]
# 2023-05-13 14:51:00.742502: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,10]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:00.754481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_input' with dtype float and shape [?,1,10]
# 	 [[{{node dense_input}}]]
# 2023-05-13 14:51:00.761720: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,10]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:00.770459: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,60]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:00.781625: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,10]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:00.791901: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,10]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:00.910155: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_input' with dtype float and shape [?,1,10]
# 	 [[{{node dense_input}}]]
# 2023-05-13 14:51:00.933900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,10]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:00.952461: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,10]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:01.055876: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,10]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:01.092929: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,60]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 2023-05-13 14:51:01.179151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'serving_default_dense_input' with dtype float and shape [?,1,10]
# 	 [[{{node serving_default_dense_input}}]]
# INFO:tensorflow:Assets written to: keras_model_tdnn_10/assets
# INFO:tensorflow:Assets written to: keras_model_tdnn_10/assets
# WINDOW SIZE: 15
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_15/tuner0.json
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_15/tuner0.json
# Search space summary
# Default search space size: 4
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 50, 'max_value': 150, 'step': 10, 'sampling': 'linear'}
# activation_h (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu', 'tanh'], 'ordered': False}
# activation_d (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu'], 'ordered': False}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
#     Completed hyperparameters search for window size: 15.
#
#     Otimal number of units of hidden layer = 70
#
#     Optimal learning rate for the optimizer = 0.001
#
#     Optimal activation function for the hidden layer = relu
#
#     Optimal activation function for the dense layer = relu
#
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1, 70)             1120
#
#  dense_3 (Dense)             (None, 1, 1)              71
#
# =================================================================
# Total params: 1,191
# Trainable params: 1,191
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3985/3985 - 6s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 3.2544e-04 - val_mean_squared_error: 3.2544e-04 - 6s/epoch - 1ms/step
# Epoch 2/10
# 3985/3985 - 5s - loss: 2.7698e-04 - mean_squared_error: 2.7698e-04 - val_loss: 2.5840e-04 - val_mean_squared_error: 2.5840e-04 - 5s/epoch - 1ms/step
# Epoch 3/10
# 3985/3985 - 5s - loss: 1.7519e-04 - mean_squared_error: 1.7519e-04 - val_loss: 1.0747e-04 - val_mean_squared_error: 1.0747e-04 - 5s/epoch - 1ms/step
# Epoch 4/10
# 3985/3985 - 5s - loss: 1.2270e-04 - mean_squared_error: 1.2270e-04 - val_loss: 5.8877e-05 - val_mean_squared_error: 5.8877e-05 - 5s/epoch - 1ms/step
# Epoch 5/10
# 3985/3985 - 5s - loss: 9.4270e-05 - mean_squared_error: 9.4270e-05 - val_loss: 2.0613e-04 - val_mean_squared_error: 2.0613e-04 - 5s/epoch - 1ms/step
# Epoch 6/10
# 3985/3985 - 5s - loss: 8.0566e-05 - mean_squared_error: 8.0566e-05 - val_loss: 5.1550e-05 - val_mean_squared_error: 5.1550e-05 - 5s/epoch - 1ms/step
# Epoch 7/10
# 3985/3985 - 5s - loss: 6.8145e-05 - mean_squared_error: 6.8145e-05 - val_loss: 8.0002e-05 - val_mean_squared_error: 8.0002e-05 - 5s/epoch - 1ms/step
# Epoch 8/10
# 3985/3985 - 5s - loss: 6.2040e-05 - mean_squared_error: 6.2040e-05 - val_loss: 1.3046e-04 - val_mean_squared_error: 1.3046e-04 - 5s/epoch - 1ms/step
# Epoch 9/10
# 3985/3985 - 5s - loss: 5.4341e-05 - mean_squared_error: 5.4341e-05 - val_loss: 2.8679e-05 - val_mean_squared_error: 2.8679e-05 - 5s/epoch - 1ms/step
# Epoch 10/10
# 3985/3985 - 5s - loss: 4.6754e-05 - mean_squared_error: 4.6754e-05 - val_loss: 4.6863e-05 - val_mean_squared_error: 4.6863e-05 - 5s/epoch - 1ms/step
# 985/985 [==============================] - 1s 1ms/step - loss: 4.6863e-05 - mean_squared_error: 4.6863e-05
# mse with window 15 is 4.6862805902492255e-05
# 2023-05-13 14:51:54.815402: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,15]
# 	 [[{{node dense_2_input}}]]
# 2023-05-13 14:51:54.845852: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,15]
# 	 [[{{node dense_2_input}}]]
# 2023-05-13 14:51:54.857956: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:54.867236: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,15]
# 	 [[{{node dense_2_input}}]]
# 2023-05-13 14:51:54.878618: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:54.887769: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,15]
# 	 [[{{node dense_2_input}}]]
# 2023-05-13 14:51:54.896280: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:54.902524: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,70]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:54.915247: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:54.924056: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:54.945097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,15]
# 	 [[{{node dense_2_input}}]]
# 2023-05-13 14:51:54.958975: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:54.967532: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:55.052713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:51:55.088763: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,70]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 2023-05-13 14:51:55.166433: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'serving_default_dense_2_input' with dtype float and shape [?,1,15]
# 	 [[{{node serving_default_dense_2_input}}]]
# INFO:tensorflow:Assets written to: keras_model_tdnn_15/assets
# INFO:tensorflow:Assets written to: keras_model_tdnn_15/assets
# WINDOW SIZE: 20
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_20/tuner0.json
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_20/tuner0.json
# Search space summary
# Default search space size: 4
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 50, 'max_value': 150, 'step': 10, 'sampling': 'linear'}
# activation_h (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu', 'tanh'], 'ordered': False}
# activation_d (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu'], 'ordered': False}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
#     Completed hyperparameters search for window size: 20.
#
#     Otimal number of units of hidden layer = 110
#
#     Optimal learning rate for the optimizer = 0.01
#
#     Optimal activation function for the hidden layer = tanh
#
#     Optimal activation function for the dense layer = linear
#
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1, 110)            2310
#
#  dense_5 (Dense)             (None, 1, 1)              111
#
# =================================================================
# Total params: 2,421
# Trainable params: 2,421
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3980/3980 - 6s - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - 6s/epoch - 1ms/step
# Epoch 2/10
# 3980/3980 - 5s - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - 5s/epoch - 1ms/step
# Epoch 3/10
# 3980/3980 - 5s - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 7.7044e-04 - val_mean_squared_error: 7.7044e-04 - 5s/epoch - 1ms/step
# Epoch 4/10
# 3980/3980 - 5s - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - 5s/epoch - 1ms/step
# Epoch 5/10
# 3980/3980 - 5s - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 7.7640e-04 - val_mean_squared_error: 7.7640e-04 - 5s/epoch - 1ms/step
# Epoch 6/10
# 3980/3980 - 5s - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 7.8574e-04 - val_mean_squared_error: 7.8574e-04 - 5s/epoch - 1ms/step
# Epoch 7/10
# 3980/3980 - 5s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 8.5876e-04 - val_mean_squared_error: 8.5876e-04 - 5s/epoch - 1ms/step
# Epoch 8/10
# 3980/3980 - 5s - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 8.9974e-04 - val_mean_squared_error: 8.9974e-04 - 5s/epoch - 1ms/step
# Epoch 9/10
# 3980/3980 - 5s - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 9.4763e-04 - val_mean_squared_error: 9.4763e-04 - 5s/epoch - 1ms/step
# Epoch 10/10
# 3980/3980 - 5s - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 7.9989e-04 - val_mean_squared_error: 7.9989e-04 - 5s/epoch - 1ms/step
# 980/980 [==============================] - 1s 1ms/step - loss: 7.9989e-04 - mean_squared_error: 7.9989e-04
# mse with window 20 is 0.0007998942746780813
# 2023-05-13 14:52:47.023219: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,20]
# 	 [[{{node dense_4_input}}]]
# 2023-05-13 14:52:47.056919: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,20]
# 	 [[{{node dense_4_input}}]]
# 2023-05-13 14:52:47.070656: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:52:47.082317: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,20]
# 	 [[{{node dense_4_input}}]]
# 2023-05-13 14:52:47.091334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:52:47.102241: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,20]
# 	 [[{{node dense_4_input}}]]
# 2023-05-13 14:52:47.108903: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:52:47.116890: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,110]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:52:47.126252: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:52:47.136888: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:52:47.156589: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,20]
# 	 [[{{node dense_4_input}}]]
# 2023-05-13 14:52:47.171204: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:52:47.180282: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:52:47.264180: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-05-13 14:52:47.303021: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,110]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 2023-05-13 14:52:47.376407: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'serving_default_dense_4_input' with dtype float and shape [?,1,20]
# 	 [[{{node serving_default_dense_4_input}}]]
# INFO:tensorflow:Assets written to: keras_model_tdnn_20/assets
# INFO:tensorflow:Assets written to: keras_model_tdnn_20/assets

# %%
print(f'the best window size is {best_window}')
# Out:
# the best window size is 15

# %%
#prepare the data again, compatibly with the best window size found
trainX, trainY = get_XY(x_train, y_train, best_window)
validX, validY = get_XY(x_valid, y_valid, best_window)
testX, testY = get_XY(x_test, y_test, best_window)

#check shape
print(trainX.shape,trainY.shape)
# Out:
# (3985, 1, 15) (3985,)

# %% [markdown]
# To ultimate model selection, we find the optimal number of epochs

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = keras.models.load_model(f'keras_model_tdnn_{best_window}')
model.summary()
history = model.fit(trainX, trainY, epochs=50, batch_size=bs, verbose=2, validation_data = (validX, validY))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1, 70)             1120
#
#  dense_3 (Dense)             (None, 1, 1)              71
#
# =================================================================
# Total params: 1,191
# Trainable params: 1,191
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 3985/3985 - 5s - loss: 5.0104e-05 - mean_squared_error: 5.0104e-05 - val_loss: 4.1430e-05 - val_mean_squared_error: 4.1430e-05 - 5s/epoch - 1ms/step
# Epoch 2/50
# 3985/3985 - 5s - loss: 4.0417e-05 - mean_squared_error: 4.0417e-05 - val_loss: 4.9347e-05 - val_mean_squared_error: 4.9347e-05 - 5s/epoch - 1ms/step
# Epoch 3/50
# 3985/3985 - 5s - loss: 3.7025e-05 - mean_squared_error: 3.7025e-05 - val_loss: 3.2331e-05 - val_mean_squared_error: 3.2331e-05 - 5s/epoch - 1ms/step
# Epoch 4/50
# 3985/3985 - 5s - loss: 3.6266e-05 - mean_squared_error: 3.6266e-05 - val_loss: 2.7944e-05 - val_mean_squared_error: 2.7944e-05 - 5s/epoch - 1ms/step
# Epoch 5/50
# 3985/3985 - 5s - loss: 3.3705e-05 - mean_squared_error: 3.3705e-05 - val_loss: 1.9390e-05 - val_mean_squared_error: 1.9390e-05 - 5s/epoch - 1ms/step
# Epoch 6/50
# 3985/3985 - 5s - loss: 3.6017e-05 - mean_squared_error: 3.6017e-05 - val_loss: 1.6697e-05 - val_mean_squared_error: 1.6697e-05 - 5s/epoch - 1ms/step
# Epoch 7/50
# 3985/3985 - 5s - loss: 3.5390e-05 - mean_squared_error: 3.5390e-05 - val_loss: 2.4512e-05 - val_mean_squared_error: 2.4512e-05 - 5s/epoch - 1ms/step
# Epoch 8/50
# 3985/3985 - 5s - loss: 3.0617e-05 - mean_squared_error: 3.0617e-05 - val_loss: 2.8661e-05 - val_mean_squared_error: 2.8661e-05 - 5s/epoch - 1ms/step
# Epoch 9/50
# 3985/3985 - 5s - loss: 3.2402e-05 - mean_squared_error: 3.2402e-05 - val_loss: 1.7619e-05 - val_mean_squared_error: 1.7619e-05 - 5s/epoch - 1ms/step
# Epoch 10/50
# 3985/3985 - 5s - loss: 3.4440e-05 - mean_squared_error: 3.4440e-05 - val_loss: 5.4956e-05 - val_mean_squared_error: 5.4956e-05 - 5s/epoch - 1ms/step
# Epoch 11/50
# 3985/3985 - 5s - loss: 2.7327e-05 - mean_squared_error: 2.7327e-05 - val_loss: 2.0733e-05 - val_mean_squared_error: 2.0733e-05 - 5s/epoch - 1ms/step
# Epoch 12/50
# 3985/3985 - 5s - loss: 2.9830e-05 - mean_squared_error: 2.9830e-05 - val_loss: 5.0159e-05 - val_mean_squared_error: 5.0159e-05 - 5s/epoch - 1ms/step
# Epoch 13/50
# 3985/3985 - 5s - loss: 3.1174e-05 - mean_squared_error: 3.1174e-05 - val_loss: 2.6224e-05 - val_mean_squared_error: 2.6224e-05 - 5s/epoch - 1ms/step
# Epoch 14/50
# 3985/3985 - 5s - loss: 2.7594e-05 - mean_squared_error: 2.7594e-05 - val_loss: 1.2728e-05 - val_mean_squared_error: 1.2728e-05 - 5s/epoch - 1ms/step
# Epoch 15/50
# 3985/3985 - 6s - loss: 2.7908e-05 - mean_squared_error: 2.7908e-05 - val_loss: 2.2712e-05 - val_mean_squared_error: 2.2712e-05 - 6s/epoch - 1ms/step
# Epoch 16/50
# 3985/3985 - 7s - loss: 2.7016e-05 - mean_squared_error: 2.7016e-05 - val_loss: 6.7664e-05 - val_mean_squared_error: 6.7664e-05 - 7s/epoch - 2ms/step
# Epoch 17/50
# 3985/3985 - 6s - loss: 2.6923e-05 - mean_squared_error: 2.6923e-05 - val_loss: 4.5842e-05 - val_mean_squared_error: 4.5842e-05 - 6s/epoch - 1ms/step
# Epoch 18/50
# 3985/3985 - 5s - loss: 2.8120e-05 - mean_squared_error: 2.8120e-05 - val_loss: 2.7571e-05 - val_mean_squared_error: 2.7571e-05 - 5s/epoch - 1ms/step
# Epoch 19/50
# 3985/3985 - 5s - loss: 2.4521e-05 - mean_squared_error: 2.4521e-05 - val_loss: 1.4886e-05 - val_mean_squared_error: 1.4886e-05 - 5s/epoch - 1ms/step
# Epoch 20/50
# 3985/3985 - 5s - loss: 2.5234e-05 - mean_squared_error: 2.5234e-05 - val_loss: 9.1337e-05 - val_mean_squared_error: 9.1337e-05 - 5s/epoch - 1ms/step
# Epoch 21/50
# 3985/3985 - 5s - loss: 2.7417e-05 - mean_squared_error: 2.7417e-05 - val_loss: 1.8604e-05 - val_mean_squared_error: 1.8604e-05 - 5s/epoch - 1ms/step
# Epoch 22/50
# 3985/3985 - 5s - loss: 2.4287e-05 - mean_squared_error: 2.4287e-05 - val_loss: 1.3352e-05 - val_mean_squared_error: 1.3352e-05 - 5s/epoch - 1ms/step
# Epoch 23/50
# 3985/3985 - 5s - loss: 2.4464e-05 - mean_squared_error: 2.4464e-05 - val_loss: 1.1625e-05 - val_mean_squared_error: 1.1625e-05 - 5s/epoch - 1ms/step
# Epoch 24/50
# 3985/3985 - 5s - loss: 2.2674e-05 - mean_squared_error: 2.2674e-05 - val_loss: 1.6295e-05 - val_mean_squared_error: 1.6295e-05 - 5s/epoch - 1ms/step
# Epoch 25/50
# 3985/3985 - 6s - loss: 2.2086e-05 - mean_squared_error: 2.2086e-05 - val_loss: 1.0955e-05 - val_mean_squared_error: 1.0955e-05 - 6s/epoch - 1ms/step
# Epoch 26/50
# 3985/3985 - 5s - loss: 2.3079e-05 - mean_squared_error: 2.3079e-05 - val_loss: 1.7239e-05 - val_mean_squared_error: 1.7239e-05 - 5s/epoch - 1ms/step
# Epoch 27/50
# 3985/3985 - 5s - loss: 2.3754e-05 - mean_squared_error: 2.3754e-05 - val_loss: 1.9001e-05 - val_mean_squared_error: 1.9001e-05 - 5s/epoch - 1ms/step
# Epoch 28/50
# 3985/3985 - 5s - loss: 2.3013e-05 - mean_squared_error: 2.3013e-05 - val_loss: 1.4554e-05 - val_mean_squared_error: 1.4554e-05 - 5s/epoch - 1ms/step
# Epoch 29/50
# 3985/3985 - 5s - loss: 2.1891e-05 - mean_squared_error: 2.1891e-05 - val_loss: 1.7724e-05 - val_mean_squared_error: 1.7724e-05 - 5s/epoch - 1ms/step
# Epoch 30/50
# 3985/3985 - 5s - loss: 2.3312e-05 - mean_squared_error: 2.3312e-05 - val_loss: 1.7856e-05 - val_mean_squared_error: 1.7856e-05 - 5s/epoch - 1ms/step
# Epoch 31/50
# 3985/3985 - 5s - loss: 2.1439e-05 - mean_squared_error: 2.1439e-05 - val_loss: 1.2358e-05 - val_mean_squared_error: 1.2358e-05 - 5s/epoch - 1ms/step
# Epoch 32/50
# 3985/3985 - 5s - loss: 2.3270e-05 - mean_squared_error: 2.3270e-05 - val_loss: 2.6605e-05 - val_mean_squared_error: 2.6605e-05 - 5s/epoch - 1ms/step
# Epoch 33/50
# 3985/3985 - 5s - loss: 2.2453e-05 - mean_squared_error: 2.2453e-05 - val_loss: 1.2095e-05 - val_mean_squared_error: 1.2095e-05 - 5s/epoch - 1ms/step
# Epoch 34/50
# 3985/3985 - 5s - loss: 2.0031e-05 - mean_squared_error: 2.0031e-05 - val_loss: 1.2063e-05 - val_mean_squared_error: 1.2063e-05 - 5s/epoch - 1ms/step
# Epoch 35/50
# 3985/3985 - 5s - loss: 2.0982e-05 - mean_squared_error: 2.0982e-05 - val_loss: 9.4810e-06 - val_mean_squared_error: 9.4810e-06 - 5s/epoch - 1ms/step
# Epoch 36/50
# 3985/3985 - 5s - loss: 2.2212e-05 - mean_squared_error: 2.2212e-05 - val_loss: 2.4222e-05 - val_mean_squared_error: 2.4222e-05 - 5s/epoch - 1ms/step
# Epoch 37/50
# 3985/3985 - 6s - loss: 2.0946e-05 - mean_squared_error: 2.0946e-05 - val_loss: 9.6602e-06 - val_mean_squared_error: 9.6602e-06 - 6s/epoch - 2ms/step
# Epoch 38/50
# 3985/3985 - 6s - loss: 1.9793e-05 - mean_squared_error: 1.9793e-05 - val_loss: 9.0210e-05 - val_mean_squared_error: 9.0210e-05 - 6s/epoch - 2ms/step
# Epoch 39/50
# 3985/3985 - 6s - loss: 2.0648e-05 - mean_squared_error: 2.0648e-05 - val_loss: 2.2788e-05 - val_mean_squared_error: 2.2788e-05 - 6s/epoch - 2ms/step
# Epoch 40/50
# 3985/3985 - 7s - loss: 2.1167e-05 - mean_squared_error: 2.1167e-05 - val_loss: 1.2373e-05 - val_mean_squared_error: 1.2373e-05 - 7s/epoch - 2ms/step
# Epoch 41/50
# 3985/3985 - 6s - loss: 2.0646e-05 - mean_squared_error: 2.0646e-05 - val_loss: 1.2036e-05 - val_mean_squared_error: 1.2036e-05 - 6s/epoch - 2ms/step
# Epoch 42/50
# 3985/3985 - 5s - loss: 2.0895e-05 - mean_squared_error: 2.0895e-05 - val_loss: 3.3333e-05 - val_mean_squared_error: 3.3333e-05 - 5s/epoch - 1ms/step
# Epoch 43/50
# 3985/3985 - 6s - loss: 1.7484e-05 - mean_squared_error: 1.7484e-05 - val_loss: 2.5354e-05 - val_mean_squared_error: 2.5354e-05 - 6s/epoch - 1ms/step
# Epoch 44/50
# 3985/3985 - 6s - loss: 1.9462e-05 - mean_squared_error: 1.9462e-05 - val_loss: 1.1829e-05 - val_mean_squared_error: 1.1829e-05 - 6s/epoch - 2ms/step
# Epoch 45/50
# 3985/3985 - 5s - loss: 1.9507e-05 - mean_squared_error: 1.9507e-05 - val_loss: 2.7917e-05 - val_mean_squared_error: 2.7917e-05 - 5s/epoch - 1ms/step
# Epoch 46/50
# 3985/3985 - 6s - loss: 1.9272e-05 - mean_squared_error: 1.9272e-05 - val_loss: 1.3761e-05 - val_mean_squared_error: 1.3761e-05 - 6s/epoch - 1ms/step
# Epoch 47/50
# 3985/3985 - 5s - loss: 1.9474e-05 - mean_squared_error: 1.9474e-05 - val_loss: 1.3933e-05 - val_mean_squared_error: 1.3933e-05 - 5s/epoch - 1ms/step
# Epoch 48/50
# 3985/3985 - 5s - loss: 1.8998e-05 - mean_squared_error: 1.8998e-05 - val_loss: 2.0005e-05 - val_mean_squared_error: 2.0005e-05 - 5s/epoch - 1ms/step
# Epoch 49/50
# 3985/3985 - 6s - loss: 1.9903e-05 - mean_squared_error: 1.9903e-05 - val_loss: 1.0743e-05 - val_mean_squared_error: 1.0743e-05 - 6s/epoch - 1ms/step
# Epoch 50/50
# 3985/3985 - 5s - loss: 1.9036e-05 - mean_squared_error: 1.9036e-05 - val_loss: 1.0948e-05 - val_mean_squared_error: 1.0948e-05 - 5s/epoch - 1ms/step

# %% [markdown]
# Find best epoch:

# %%
val_mse_per_epoch = history.history['val_mean_squared_error']
best_epoch = val_mse_per_epoch.index(min(val_mse_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 35

# %% [markdown]
# # END OF MODEL SELECTION

# %% [markdown]
# Re-instantiate the hypermodel and train it with the optimal number of epochs from above.

# %%
hypermodel = keras.models.load_model(f'keras_model_tdnn_{best_window}')

# %%
# Retrain the model
history = hypermodel.fit(trainX, trainY, epochs=best_epoch, batch_size=bs, verbose=2, validation_data = (validX, validY)).history
# Out:
# Epoch 1/35
# 3985/3985 - 6s - loss: 4.6940e-05 - mean_squared_error: 4.6940e-05 - val_loss: 3.1458e-05 - val_mean_squared_error: 3.1458e-05 - 6s/epoch - 1ms/step
# Epoch 2/35
# 3985/3985 - 6s - loss: 4.0849e-05 - mean_squared_error: 4.0849e-05 - val_loss: 1.0219e-04 - val_mean_squared_error: 1.0219e-04 - 6s/epoch - 1ms/step
# Epoch 3/35
# 3985/3985 - 5s - loss: 4.0575e-05 - mean_squared_error: 4.0575e-05 - val_loss: 3.8637e-05 - val_mean_squared_error: 3.8637e-05 - 5s/epoch - 1ms/step
# Epoch 4/35
# 3985/3985 - 7s - loss: 3.7500e-05 - mean_squared_error: 3.7500e-05 - val_loss: 2.1150e-05 - val_mean_squared_error: 2.1150e-05 - 7s/epoch - 2ms/step
# Epoch 5/35
# 3985/3985 - 5s - loss: 3.6445e-05 - mean_squared_error: 3.6445e-05 - val_loss: 1.6660e-05 - val_mean_squared_error: 1.6660e-05 - 5s/epoch - 1ms/step
# Epoch 6/35
# 3985/3985 - 5s - loss: 3.7205e-05 - mean_squared_error: 3.7205e-05 - val_loss: 3.4197e-05 - val_mean_squared_error: 3.4197e-05 - 5s/epoch - 1ms/step
# Epoch 7/35
# 3985/3985 - 6s - loss: 3.0352e-05 - mean_squared_error: 3.0352e-05 - val_loss: 4.5182e-05 - val_mean_squared_error: 4.5182e-05 - 6s/epoch - 1ms/step
# Epoch 8/35
# 3985/3985 - 6s - loss: 3.2510e-05 - mean_squared_error: 3.2510e-05 - val_loss: 2.7749e-05 - val_mean_squared_error: 2.7749e-05 - 6s/epoch - 1ms/step
# Epoch 9/35
# 3985/3985 - 6s - loss: 3.1553e-05 - mean_squared_error: 3.1553e-05 - val_loss: 6.6944e-05 - val_mean_squared_error: 6.6944e-05 - 6s/epoch - 1ms/step
# Epoch 10/35
# 3985/3985 - 6s - loss: 3.1338e-05 - mean_squared_error: 3.1338e-05 - val_loss: 2.1229e-05 - val_mean_squared_error: 2.1229e-05 - 6s/epoch - 1ms/step
# Epoch 11/35
# 3985/3985 - 6s - loss: 2.9615e-05 - mean_squared_error: 2.9615e-05 - val_loss: 2.3302e-05 - val_mean_squared_error: 2.3302e-05 - 6s/epoch - 1ms/step
# Epoch 12/35
# 3985/3985 - 5s - loss: 2.8444e-05 - mean_squared_error: 2.8444e-05 - val_loss: 1.8995e-05 - val_mean_squared_error: 1.8995e-05 - 5s/epoch - 1ms/step
# Epoch 13/35
# 3985/3985 - 5s - loss: 2.8592e-05 - mean_squared_error: 2.8592e-05 - val_loss: 2.8427e-05 - val_mean_squared_error: 2.8427e-05 - 5s/epoch - 1ms/step
# Epoch 14/35
# 3985/3985 - 5s - loss: 2.8673e-05 - mean_squared_error: 2.8673e-05 - val_loss: 2.5477e-05 - val_mean_squared_error: 2.5477e-05 - 5s/epoch - 1ms/step
# Epoch 15/35
# 3985/3985 - 6s - loss: 2.6449e-05 - mean_squared_error: 2.6449e-05 - val_loss: 1.6245e-05 - val_mean_squared_error: 1.6245e-05 - 6s/epoch - 1ms/step
# Epoch 16/35
# 3985/3985 - 5s - loss: 2.8922e-05 - mean_squared_error: 2.8922e-05 - val_loss: 6.9006e-05 - val_mean_squared_error: 6.9006e-05 - 5s/epoch - 1ms/step
# Epoch 17/35
# 3985/3985 - 5s - loss: 2.6839e-05 - mean_squared_error: 2.6839e-05 - val_loss: 2.4683e-05 - val_mean_squared_error: 2.4683e-05 - 5s/epoch - 1ms/step
# Epoch 18/35
# 3985/3985 - 6s - loss: 3.0550e-05 - mean_squared_error: 3.0550e-05 - val_loss: 2.6464e-05 - val_mean_squared_error: 2.6464e-05 - 6s/epoch - 1ms/step
# Epoch 19/35
# 3985/3985 - 6s - loss: 2.3801e-05 - mean_squared_error: 2.3801e-05 - val_loss: 1.3394e-05 - val_mean_squared_error: 1.3394e-05 - 6s/epoch - 2ms/step
# Epoch 20/35
# 3985/3985 - 5s - loss: 2.5865e-05 - mean_squared_error: 2.5865e-05 - val_loss: 4.0753e-05 - val_mean_squared_error: 4.0753e-05 - 5s/epoch - 1ms/step
# Epoch 21/35
# 3985/3985 - 5s - loss: 2.4532e-05 - mean_squared_error: 2.4532e-05 - val_loss: 1.3562e-05 - val_mean_squared_error: 1.3562e-05 - 5s/epoch - 1ms/step
# Epoch 22/35
# 3985/3985 - 5s - loss: 2.6147e-05 - mean_squared_error: 2.6147e-05 - val_loss: 3.4238e-05 - val_mean_squared_error: 3.4238e-05 - 5s/epoch - 1ms/step
# Epoch 23/35
# 3985/3985 - 5s - loss: 2.3748e-05 - mean_squared_error: 2.3748e-05 - val_loss: 2.0906e-05 - val_mean_squared_error: 2.0906e-05 - 5s/epoch - 1ms/step
# Epoch 24/35
# 3985/3985 - 5s - loss: 2.4164e-05 - mean_squared_error: 2.4164e-05 - val_loss: 1.9069e-05 - val_mean_squared_error: 1.9069e-05 - 5s/epoch - 1ms/step
# Epoch 25/35
# 3985/3985 - 5s - loss: 2.4126e-05 - mean_squared_error: 2.4126e-05 - val_loss: 1.5261e-05 - val_mean_squared_error: 1.5261e-05 - 5s/epoch - 1ms/step
# Epoch 26/35
# 3985/3985 - 7s - loss: 2.1490e-05 - mean_squared_error: 2.1490e-05 - val_loss: 3.4125e-05 - val_mean_squared_error: 3.4125e-05 - 7s/epoch - 2ms/step
# Epoch 27/35
# 3985/3985 - 5s - loss: 2.3195e-05 - mean_squared_error: 2.3195e-05 - val_loss: 4.3833e-05 - val_mean_squared_error: 4.3833e-05 - 5s/epoch - 1ms/step
# Epoch 28/35
# 3985/3985 - 6s - loss: 2.2026e-05 - mean_squared_error: 2.2026e-05 - val_loss: 1.9461e-05 - val_mean_squared_error: 1.9461e-05 - 6s/epoch - 2ms/step
# Epoch 29/35
# 3985/3985 - 5s - loss: 2.2780e-05 - mean_squared_error: 2.2780e-05 - val_loss: 1.7668e-05 - val_mean_squared_error: 1.7668e-05 - 5s/epoch - 1ms/step
# Epoch 30/35
# 3985/3985 - 5s - loss: 2.3993e-05 - mean_squared_error: 2.3993e-05 - val_loss: 2.2347e-05 - val_mean_squared_error: 2.2347e-05 - 5s/epoch - 1ms/step
# Epoch 31/35
# 3985/3985 - 5s - loss: 2.1743e-05 - mean_squared_error: 2.1743e-05 - val_loss: 1.2851e-05 - val_mean_squared_error: 1.2851e-05 - 5s/epoch - 1ms/step
# Epoch 32/35
# 3985/3985 - 5s - loss: 2.1796e-05 - mean_squared_error: 2.1796e-05 - val_loss: 1.2882e-05 - val_mean_squared_error: 1.2882e-05 - 5s/epoch - 1ms/step
# Epoch 33/35
# 3985/3985 - 5s - loss: 2.0975e-05 - mean_squared_error: 2.0975e-05 - val_loss: 1.1566e-05 - val_mean_squared_error: 1.1566e-05 - 5s/epoch - 1ms/step
# Epoch 34/35
# 3985/3985 - 5s - loss: 2.5121e-05 - mean_squared_error: 2.5121e-05 - val_loss: 2.3400e-05 - val_mean_squared_error: 2.3400e-05 - 5s/epoch - 1ms/step
# Epoch 35/35
# 3985/3985 - 5s - loss: 2.2075e-05 - mean_squared_error: 2.2075e-05 - val_loss: 5.3405e-05 - val_mean_squared_error: 5.3405e-05 - 5s/epoch - 1ms/step

# %% [markdown]
# ### Make plots of the loss and validation loss

# %%
history_plot(history,best_window)

# %% [markdown]
# Save history data

# %%
hist_df = pd.DataFrame(history) 
# save to json:  
hist_json_file = 'history_tdnn.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %% [markdown]
# To load history data use:

# %%
#history = pd.read_json('history_tdnn.json')

# %% [markdown]
# Save the final model

# %%
hypermodel.save(f'keras_model_tdnn')
# Out:
# 2023-05-13 15:00:31.642545: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,15]
# 	 [[{{node dense_2_input}}]]
# 2023-05-13 15:00:31.673160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,15]
# 	 [[{{node dense_2_input}}]]
# 2023-05-13 15:00:31.686484: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 15:00:31.696958: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,15]
# 	 [[{{node dense_2_input}}]]
# 2023-05-13 15:00:31.705989: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 15:00:31.716765: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,15]
# 	 [[{{node dense_2_input}}]]
# 2023-05-13 15:00:31.723226: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 15:00:31.731837: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,70]
# 	 [[{{node inputs}}]]
# 2023-05-13 15:00:31.742099: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 15:00:31.752708: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 15:00:31.775250: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,15]
# 	 [[{{node dense_2_input}}]]
# 2023-05-13 15:00:31.791754: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 15:00:31.802771: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 15:00:31.908891: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,15]
# 	 [[{{node inputs}}]]
# 2023-05-13 15:00:31.936869: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,70]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 2023-05-13 15:00:31.998132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'serving_default_dense_2_input' with dtype float and shape [?,1,15]
# 	 [[{{node serving_default_dense_2_input}}]]
# INFO:tensorflow:Assets written to: keras_model_tdnn/assets
# INFO:tensorflow:Assets written to: keras_model_tdnn/assets

# %% [markdown]
# Command to (eventually) load the saved model:

# %%
#hypermodel = keras.models.load_model('keras_model_tdnn')

# %% [markdown]
# # Plots of target and output signals over time (of the best model)

# %%
#training
y = hypermodel.predict(trainX)
mse = hypermodel.evaluate(trainX, trainY, batch_size=bs)[0]
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'training - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,trainY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('training (first 200 timesteps)')
plt.plot(t[:200],y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t[:200],trainY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig(f"plots/tdnn_training.pdf")

#validation
y = hypermodel.predict(validX)
mse = hypermodel.evaluate(validX, validY, batch_size=bs)[0]
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'validation - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,validY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('validation (first 200 timesteps)')
plt.plot(t[:200],y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t[:200],validY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig(f"plots/tdnn_validation.pdf")

#test
y = hypermodel.predict(testX)
mse = hypermodel.evaluate(testX, testY, batch_size=bs)[0]
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'test - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,testY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('test (first 200 timesteps)')
plt.plot(t[:200],y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t[:200],testY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig(f"plots/tdnn_test.pdf")
# Out:
# 125/125 [==============================] - 0s 1ms/step
# 3985/3985 [==============================] - 5s 1ms/step - loss: 5.2663e-05 - mean_squared_error: 5.2663e-05
# 31/31 [==============================] - 0s 1ms/step
# 985/985 [==============================] - 1s 1ms/step - loss: 5.3405e-05 - mean_squared_error: 5.3405e-05
# 156/156 [==============================] - 0s 1ms/step
# 4985/4985 [==============================] - 7s 1ms/step - loss: 5.1779e-05 - mean_squared_error: 5.1779e-05
