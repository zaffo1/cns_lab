# %% [markdown]
# # Assignment 1: NARMA10 task
# ## TDNN
# Note: as a reference for keras tuner I used the documentation: https://www.tensorflow.org/tutorials/keras/keras_tuner

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
import keras_tuner as kt
from keras import backend as K
import pandas as pd

# %% [markdown]
# # [Load final Results]

# %%
#manually trained hyperparameters (number of epochs, window size)
best_epoch, best_window = np.load('hyperparameters_best_epoch_best_window.npy', allow_pickle=True)
print(f'Number of epochs: {best_epoch}\nBest window size: {best_window}')
#best model
final_model = keras.models.load_model('keras_model_tdnn')
history = final_model.history
#history variable
history = pd.read_json('history_tdnn.json')
#errors 
errors = np.load('errors_tdnn.npy')
print(f'\nTraining MSE = {errors[0]} \nValidation MSE = {errors[1]} \nTest MSE = {errors[2]}')
# Out:
# Number of epochs: 47
# Best window size: 20
#
# Training MSE = 1.9681212506839074e-05
# Validation MSE = 2.2403337425203063e-05
# Test MSE = 2.2071802959544584e-05

# %% [markdown]
# function to reshape the dataset to feed the tdnn

# %%
# Prepare the input X and target Y in order to implement the tdnn
def get_XY(x, y, window):
    # Remove the first "window" elements from y array
    Y = y[window:]
    # X will be an array containing "len(Y)" arrays created using the sliding window
    X = []
    rows_x = len(Y)
    j = 0
    for i in range(rows_x):
        X = np.append(X,x[j:j+window])
        j = j + 1

    #reshape X so it can be fed to the Dense layer
    X =  np.reshape(X, (rows_x, 1, window)) 
    return X, Y

# %% [markdown]
# function to plot the learning history

# %%
def history_plot(history,window):
    plt.figure(figsize = (15,5))

    plt.subplot(121)
    plt.plot(history['loss'])
    plt.title(f'Loss (window:{window})')
    plt.xlabel('Epochs')
    plt.ylabel('MSE')
    #plt.yscale('log')

    plt.subplot(122)
    plt.plot(history['val_loss'])
    plt.title(f'Validation Loss (window:{window})')
    plt.xlabel('Epochs')
    plt.ylabel('MSE')
    #plt.yscale('log')
    plt.tight_layout()

    plt.savefig(f"plots/tdnn_loss_{window}.pdf")
    plt.show()

# %% [markdown]
# ### Load the dataset

# %%
#load the data
x, y = np.loadtxt("NARMA10.csv", delimiter=",")


#split the dataset into training, validation and test
x_train = x[:4000]
x_valid = x[4000:5000] #validation
x_test = x[5000:]

y_train = y[:4000]
y_valid = y[4000:5000]
y_test = y[5000:]

#plot the data
plt.figure(figsize = (25,7))
ax1 = plt.subplot(211)
plt.title('Input', fontsize=18)
ax1.plot(x, color = 'b', linewidth= 0.2)
ax1.axvline(x = 4000, color = 'black', linestyle= '--')
ax1.axvline(x = 5000, color = 'black', linestyle= '--')

ax2 = plt.subplot(212, sharex = ax1)
plt.title('Target', fontsize=18)
ax2.plot(y, color = 'r', linewidth = 0.2)
ax2.axvline(x = 4000, color = 'black', linestyle= '--')
ax2.axvline(x = 5000, color = 'black', linestyle= '--')
plt.xlabel('Timesteps', fontsize=14)
plt.tight_layout()

# %% [markdown]
# batch size:

# %%
#batch size 
bs = 1

# %% [markdown]
# # MODEL SELECTION
# In order to do model selection, I proceed in part using keras tuner, and in part manually.
# In fact, with keras tuner it was not possible to set the window size as an hyperparameter, because changing thew window size means changing the dataset structure.
# To solve this problem, i created a for cycle to handle the model selection for the window size, and inside the cycle I use keras tuner to tune the other hyperparameters, i.e:
# - number of units of hidden layer
# - learning rate for the optimizer
# - activation function for the hidden layer
# - activation function for the dense layer

# %%
#size of the window we use to buffer the input
windows = [10,20,15] #window sizes to investigate

mse_min = 1e3 #initialize to a high value
for window_size in windows:
    print(f'\n WINDOW SIZE: {window_size} \n')

    #Prepare the dataset to feed the tdnn, accordingly to the selected window size:
    trainX, trainY = get_XY(x_train, y_train, window_size)
    validX, validY = get_XY(x_valid, y_valid, window_size)
    testX, testY = get_XY(x_test, y_test, window_size)

    #Create the model
    #To do model selection, we actually create the "hypermodel",
    #defining the hyperparameter search space as well as the architecture of the model.

    def model_architecture(hidden_units, activation_h, activation_d, lr):
        model = Sequential()
        input_shape = (1, window_size) 
        model.add(Dense(units=hidden_units,input_shape=input_shape, activation=activation_h))
        model.add(Dense(units=1, activation=activation_d))
        model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=lr),metrics=['mean_squared_error'])
        return model

    def create_model(hp):

        # Tune the number of units in the first Dense layer
        # Choose an optimal value between 50-150
        hidden_units = hp.Int('units',  min_value=50, max_value=150, step=10)

        #Tune the activation function of the hidden layer
        activation_h = hp.Choice("activation_h", ["linear","relu", "tanh"])
        #Tune the activation function of the last layer
        activation_d = hp.Choice("activation_d", ["linear","relu"])
        # Tune the learning rate for the optimizer
        lr = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])


        # call model-building code with the hyperparameter values.
        model = model_architecture(
            hidden_units=hidden_units, activation_d=activation_d, activation_h=activation_h, lr=lr
        )
        return model


    # Instantiate hyperparameter tuner
    # use random search to find optimal hyperparameters
    tuner = kt.RandomSearch(
                        hypermodel = create_model,
                        objective='val_mean_squared_error',
                        max_trials=20,
                        #overwrite=True,
                        directory='tuner',
                        project_name=f'tuner_tdnn_{window_size}'
                        )

    tuner.search_space_summary()


    #Create a callback to stop training early after reaching a certain value for the validation loss.
    stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)


    tuner.search(trainX, trainY, epochs=8, batch_size=bs, validation_data = (validX, validY), callbacks=[stop_early])
    # Get the optimal hyperparameters
    best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

    print(f"""
    Completed hyperparameters search for window size: {window_size}.\n
    Otimal number of units of hidden layer = {best_hps.get('units')} \n
    Optimal learning rate for the optimizer = {best_hps.get('learning_rate')} \n
    Optimal activation function for the hidden layer = {best_hps.get('activation_h')} \n
    Optimal activation function for the dense layer = {best_hps.get('activation_d')}
    """)
        
    #instantiate the model
    window_model = tuner.hypermodel.build(best_hps)
    window_model.summary()
    window_model.fit(trainX, trainY, epochs=10, batch_size=bs, verbose=2, validation_data = (validX, validY))
    mse = window_model.evaluate(validX, validY, batch_size=bs)[0]
    print(f'\n mse with window {window_size} is {mse} \n') 
    #window_model.save(f'keras_model_tdnn_{window_size}')
    if mse < mse_min:
        mse_min = mse
        best_window = window_size
        final_hps = best_hps
# Out:
#  WINDOW SIZE: 10
#
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_10/tuner0.json
# Search space summary
# Default search space size: 4
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 50, 'max_value': 150, 'step': 10, 'sampling': 'linear'}
# activation_h (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu', 'tanh'], 'ordered': False}
# activation_d (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu'], 'ordered': False}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# INFO:tensorflow:Oracle triggered exit
#
#     Completed hyperparameters search for window size: 10.
#
#     Otimal number of units of hidden layer = 110
#
#     Optimal learning rate for the optimizer = 0.001
#
#     Optimal activation function for the hidden layer = relu
#
#     Optimal activation function for the dense layer = relu
#
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 1, 110)            1210
#
#  dense_15 (Dense)            (None, 1, 1)              111
#
# =================================================================
# Total params: 1,321
# Trainable params: 1,321
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3990/3990 - 6s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 9.8853e-04 - val_mean_squared_error: 9.8853e-04 - 6s/epoch - 1ms/step
# Epoch 2/10
# 3990/3990 - 5s - loss: 7.0711e-04 - mean_squared_error: 7.0711e-04 - val_loss: 8.7608e-04 - val_mean_squared_error: 8.7608e-04 - 5s/epoch - 1ms/step
# Epoch 3/10
# 3990/3990 - 5s - loss: 6.3711e-04 - mean_squared_error: 6.3711e-04 - val_loss: 5.1608e-04 - val_mean_squared_error: 5.1608e-04 - 5s/epoch - 1ms/step
# Epoch 4/10
# 3990/3990 - 5s - loss: 5.9685e-04 - mean_squared_error: 5.9685e-04 - val_loss: 7.2077e-04 - val_mean_squared_error: 7.2077e-04 - 5s/epoch - 1ms/step
# Epoch 5/10
# 3990/3990 - 6s - loss: 5.4693e-04 - mean_squared_error: 5.4693e-04 - val_loss: 6.6743e-04 - val_mean_squared_error: 6.6743e-04 - 6s/epoch - 2ms/step
# Epoch 6/10
# 3990/3990 - 6s - loss: 5.3753e-04 - mean_squared_error: 5.3753e-04 - val_loss: 6.5102e-04 - val_mean_squared_error: 6.5102e-04 - 6s/epoch - 2ms/step
# Epoch 7/10
# 3990/3990 - 6s - loss: 5.1261e-04 - mean_squared_error: 5.1261e-04 - val_loss: 5.7681e-04 - val_mean_squared_error: 5.7681e-04 - 6s/epoch - 2ms/step
# Epoch 8/10
# 3990/3990 - 5s - loss: 5.1329e-04 - mean_squared_error: 5.1329e-04 - val_loss: 9.1394e-04 - val_mean_squared_error: 9.1394e-04 - 5s/epoch - 1ms/step
# Epoch 9/10
# 3990/3990 - 5s - loss: 5.1418e-04 - mean_squared_error: 5.1418e-04 - val_loss: 4.5866e-04 - val_mean_squared_error: 4.5866e-04 - 5s/epoch - 1ms/step
# Epoch 10/10
# 3990/3990 - 5s - loss: 4.9834e-04 - mean_squared_error: 4.9834e-04 - val_loss: 4.4475e-04 - val_mean_squared_error: 4.4475e-04 - 5s/epoch - 1ms/step
# 990/990 [==============================] - 1s 1ms/step - loss: 4.4475e-04 - mean_squared_error: 4.4475e-04
#
#  mse with window 10 is 0.00044475210597738624
#
#
#  WINDOW SIZE: 20
#
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_20/tuner0.json
# Search space summary
# Default search space size: 4
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 50, 'max_value': 150, 'step': 10, 'sampling': 'linear'}
# activation_h (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu', 'tanh'], 'ordered': False}
# activation_d (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu'], 'ordered': False}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# INFO:tensorflow:Oracle triggered exit
#
#     Completed hyperparameters search for window size: 20.
#
#     Otimal number of units of hidden layer = 80
#
#     Optimal learning rate for the optimizer = 0.001
#
#     Optimal activation function for the hidden layer = relu
#
#     Optimal activation function for the dense layer = relu
#
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 1, 80)             1680
#
#  dense_17 (Dense)            (None, 1, 1)              81
#
# =================================================================
# Total params: 1,761
# Trainable params: 1,761
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3980/3980 - 6s - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 4.8688e-04 - val_mean_squared_error: 4.8688e-04 - 6s/epoch - 1ms/step
# Epoch 2/10
# 3980/3980 - 5s - loss: 3.8906e-04 - mean_squared_error: 3.8906e-04 - val_loss: 2.4121e-04 - val_mean_squared_error: 2.4121e-04 - 5s/epoch - 1ms/step
# Epoch 3/10
# 3980/3980 - 6s - loss: 2.5376e-04 - mean_squared_error: 2.5376e-04 - val_loss: 2.2553e-04 - val_mean_squared_error: 2.2553e-04 - 6s/epoch - 1ms/step
# Epoch 4/10
# 3980/3980 - 6s - loss: 1.6111e-04 - mean_squared_error: 1.6111e-04 - val_loss: 1.6480e-04 - val_mean_squared_error: 1.6480e-04 - 6s/epoch - 2ms/step
# Epoch 5/10
# 3980/3980 - 5s - loss: 1.2441e-04 - mean_squared_error: 1.2441e-04 - val_loss: 9.5791e-05 - val_mean_squared_error: 9.5791e-05 - 5s/epoch - 1ms/step
# Epoch 6/10
# 3980/3980 - 5s - loss: 1.0288e-04 - mean_squared_error: 1.0288e-04 - val_loss: 5.8277e-05 - val_mean_squared_error: 5.8277e-05 - 5s/epoch - 1ms/step
# Epoch 7/10
# 3980/3980 - 5s - loss: 8.8938e-05 - mean_squared_error: 8.8938e-05 - val_loss: 1.4814e-04 - val_mean_squared_error: 1.4814e-04 - 5s/epoch - 1ms/step
# Epoch 8/10
# 3980/3980 - 5s - loss: 8.0005e-05 - mean_squared_error: 8.0005e-05 - val_loss: 5.5374e-05 - val_mean_squared_error: 5.5374e-05 - 5s/epoch - 1ms/step
# Epoch 9/10
# 3980/3980 - 5s - loss: 7.1151e-05 - mean_squared_error: 7.1151e-05 - val_loss: 4.9582e-05 - val_mean_squared_error: 4.9582e-05 - 5s/epoch - 1ms/step
# Epoch 10/10
# 3980/3980 - 5s - loss: 6.5591e-05 - mean_squared_error: 6.5591e-05 - val_loss: 4.1539e-05 - val_mean_squared_error: 4.1539e-05 - 5s/epoch - 1ms/step
# 980/980 [==============================] - 1s 1ms/step - loss: 4.1539e-05 - mean_squared_error: 4.1539e-05
#
#  mse with window 20 is 4.1538809455232695e-05
#
#
#  WINDOW SIZE: 15
#
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn_15/tuner0.json
# Search space summary
# Default search space size: 4
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 50, 'max_value': 150, 'step': 10, 'sampling': 'linear'}
# activation_h (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu', 'tanh'], 'ordered': False}
# activation_d (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu'], 'ordered': False}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# INFO:tensorflow:Oracle triggered exit
#
#     Completed hyperparameters search for window size: 15.
#
#     Otimal number of units of hidden layer = 80
#
#     Optimal learning rate for the optimizer = 0.01
#
#     Optimal activation function for the hidden layer = relu
#
#     Optimal activation function for the dense layer = relu
#
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 1, 80)             1280
#
#  dense_19 (Dense)            (None, 1, 1)              81
#
# =================================================================
# Total params: 1,361
# Trainable params: 1,361
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3985/3985 - 6s - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 4.4438e-04 - val_mean_squared_error: 4.4438e-04 - 6s/epoch - 2ms/step
# Epoch 2/10
# 3985/3985 - 5s - loss: 5.5344e-04 - mean_squared_error: 5.5344e-04 - val_loss: 3.7651e-04 - val_mean_squared_error: 3.7651e-04 - 5s/epoch - 1ms/step
# Epoch 3/10
# 3985/3985 - 5s - loss: 5.9262e-04 - mean_squared_error: 5.9262e-04 - val_loss: 4.9628e-04 - val_mean_squared_error: 4.9628e-04 - 5s/epoch - 1ms/step
# Epoch 4/10
# 3985/3985 - 5s - loss: 5.4240e-04 - mean_squared_error: 5.4240e-04 - val_loss: 8.1776e-04 - val_mean_squared_error: 8.1776e-04 - 5s/epoch - 1ms/step
# Epoch 5/10
# 3985/3985 - 5s - loss: 4.8337e-04 - mean_squared_error: 4.8337e-04 - val_loss: 2.8103e-04 - val_mean_squared_error: 2.8103e-04 - 5s/epoch - 1ms/step
# Epoch 6/10
# 3985/3985 - 5s - loss: 5.0678e-04 - mean_squared_error: 5.0678e-04 - val_loss: 7.7381e-04 - val_mean_squared_error: 7.7381e-04 - 5s/epoch - 1ms/step
# Epoch 7/10
# 3985/3985 - 5s - loss: 5.1618e-04 - mean_squared_error: 5.1618e-04 - val_loss: 4.9166e-04 - val_mean_squared_error: 4.9166e-04 - 5s/epoch - 1ms/step
# Epoch 8/10
# 3985/3985 - 5s - loss: 5.0490e-04 - mean_squared_error: 5.0490e-04 - val_loss: 2.6643e-04 - val_mean_squared_error: 2.6643e-04 - 5s/epoch - 1ms/step
# Epoch 9/10
# 3985/3985 - 5s - loss: 5.0563e-04 - mean_squared_error: 5.0563e-04 - val_loss: 6.1459e-04 - val_mean_squared_error: 6.1459e-04 - 5s/epoch - 1ms/step
# Epoch 10/10
# 3985/3985 - 5s - loss: 5.3073e-04 - mean_squared_error: 5.3073e-04 - val_loss: 5.3002e-04 - val_mean_squared_error: 5.3002e-04 - 5s/epoch - 1ms/step
# 985/985 [==============================] - 1s 1ms/step - loss: 5.3002e-04 - mean_squared_error: 5.3002e-04
#
#  mse with window 15 is 0.0005300218472257257

# %%
print(f'The best window size is {best_window}')
# Out:
# The best window size is 20

# %% [markdown]
# ### Reinstantiate the model with the best window size

# %%
def model_architecture(hidden_units, activation_h, activation_d, lr):
    model = Sequential()
    input_shape = (1, best_window) 
    model.add(Dense(units=hidden_units,input_shape=input_shape, activation=activation_h))
    model.add(Dense(units=1, activation=activation_d))
    model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=lr),metrics=['mean_squared_error'])
    return model
# Out:
# '\n\ndef create_model(hp):\n\n    # Tune the number of units in the first Dense layer\n    # Choose an optimal value between 50-150\n    hidden_units = hp.Int(\'units\',  min_value=50, max_value=150, step=10)\n\n    #Tune the activation function of the hidden layer\n    activation_h = hp.Choice("activation_h", ["linear","relu", "tanh"])\n    #Tune the activation function of the last layer\n    activation_d = hp.Choice("activation_d", ["linear","relu"])\n    # Tune the learning rate for the optimizer\n    lr = hp.Choice(\'learning_rate\', values=[1e-2, 1e-3, 1e-4])\n\n\n    # call model-building code with the hyperparameter values.\n    model = model_architecture(\n        hidden_units=hidden_units, activation_d=activation_d, activation_h=activation_h, lr=lr\n    )\n    return model\n'

# %%
#prepare the data again, compatibly with the best window size found
trainX, trainY = get_XY(x_train, y_train, best_window)
validX, validY = get_XY(x_valid, y_valid, best_window)
testX, testY = get_XY(x_test, y_test, best_window)

#check shape
print(trainX.shape,trainY.shape)
# Out:
# (3980, 1, 20) (3980,)

# %% [markdown]
# To ultimate model selection, we find the optimal number of epochs

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
#model = keras.models.load_model(f'keras_model_tdnn_{best_window}')
model = tuner.hypermodel.build(final_hps)
model.summary()
history = model.fit(trainX, trainY, epochs=50, batch_size=bs, verbose=2, validation_data = (validX, validY))
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 1, 80)             1680
#
#  dense_21 (Dense)            (None, 1, 1)              81
#
# =================================================================
# Total params: 1,761
# Trainable params: 1,761
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 3980/3980 - 5s - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - 5s/epoch - 1ms/step
# Epoch 2/50
# 3980/3980 - 5s - loss: 4.1087e-04 - mean_squared_error: 4.1087e-04 - val_loss: 4.1761e-04 - val_mean_squared_error: 4.1761e-04 - 5s/epoch - 1ms/step
# Epoch 3/50
# 3980/3980 - 5s - loss: 2.3376e-04 - mean_squared_error: 2.3376e-04 - val_loss: 2.1766e-04 - val_mean_squared_error: 2.1766e-04 - 5s/epoch - 1ms/step
# Epoch 4/50
# 3980/3980 - 5s - loss: 1.5481e-04 - mean_squared_error: 1.5481e-04 - val_loss: 1.0327e-04 - val_mean_squared_error: 1.0327e-04 - 5s/epoch - 1ms/step
# Epoch 5/50
# 3980/3980 - 5s - loss: 1.2500e-04 - mean_squared_error: 1.2500e-04 - val_loss: 8.6697e-05 - val_mean_squared_error: 8.6697e-05 - 5s/epoch - 1ms/step
# Epoch 6/50
# 3980/3980 - 5s - loss: 1.0484e-04 - mean_squared_error: 1.0484e-04 - val_loss: 5.7957e-05 - val_mean_squared_error: 5.7957e-05 - 5s/epoch - 1ms/step
# Epoch 7/50
# 3980/3980 - 5s - loss: 8.4232e-05 - mean_squared_error: 8.4232e-05 - val_loss: 5.6488e-05 - val_mean_squared_error: 5.6488e-05 - 5s/epoch - 1ms/step
# Epoch 8/50
# 3980/3980 - 5s - loss: 7.5116e-05 - mean_squared_error: 7.5116e-05 - val_loss: 1.0980e-04 - val_mean_squared_error: 1.0980e-04 - 5s/epoch - 1ms/step
# Epoch 9/50
# 3980/3980 - 5s - loss: 7.3788e-05 - mean_squared_error: 7.3788e-05 - val_loss: 6.9941e-05 - val_mean_squared_error: 6.9941e-05 - 5s/epoch - 1ms/step
# Epoch 10/50
# 3980/3980 - 6s - loss: 6.1277e-05 - mean_squared_error: 6.1277e-05 - val_loss: 4.4586e-05 - val_mean_squared_error: 4.4586e-05 - 6s/epoch - 1ms/step
# Epoch 11/50
# 3980/3980 - 6s - loss: 5.7477e-05 - mean_squared_error: 5.7477e-05 - val_loss: 6.1521e-05 - val_mean_squared_error: 6.1521e-05 - 6s/epoch - 1ms/step
# Epoch 12/50
# 3980/3980 - 6s - loss: 4.7572e-05 - mean_squared_error: 4.7572e-05 - val_loss: 4.4623e-05 - val_mean_squared_error: 4.4623e-05 - 6s/epoch - 1ms/step
# Epoch 13/50
# 3980/3980 - 5s - loss: 4.7673e-05 - mean_squared_error: 4.7673e-05 - val_loss: 3.3327e-05 - val_mean_squared_error: 3.3327e-05 - 5s/epoch - 1ms/step
# Epoch 14/50
# 3980/3980 - 5s - loss: 4.4028e-05 - mean_squared_error: 4.4028e-05 - val_loss: 2.7274e-05 - val_mean_squared_error: 2.7274e-05 - 5s/epoch - 1ms/step
# Epoch 15/50
# 3980/3980 - 5s - loss: 4.1169e-05 - mean_squared_error: 4.1169e-05 - val_loss: 7.6242e-05 - val_mean_squared_error: 7.6242e-05 - 5s/epoch - 1ms/step
# Epoch 16/50
# 3980/3980 - 5s - loss: 4.0049e-05 - mean_squared_error: 4.0049e-05 - val_loss: 2.9499e-05 - val_mean_squared_error: 2.9499e-05 - 5s/epoch - 1ms/step
# Epoch 17/50
# 3980/3980 - 5s - loss: 3.8892e-05 - mean_squared_error: 3.8892e-05 - val_loss: 2.2573e-05 - val_mean_squared_error: 2.2573e-05 - 5s/epoch - 1ms/step
# Epoch 18/50
# 3980/3980 - 5s - loss: 3.3258e-05 - mean_squared_error: 3.3258e-05 - val_loss: 1.8339e-05 - val_mean_squared_error: 1.8339e-05 - 5s/epoch - 1ms/step
# Epoch 19/50
# 3980/3980 - 5s - loss: 3.5629e-05 - mean_squared_error: 3.5629e-05 - val_loss: 1.1191e-04 - val_mean_squared_error: 1.1191e-04 - 5s/epoch - 1ms/step
# Epoch 20/50
# 3980/3980 - 5s - loss: 3.4880e-05 - mean_squared_error: 3.4880e-05 - val_loss: 5.0161e-05 - val_mean_squared_error: 5.0161e-05 - 5s/epoch - 1ms/step
# Epoch 21/50
# 3980/3980 - 5s - loss: 3.4354e-05 - mean_squared_error: 3.4354e-05 - val_loss: 3.0127e-05 - val_mean_squared_error: 3.0127e-05 - 5s/epoch - 1ms/step
# Epoch 22/50
# 3980/3980 - 5s - loss: 3.3417e-05 - mean_squared_error: 3.3417e-05 - val_loss: 4.1188e-05 - val_mean_squared_error: 4.1188e-05 - 5s/epoch - 1ms/step
# Epoch 23/50
# 3980/3980 - 5s - loss: 3.4679e-05 - mean_squared_error: 3.4679e-05 - val_loss: 2.8065e-05 - val_mean_squared_error: 2.8065e-05 - 5s/epoch - 1ms/step
# Epoch 24/50
# 3980/3980 - 5s - loss: 3.2054e-05 - mean_squared_error: 3.2054e-05 - val_loss: 1.6872e-05 - val_mean_squared_error: 1.6872e-05 - 5s/epoch - 1ms/step
# Epoch 25/50
# 3980/3980 - 5s - loss: 3.2069e-05 - mean_squared_error: 3.2069e-05 - val_loss: 2.1150e-05 - val_mean_squared_error: 2.1150e-05 - 5s/epoch - 1ms/step
# Epoch 26/50
# 3980/3980 - 5s - loss: 3.0789e-05 - mean_squared_error: 3.0789e-05 - val_loss: 1.4790e-05 - val_mean_squared_error: 1.4790e-05 - 5s/epoch - 1ms/step
# Epoch 27/50
# 3980/3980 - 5s - loss: 3.0878e-05 - mean_squared_error: 3.0878e-05 - val_loss: 1.4662e-05 - val_mean_squared_error: 1.4662e-05 - 5s/epoch - 1ms/step
# Epoch 28/50
# 3980/3980 - 5s - loss: 3.1926e-05 - mean_squared_error: 3.1926e-05 - val_loss: 1.8974e-05 - val_mean_squared_error: 1.8974e-05 - 5s/epoch - 1ms/step
# Epoch 29/50
# 3980/3980 - 5s - loss: 2.9208e-05 - mean_squared_error: 2.9208e-05 - val_loss: 1.8063e-05 - val_mean_squared_error: 1.8063e-05 - 5s/epoch - 1ms/step
# Epoch 30/50
# 3980/3980 - 5s - loss: 2.8650e-05 - mean_squared_error: 2.8650e-05 - val_loss: 2.0573e-05 - val_mean_squared_error: 2.0573e-05 - 5s/epoch - 1ms/step
# Epoch 31/50
# 3980/3980 - 5s - loss: 2.8129e-05 - mean_squared_error: 2.8129e-05 - val_loss: 2.1544e-05 - val_mean_squared_error: 2.1544e-05 - 5s/epoch - 1ms/step
# Epoch 32/50
# 3980/3980 - 5s - loss: 2.9652e-05 - mean_squared_error: 2.9652e-05 - val_loss: 1.4870e-05 - val_mean_squared_error: 1.4870e-05 - 5s/epoch - 1ms/step
# Epoch 33/50
# 3980/3980 - 5s - loss: 2.9490e-05 - mean_squared_error: 2.9490e-05 - val_loss: 2.0401e-05 - val_mean_squared_error: 2.0401e-05 - 5s/epoch - 1ms/step
# Epoch 34/50
# 3980/3980 - 5s - loss: 2.6113e-05 - mean_squared_error: 2.6113e-05 - val_loss: 1.2637e-05 - val_mean_squared_error: 1.2637e-05 - 5s/epoch - 1ms/step
# Epoch 35/50
# 3980/3980 - 5s - loss: 3.1942e-05 - mean_squared_error: 3.1942e-05 - val_loss: 2.1090e-05 - val_mean_squared_error: 2.1090e-05 - 5s/epoch - 1ms/step
# Epoch 36/50
# 3980/3980 - 5s - loss: 2.6561e-05 - mean_squared_error: 2.6561e-05 - val_loss: 4.0959e-05 - val_mean_squared_error: 4.0959e-05 - 5s/epoch - 1ms/step
# Epoch 37/50
# 3980/3980 - 6s - loss: 2.8330e-05 - mean_squared_error: 2.8330e-05 - val_loss: 3.5554e-05 - val_mean_squared_error: 3.5554e-05 - 6s/epoch - 1ms/step
# Epoch 38/50
# 3980/3980 - 5s - loss: 2.7407e-05 - mean_squared_error: 2.7407e-05 - val_loss: 1.4986e-05 - val_mean_squared_error: 1.4986e-05 - 5s/epoch - 1ms/step
# Epoch 39/50
# 3980/3980 - 5s - loss: 2.5903e-05 - mean_squared_error: 2.5903e-05 - val_loss: 5.1307e-05 - val_mean_squared_error: 5.1307e-05 - 5s/epoch - 1ms/step
# Epoch 40/50
# 3980/3980 - 5s - loss: 2.8129e-05 - mean_squared_error: 2.8129e-05 - val_loss: 2.7157e-05 - val_mean_squared_error: 2.7157e-05 - 5s/epoch - 1ms/step
# Epoch 41/50
# 3980/3980 - 5s - loss: 2.7091e-05 - mean_squared_error: 2.7091e-05 - val_loss: 1.6227e-05 - val_mean_squared_error: 1.6227e-05 - 5s/epoch - 1ms/step
# Epoch 42/50
# 3980/3980 - 5s - loss: 2.6313e-05 - mean_squared_error: 2.6313e-05 - val_loss: 2.2790e-05 - val_mean_squared_error: 2.2790e-05 - 5s/epoch - 1ms/step
# Epoch 43/50
# 3980/3980 - 5s - loss: 2.7701e-05 - mean_squared_error: 2.7701e-05 - val_loss: 3.4235e-05 - val_mean_squared_error: 3.4235e-05 - 5s/epoch - 1ms/step
# Epoch 44/50
# 3980/3980 - 5s - loss: 2.4666e-05 - mean_squared_error: 2.4666e-05 - val_loss: 1.2665e-05 - val_mean_squared_error: 1.2665e-05 - 5s/epoch - 1ms/step
# Epoch 45/50
# 3980/3980 - 5s - loss: 2.5779e-05 - mean_squared_error: 2.5779e-05 - val_loss: 1.1691e-05 - val_mean_squared_error: 1.1691e-05 - 5s/epoch - 1ms/step
# Epoch 46/50
# 3980/3980 - 5s - loss: 2.5247e-05 - mean_squared_error: 2.5247e-05 - val_loss: 2.1151e-05 - val_mean_squared_error: 2.1151e-05 - 5s/epoch - 1ms/step
# Epoch 47/50
# 3980/3980 - 5s - loss: 2.2358e-05 - mean_squared_error: 2.2358e-05 - val_loss: 6.1099e-05 - val_mean_squared_error: 6.1099e-05 - 5s/epoch - 1ms/step
# Epoch 48/50
# 3980/3980 - 5s - loss: 2.2919e-05 - mean_squared_error: 2.2919e-05 - val_loss: 2.8280e-05 - val_mean_squared_error: 2.8280e-05 - 5s/epoch - 1ms/step
# Epoch 49/50
# 3980/3980 - 5s - loss: 2.4747e-05 - mean_squared_error: 2.4747e-05 - val_loss: 1.8970e-05 - val_mean_squared_error: 1.8970e-05 - 5s/epoch - 1ms/step
# Epoch 50/50
# 3980/3980 - 5s - loss: 2.2684e-05 - mean_squared_error: 2.2684e-05 - val_loss: 1.7749e-05 - val_mean_squared_error: 1.7749e-05 - 5s/epoch - 1ms/step

# %% [markdown]
# Find best epoch:

# %%
val_mse_per_epoch = history.history['val_mean_squared_error']
best_epoch = val_mse_per_epoch.index(min(val_mse_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 45

# %% [markdown]
# save into a file the values found for best number of epochs and best window size

# %%
hp = np.array([best_epoch, best_window])
np.save('hyperparameters_best_epoch_best_window',hp, allow_pickle=True)

# %% [markdown]
# # END OF MODEL SELECTION

# %% [markdown]
# to load the best values found for number of epochs and window size:

# %%
#best_epoch, best_window = np.load('hyperparameters_best_epoch_best_window.npy', allow_pickle=True)

# %% [markdown]
# Re-instantiate the hypermodel and train it with the optimal number of epochs from above.

# %%
final_model = tuner.hypermodel.build(final_hps)

# %%
# Retrain the model
history = final_model.fit(trainX, trainY, epochs=best_epoch, batch_size=bs, verbose=2, validation_data = (validX, validY)).history
# Out:
# Epoch 1/45
# 3980/3980 - 5s - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - 5s/epoch - 1ms/step
# Epoch 2/45
# 3980/3980 - 5s - loss: 4.1993e-04 - mean_squared_error: 4.1993e-04 - val_loss: 1.9989e-04 - val_mean_squared_error: 1.9989e-04 - 5s/epoch - 1ms/step
# Epoch 3/45
# 3980/3980 - 5s - loss: 2.4497e-04 - mean_squared_error: 2.4497e-04 - val_loss: 2.8545e-04 - val_mean_squared_error: 2.8545e-04 - 5s/epoch - 1ms/step
# Epoch 4/45
# 3980/3980 - 5s - loss: 1.7060e-04 - mean_squared_error: 1.7060e-04 - val_loss: 1.0202e-04 - val_mean_squared_error: 1.0202e-04 - 5s/epoch - 1ms/step
# Epoch 5/45
# 3980/3980 - 5s - loss: 1.2225e-04 - mean_squared_error: 1.2225e-04 - val_loss: 2.3899e-04 - val_mean_squared_error: 2.3899e-04 - 5s/epoch - 1ms/step
# Epoch 6/45
# 3980/3980 - 5s - loss: 1.0408e-04 - mean_squared_error: 1.0408e-04 - val_loss: 9.0477e-05 - val_mean_squared_error: 9.0477e-05 - 5s/epoch - 1ms/step
# Epoch 7/45
# 3980/3980 - 5s - loss: 8.9023e-05 - mean_squared_error: 8.9023e-05 - val_loss: 5.2351e-05 - val_mean_squared_error: 5.2351e-05 - 5s/epoch - 1ms/step
# Epoch 8/45
# 3980/3980 - 5s - loss: 7.7228e-05 - mean_squared_error: 7.7228e-05 - val_loss: 1.5188e-04 - val_mean_squared_error: 1.5188e-04 - 5s/epoch - 1ms/step
# Epoch 9/45
# 3980/3980 - 5s - loss: 6.8744e-05 - mean_squared_error: 6.8744e-05 - val_loss: 1.4180e-04 - val_mean_squared_error: 1.4180e-04 - 5s/epoch - 1ms/step
# Epoch 10/45
# 3980/3980 - 5s - loss: 6.8867e-05 - mean_squared_error: 6.8867e-05 - val_loss: 3.6132e-05 - val_mean_squared_error: 3.6132e-05 - 5s/epoch - 1ms/step
# Epoch 11/45
# 3980/3980 - 5s - loss: 5.7852e-05 - mean_squared_error: 5.7852e-05 - val_loss: 7.2585e-05 - val_mean_squared_error: 7.2585e-05 - 5s/epoch - 1ms/step
# Epoch 12/45
# 3980/3980 - 5s - loss: 5.7000e-05 - mean_squared_error: 5.7000e-05 - val_loss: 6.1305e-05 - val_mean_squared_error: 6.1305e-05 - 5s/epoch - 1ms/step
# Epoch 13/45
# 3980/3980 - 5s - loss: 5.2429e-05 - mean_squared_error: 5.2429e-05 - val_loss: 4.7010e-05 - val_mean_squared_error: 4.7010e-05 - 5s/epoch - 1ms/step
# Epoch 14/45
# 3980/3980 - 5s - loss: 5.0704e-05 - mean_squared_error: 5.0704e-05 - val_loss: 3.7106e-05 - val_mean_squared_error: 3.7106e-05 - 5s/epoch - 1ms/step
# Epoch 15/45
# 3980/3980 - 5s - loss: 5.2264e-05 - mean_squared_error: 5.2264e-05 - val_loss: 3.3247e-05 - val_mean_squared_error: 3.3247e-05 - 5s/epoch - 1ms/step
# Epoch 16/45
# 3980/3980 - 5s - loss: 4.4970e-05 - mean_squared_error: 4.4970e-05 - val_loss: 2.5756e-05 - val_mean_squared_error: 2.5756e-05 - 5s/epoch - 1ms/step
# Epoch 17/45
# 3980/3980 - 5s - loss: 4.4091e-05 - mean_squared_error: 4.4091e-05 - val_loss: 3.4678e-05 - val_mean_squared_error: 3.4678e-05 - 5s/epoch - 1ms/step
# Epoch 18/45
# 3980/3980 - 5s - loss: 4.4473e-05 - mean_squared_error: 4.4473e-05 - val_loss: 2.8338e-05 - val_mean_squared_error: 2.8338e-05 - 5s/epoch - 1ms/step
# Epoch 19/45
# 3980/3980 - 5s - loss: 4.4072e-05 - mean_squared_error: 4.4072e-05 - val_loss: 2.1020e-05 - val_mean_squared_error: 2.1020e-05 - 5s/epoch - 1ms/step
# Epoch 20/45
# 3980/3980 - 5s - loss: 4.0924e-05 - mean_squared_error: 4.0924e-05 - val_loss: 9.2897e-05 - val_mean_squared_error: 9.2897e-05 - 5s/epoch - 1ms/step
# Epoch 21/45
# 3980/3980 - 5s - loss: 4.1579e-05 - mean_squared_error: 4.1579e-05 - val_loss: 3.3167e-05 - val_mean_squared_error: 3.3167e-05 - 5s/epoch - 1ms/step
# Epoch 22/45
# 3980/3980 - 5s - loss: 3.9992e-05 - mean_squared_error: 3.9992e-05 - val_loss: 2.3458e-05 - val_mean_squared_error: 2.3458e-05 - 5s/epoch - 1ms/step
# Epoch 23/45
# 3980/3980 - 5s - loss: 4.2855e-05 - mean_squared_error: 4.2855e-05 - val_loss: 2.2006e-05 - val_mean_squared_error: 2.2006e-05 - 5s/epoch - 1ms/step
# Epoch 24/45
# 3980/3980 - 5s - loss: 3.9116e-05 - mean_squared_error: 3.9116e-05 - val_loss: 4.0455e-05 - val_mean_squared_error: 4.0455e-05 - 5s/epoch - 1ms/step
# Epoch 25/45
# 3980/3980 - 5s - loss: 3.8088e-05 - mean_squared_error: 3.8088e-05 - val_loss: 5.7487e-05 - val_mean_squared_error: 5.7487e-05 - 5s/epoch - 1ms/step
# Epoch 26/45
# 3980/3980 - 5s - loss: 3.6353e-05 - mean_squared_error: 3.6353e-05 - val_loss: 3.0361e-05 - val_mean_squared_error: 3.0361e-05 - 5s/epoch - 1ms/step
# Epoch 27/45
# 3980/3980 - 5s - loss: 3.9732e-05 - mean_squared_error: 3.9732e-05 - val_loss: 3.3696e-05 - val_mean_squared_error: 3.3696e-05 - 5s/epoch - 1ms/step
# Epoch 28/45
# 3980/3980 - 5s - loss: 3.4897e-05 - mean_squared_error: 3.4897e-05 - val_loss: 2.6394e-05 - val_mean_squared_error: 2.6394e-05 - 5s/epoch - 1ms/step
# Epoch 29/45
# 3980/3980 - 5s - loss: 3.4758e-05 - mean_squared_error: 3.4758e-05 - val_loss: 2.4425e-05 - val_mean_squared_error: 2.4425e-05 - 5s/epoch - 1ms/step
# Epoch 30/45
# 3980/3980 - 5s - loss: 3.2576e-05 - mean_squared_error: 3.2576e-05 - val_loss: 4.2376e-05 - val_mean_squared_error: 4.2376e-05 - 5s/epoch - 1ms/step
# Epoch 31/45
# 3980/3980 - 5s - loss: 3.3937e-05 - mean_squared_error: 3.3937e-05 - val_loss: 6.1709e-05 - val_mean_squared_error: 6.1709e-05 - 5s/epoch - 1ms/step
# Epoch 32/45
# 3980/3980 - 5s - loss: 3.0700e-05 - mean_squared_error: 3.0700e-05 - val_loss: 2.4093e-05 - val_mean_squared_error: 2.4093e-05 - 5s/epoch - 1ms/step
# Epoch 33/45
# 3980/3980 - 5s - loss: 3.1389e-05 - mean_squared_error: 3.1389e-05 - val_loss: 2.5029e-05 - val_mean_squared_error: 2.5029e-05 - 5s/epoch - 1ms/step
# Epoch 34/45
# 3980/3980 - 5s - loss: 2.9898e-05 - mean_squared_error: 2.9898e-05 - val_loss: 1.6475e-05 - val_mean_squared_error: 1.6475e-05 - 5s/epoch - 1ms/step
# Epoch 35/45
# 3980/3980 - 5s - loss: 3.0766e-05 - mean_squared_error: 3.0766e-05 - val_loss: 2.3139e-05 - val_mean_squared_error: 2.3139e-05 - 5s/epoch - 1ms/step
# Epoch 36/45
# 3980/3980 - 5s - loss: 2.8086e-05 - mean_squared_error: 2.8086e-05 - val_loss: 3.3779e-05 - val_mean_squared_error: 3.3779e-05 - 5s/epoch - 1ms/step
# Epoch 37/45
# 3980/3980 - 6s - loss: 2.9790e-05 - mean_squared_error: 2.9790e-05 - val_loss: 2.0960e-05 - val_mean_squared_error: 2.0960e-05 - 6s/epoch - 1ms/step
# Epoch 38/45
# 3980/3980 - 6s - loss: 2.6860e-05 - mean_squared_error: 2.6860e-05 - val_loss: 1.7579e-05 - val_mean_squared_error: 1.7579e-05 - 6s/epoch - 1ms/step
# Epoch 39/45
# 3980/3980 - 5s - loss: 2.8195e-05 - mean_squared_error: 2.8195e-05 - val_loss: 4.8692e-05 - val_mean_squared_error: 4.8692e-05 - 5s/epoch - 1ms/step
# Epoch 40/45
# 3980/3980 - 6s - loss: 2.5933e-05 - mean_squared_error: 2.5933e-05 - val_loss: 1.5018e-05 - val_mean_squared_error: 1.5018e-05 - 6s/epoch - 2ms/step
# Epoch 41/45
# 3980/3980 - 6s - loss: 2.5195e-05 - mean_squared_error: 2.5195e-05 - val_loss: 1.4134e-05 - val_mean_squared_error: 1.4134e-05 - 6s/epoch - 2ms/step
# Epoch 42/45
# 3980/3980 - 6s - loss: 2.6910e-05 - mean_squared_error: 2.6910e-05 - val_loss: 3.1920e-05 - val_mean_squared_error: 3.1920e-05 - 6s/epoch - 1ms/step
# Epoch 43/45
# 3980/3980 - 5s - loss: 2.5775e-05 - mean_squared_error: 2.5775e-05 - val_loss: 2.0236e-05 - val_mean_squared_error: 2.0236e-05 - 5s/epoch - 1ms/step
# Epoch 44/45
# 3980/3980 - 5s - loss: 2.6656e-05 - mean_squared_error: 2.6656e-05 - val_loss: 1.9101e-05 - val_mean_squared_error: 1.9101e-05 - 5s/epoch - 1ms/step
# Epoch 45/45
# 3980/3980 - 5s - loss: 2.8111e-05 - mean_squared_error: 2.8111e-05 - val_loss: 1.1684e-05 - val_mean_squared_error: 1.1684e-05 - 5s/epoch - 1ms/step

# %% [markdown]
# ### Make plots of the loss and validation loss

# %%
history_plot(history,best_window)

# %% [markdown]
# Save history data

# %%
hist_df = pd.DataFrame(history) 
# save to json:  
hist_json_file = 'history_RNN.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %% [markdown]
# To load history data use:

# %%
#history = np.load('history_tdnn.npy')

# %% [markdown]
# Save the final model

# %%
final_model.save(f'keras_model_tdnn')
# Out:
# 2023-06-02 18:57:46.098617: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_22_input' with dtype float and shape [?,1,20]
# 	 [[{{node dense_22_input}}]]
# 2023-06-02 18:57:46.128243: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_22_input' with dtype float and shape [?,1,20]
# 	 [[{{node dense_22_input}}]]
# 2023-06-02 18:57:46.141228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-06-02 18:57:46.154461: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_22_input' with dtype float and shape [?,1,20]
# 	 [[{{node dense_22_input}}]]
# 2023-06-02 18:57:46.168725: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-06-02 18:57:46.181689: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_22_input' with dtype float and shape [?,1,20]
# 	 [[{{node dense_22_input}}]]
# 2023-06-02 18:57:46.191143: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-06-02 18:57:46.200483: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,80]
# 	 [[{{node inputs}}]]
# 2023-06-02 18:57:46.211449: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-06-02 18:57:46.222210: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-06-02 18:57:46.274649: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_22_input' with dtype float and shape [?,1,20]
# 	 [[{{node dense_22_input}}]]
# 2023-06-02 18:57:46.290163: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-06-02 18:57:46.299149: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-06-02 18:57:46.385905: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,20]
# 	 [[{{node inputs}}]]
# 2023-06-02 18:57:46.410171: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,80]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 2023-06-02 18:57:46.465791: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'serving_default_dense_22_input' with dtype float and shape [?,1,20]
# 	 [[{{node serving_default_dense_22_input}}]]
# INFO:tensorflow:Assets written to: keras_model_tdnn/assets
# INFO:tensorflow:Assets written to: keras_model_tdnn/assets

# %% [markdown]
# Command to (eventually) load the saved model:

# %%
#final_model = keras.models.load_model('keras_model_tdnn')

# %% [markdown]
# # Plots of target and output signals over time (of the best model)

# %%
#training
errors = []

y = final_model.predict(trainX)
mse = final_model.evaluate(trainX, trainY, batch_size=bs)[0]
errors.append(mse)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'training - MSE = {mse:e}')
plt.plot(y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(trainY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('training (first 200 timesteps)')
plt.plot(y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(trainY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig(f"plots/tdnn_training.pdf")

#validation
y = final_model.predict(validX)
mse = final_model.evaluate(validX, validY, batch_size=bs)[0]
errors.append(mse)
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'validation - MSE = {mse:e}')
plt.plot(y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(validY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('validation (first 200 timesteps)')
plt.plot(y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(validY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig(f"plots/tdnn_validation.pdf")

#test
y = final_model.predict(testX)
mse = final_model.evaluate(testX, testY, batch_size=bs)[0]
errors.append(mse)

t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'test - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,testY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('test (first 200 timesteps)')
plt.plot(y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(testY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig(f"plots/tdnn_test.pdf")


np.save('errors_tdnn',errors)
print(f'Training MSE = {errors[0]} \nValidation MSE = {errors[1]} \nTest MSE = {errors[2]}')
# Out:
# 125/125 [==============================] - 0s 1ms/step
# 3980/3980 [==============================] - 5s 1ms/step - loss: 1.0746e-05 - mean_squared_error: 1.0746e-05
# 31/31 [==============================] - 0s 1ms/step
# 980/980 [==============================] - 1s 1ms/step - loss: 1.1684e-05 - mean_squared_error: 1.1684e-05
# 156/156 [==============================] - 0s 2ms/step
# 4980/4980 [==============================] - 6s 1ms/step - loss: 1.1819e-05 - mean_squared_error: 1.1819e-05
# Training MSE = 1.0745613508333918e-05
# Validation MSE = 1.1684370292641688e-05
# Test MSE = 1.1818874554592185e-05
