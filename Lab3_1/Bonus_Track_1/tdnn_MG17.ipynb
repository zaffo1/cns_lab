# %% [markdown]
# # Bonus-track Assignment 1: Mackey-Glass 17 task
# ## RNN
# Note: as a reference for keras tuner I used the documentation: https://www.tensorflow.org/tutorials/keras/keras_tuner

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
import keras_tuner as kt

# %% [markdown]
# ### Load the dataset

# %%
#load the data
data = np.loadtxt("MG17.csv", delimiter=",")

#organize input and target 
x = data[:-1]
y = data[1:]
print(data)
# Out:
# [ 0.032164  0.040426  0.057861 ... -0.19556  -0.1368   -0.082192]

# %%
#split the dataset into training, validation and test
x_train = x[:4000]
x_valid = x[4000:5000] #validation
x_test = x[5000:]

y_train = y[:4000]
y_valid = y[4000:5000]
y_test = y[5000:]

#plot the data
t=np.arange(start=0,stop=len(x), step=1)
plt.figure(figsize = (25,7))
ax1 = plt.subplot(211)
plt.title('Input', fontsize=18)
ax1.plot(t,x, color = 'b', linewidth= 0.5)
ax1.axvline(x = 4000, color = 'black', linestyle= '--')
ax1.axvline(x = 5000, color = 'black', linestyle= '--')

ax2 = plt.subplot(212, sharex = ax1)
plt.title('Target', fontsize=18)
ax2.plot(t,y, color = 'r', linewidth = 0.5)
ax2.axvline(x = 4000, color = 'black', linestyle= '--')
ax2.axvline(x = 5000, color = 'black', linestyle= '--')
plt.xlabel('Timesteps', fontsize=14)
plt.tight_layout()

# %%
#size of the window we use to buffer the input
window_size = 17 #fix this value at 10 since we know it's the optimal value from theory

# %% [markdown]
# Prepare the dataset to implement the tdnn:

# %%
# Prepare the input X and target Y in order to implement the tdnn
def get_XY(x, y, window):
    # Remove the first "window" elements from y array
    Y = y[window:]
    # X will be an array containing "len(Y)" arrays created using the sliding window
    X = []
    rows_x = len(Y)
    j = 0
    for i in range(rows_x):
        X = np.append(X,x[j:j+window])
        j = j + 1

    #reshape X so it can be fed to the Dense layer
    X =  np.reshape(X, (rows_x, 1, window)) 
    return X, Y 


#prepare the data
trainX, trainY = get_XY(x_train, y_train, window_size)
validX, validY = get_XY(x_valid, y_valid, window_size)
testX, testY = get_XY(x_test, y_test, window_size)

#check shape
print(trainX.shape,trainY.shape)
# Out:
# (3983, 1, 17) (3983,)

# %% [markdown]
# ### Create the model
# To do model selection, we actually create the "hypermodel", defining the hyperparameter search space as well as the architecture of the model.

# %%
def model_architecture(hidden_units, activation_h, activation_d, lr):
    model = Sequential()
    input_shape = (1, window_size) 
    model.add(Dense(units=hidden_units,input_shape=input_shape, activation=activation_h))
    model.add(Dense(units=1, activation=activation_d))
    model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=lr),metrics=['mean_squared_error'])
    return model


def create_model(hp):

    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 10-250
    hidden_units = hp.Int('units',  min_value=10, max_value=250, step=10)

    #Tune the activation function of the hidden layer
    activation_h = hp.Choice("activation_h", ["linear","relu", "tanh"])
    #Tune the activation function of the last layer
    activation_d = hp.Choice("activation_d", ["linear","relu"])

    # Tune the learning rate for the optimizer
    lr = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])


    # call model-building code with the hyperparameter values.
    model = model_architecture(
        hidden_units=hidden_units, activation_d=activation_d, activation_h=activation_h, lr=lr
    )
    return model

# %% [markdown]
# Instantiate hyperparameter tuner

# %%
# use random search to find optimal hyperparameters
tuner = kt.RandomSearch(
                     hypermodel =create_model,
                     objective='val_mean_squared_error',
                     max_trials=25,
                     overwrite=True,
                     directory='tuner',
                     project_name='tuner_tdnn'
                     )

tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 10, 'max_value': 250, 'step': 10, 'sampling': 'linear'}
# activation_h (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu', 'tanh'], 'ordered': False}
# activation_d (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu'], 'ordered': False}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %% [markdown]
# Create a callback to stop training early after reaching a certain value for the validation loss.

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(trainX, trainY, epochs=20, batch_size=1, validation_data = (validX, validY), callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
Completed hyperparameters search.\n
Otimal number of units of hidden layer = {best_hps.get('units')} \n
Optimal learning rate for the optimizer = {best_hps.get('learning_rate')} \n
Optimal activation function for the hidden layer = {best_hps.get('activation_h')} \n
Optimal activation function for the dense layer = {best_hps.get('activation_d')}
""")
# Out:
# Trial 25 Complete [00h 00m 31s]
# val_mean_squared_error: 0.05136428400874138
#
# Best val_mean_squared_error So Far: 2.3141926703829085e-06
# Total elapsed time: 00h 42m 05s
# INFO:tensorflow:Oracle triggered exit
#
# Completed hyperparameters search.
#
# Otimal number of units of hidden layer = 90
#
# Optimal learning rate for the optimizer = 0.0001
#
# Optimal activation function for the hidden layer = relu
#
# Optimal activation function for the dense layer = linear

# %% [markdown]
# Find the optimal number of epochs

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
model.summary()
history = model.fit(trainX, trainY, epochs=50, batch_size=1, verbose=2, validation_data = (validX, validY))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1, 90)             1620
#
#  dense_3 (Dense)             (None, 1, 1)              91
#
# =================================================================
# Total params: 1,711
# Trainable params: 1,711
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 3983/3983 - 6s - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 4.8544e-04 - val_mean_squared_error: 4.8544e-04 - 6s/epoch - 1ms/step
# Epoch 2/50
# 3983/3983 - 5s - loss: 2.2212e-04 - mean_squared_error: 2.2212e-04 - val_loss: 1.0811e-04 - val_mean_squared_error: 1.0811e-04 - 5s/epoch - 1ms/step
# Epoch 3/50
# 3983/3983 - 5s - loss: 6.4999e-05 - mean_squared_error: 6.4999e-05 - val_loss: 5.8956e-05 - val_mean_squared_error: 5.8956e-05 - 5s/epoch - 1ms/step
# Epoch 4/50
# 3983/3983 - 5s - loss: 3.3669e-05 - mean_squared_error: 3.3669e-05 - val_loss: 5.1811e-05 - val_mean_squared_error: 5.1811e-05 - 5s/epoch - 1ms/step
# Epoch 5/50
# 3983/3983 - 5s - loss: 2.1730e-05 - mean_squared_error: 2.1730e-05 - val_loss: 2.3281e-05 - val_mean_squared_error: 2.3281e-05 - 5s/epoch - 1ms/step
# Epoch 6/50
# 3983/3983 - 5s - loss: 1.6047e-05 - mean_squared_error: 1.6047e-05 - val_loss: 1.7941e-05 - val_mean_squared_error: 1.7941e-05 - 5s/epoch - 1ms/step
# Epoch 7/50
# 3983/3983 - 5s - loss: 1.2366e-05 - mean_squared_error: 1.2366e-05 - val_loss: 3.5038e-05 - val_mean_squared_error: 3.5038e-05 - 5s/epoch - 1ms/step
# Epoch 8/50
# 3983/3983 - 5s - loss: 1.2337e-05 - mean_squared_error: 1.2337e-05 - val_loss: 1.2113e-05 - val_mean_squared_error: 1.2113e-05 - 5s/epoch - 1ms/step
# Epoch 9/50
# 3983/3983 - 5s - loss: 1.0331e-05 - mean_squared_error: 1.0331e-05 - val_loss: 4.8892e-05 - val_mean_squared_error: 4.8892e-05 - 5s/epoch - 1ms/step
# Epoch 10/50
# 3983/3983 - 5s - loss: 9.9146e-06 - mean_squared_error: 9.9146e-06 - val_loss: 5.5945e-06 - val_mean_squared_error: 5.5945e-06 - 5s/epoch - 1ms/step
# Epoch 11/50
# 3983/3983 - 5s - loss: 1.0460e-05 - mean_squared_error: 1.0460e-05 - val_loss: 2.1128e-05 - val_mean_squared_error: 2.1128e-05 - 5s/epoch - 1ms/step
# Epoch 12/50
# 3983/3983 - 5s - loss: 7.5918e-06 - mean_squared_error: 7.5918e-06 - val_loss: 7.0800e-06 - val_mean_squared_error: 7.0800e-06 - 5s/epoch - 1ms/step
# Epoch 13/50
# 3983/3983 - 7s - loss: 9.2633e-06 - mean_squared_error: 9.2633e-06 - val_loss: 3.1633e-06 - val_mean_squared_error: 3.1633e-06 - 7s/epoch - 2ms/step
# Epoch 14/50
# 3983/3983 - 6s - loss: 7.5398e-06 - mean_squared_error: 7.5398e-06 - val_loss: 6.7175e-05 - val_mean_squared_error: 6.7175e-05 - 6s/epoch - 1ms/step
# Epoch 15/50
# 3983/3983 - 6s - loss: 8.1475e-06 - mean_squared_error: 8.1475e-06 - val_loss: 1.3439e-05 - val_mean_squared_error: 1.3439e-05 - 6s/epoch - 1ms/step
# Epoch 16/50
# 3983/3983 - 5s - loss: 7.3083e-06 - mean_squared_error: 7.3083e-06 - val_loss: 3.1607e-06 - val_mean_squared_error: 3.1607e-06 - 5s/epoch - 1ms/step
# Epoch 17/50
# 3983/3983 - 5s - loss: 7.3541e-06 - mean_squared_error: 7.3541e-06 - val_loss: 4.1405e-06 - val_mean_squared_error: 4.1405e-06 - 5s/epoch - 1ms/step
# Epoch 18/50
# 3983/3983 - 5s - loss: 7.2076e-06 - mean_squared_error: 7.2076e-06 - val_loss: 7.9360e-06 - val_mean_squared_error: 7.9360e-06 - 5s/epoch - 1ms/step
# Epoch 19/50
# 3983/3983 - 5s - loss: 6.3967e-06 - mean_squared_error: 6.3967e-06 - val_loss: 2.8786e-06 - val_mean_squared_error: 2.8786e-06 - 5s/epoch - 1ms/step
# Epoch 20/50
# 3983/3983 - 5s - loss: 6.3009e-06 - mean_squared_error: 6.3009e-06 - val_loss: 7.8378e-06 - val_mean_squared_error: 7.8378e-06 - 5s/epoch - 1ms/step
# Epoch 21/50
# 3983/3983 - 6s - loss: 6.0612e-06 - mean_squared_error: 6.0612e-06 - val_loss: 7.2738e-06 - val_mean_squared_error: 7.2738e-06 - 6s/epoch - 1ms/step
# Epoch 22/50
# 3983/3983 - 5s - loss: 6.3553e-06 - mean_squared_error: 6.3553e-06 - val_loss: 6.7144e-06 - val_mean_squared_error: 6.7144e-06 - 5s/epoch - 1ms/step
# Epoch 23/50
# 3983/3983 - 7s - loss: 6.3878e-06 - mean_squared_error: 6.3878e-06 - val_loss: 4.4480e-06 - val_mean_squared_error: 4.4480e-06 - 7s/epoch - 2ms/step
# Epoch 24/50
# 3983/3983 - 7s - loss: 4.9806e-06 - mean_squared_error: 4.9806e-06 - val_loss: 1.1453e-05 - val_mean_squared_error: 1.1453e-05 - 7s/epoch - 2ms/step
# Epoch 25/50
# 3983/3983 - 6s - loss: 5.9867e-06 - mean_squared_error: 5.9867e-06 - val_loss: 3.6821e-06 - val_mean_squared_error: 3.6821e-06 - 6s/epoch - 1ms/step
# Epoch 26/50
# 3983/3983 - 5s - loss: 6.0442e-06 - mean_squared_error: 6.0442e-06 - val_loss: 2.3764e-06 - val_mean_squared_error: 2.3764e-06 - 5s/epoch - 1ms/step
# Epoch 27/50
# 3983/3983 - 5s - loss: 6.4393e-06 - mean_squared_error: 6.4393e-06 - val_loss: 1.2315e-06 - val_mean_squared_error: 1.2315e-06 - 5s/epoch - 1ms/step
# Epoch 28/50
# 3983/3983 - 5s - loss: 5.6783e-06 - mean_squared_error: 5.6783e-06 - val_loss: 1.5660e-06 - val_mean_squared_error: 1.5660e-06 - 5s/epoch - 1ms/step
# Epoch 29/50
# 3983/3983 - 5s - loss: 5.8651e-06 - mean_squared_error: 5.8651e-06 - val_loss: 2.5686e-06 - val_mean_squared_error: 2.5686e-06 - 5s/epoch - 1ms/step
# Epoch 30/50
# 3983/3983 - 5s - loss: 5.5859e-06 - mean_squared_error: 5.5859e-06 - val_loss: 1.4992e-06 - val_mean_squared_error: 1.4992e-06 - 5s/epoch - 1ms/step
# Epoch 31/50
# 3983/3983 - 5s - loss: 6.0405e-06 - mean_squared_error: 6.0405e-06 - val_loss: 2.2001e-06 - val_mean_squared_error: 2.2001e-06 - 5s/epoch - 1ms/step
# Epoch 32/50
# 3983/3983 - 5s - loss: 5.1830e-06 - mean_squared_error: 5.1830e-06 - val_loss: 4.5695e-06 - val_mean_squared_error: 4.5695e-06 - 5s/epoch - 1ms/step
# Epoch 33/50
# 3983/3983 - 5s - loss: 5.0417e-06 - mean_squared_error: 5.0417e-06 - val_loss: 1.7714e-06 - val_mean_squared_error: 1.7714e-06 - 5s/epoch - 1ms/step
# Epoch 34/50
# 3983/3983 - 5s - loss: 4.8065e-06 - mean_squared_error: 4.8065e-06 - val_loss: 4.7503e-06 - val_mean_squared_error: 4.7503e-06 - 5s/epoch - 1ms/step
# Epoch 35/50
# 3983/3983 - 5s - loss: 5.8712e-06 - mean_squared_error: 5.8712e-06 - val_loss: 2.2934e-06 - val_mean_squared_error: 2.2934e-06 - 5s/epoch - 1ms/step
# Epoch 36/50
# 3983/3983 - 5s - loss: 6.1410e-06 - mean_squared_error: 6.1410e-06 - val_loss: 2.7055e-06 - val_mean_squared_error: 2.7055e-06 - 5s/epoch - 1ms/step
# Epoch 37/50
# 3983/3983 - 5s - loss: 5.2652e-06 - mean_squared_error: 5.2652e-06 - val_loss: 2.7540e-06 - val_mean_squared_error: 2.7540e-06 - 5s/epoch - 1ms/step
# Epoch 38/50
# 3983/3983 - 5s - loss: 5.3360e-06 - mean_squared_error: 5.3360e-06 - val_loss: 1.3585e-06 - val_mean_squared_error: 1.3585e-06 - 5s/epoch - 1ms/step
# Epoch 39/50
# 3983/3983 - 5s - loss: 4.6039e-06 - mean_squared_error: 4.6039e-06 - val_loss: 1.9769e-06 - val_mean_squared_error: 1.9769e-06 - 5s/epoch - 1ms/step
# Epoch 40/50
# 3983/3983 - 5s - loss: 5.1351e-06 - mean_squared_error: 5.1351e-06 - val_loss: 1.5509e-06 - val_mean_squared_error: 1.5509e-06 - 5s/epoch - 1ms/step
# Epoch 41/50
# 3983/3983 - 5s - loss: 4.6815e-06 - mean_squared_error: 4.6815e-06 - val_loss: 1.6785e-06 - val_mean_squared_error: 1.6785e-06 - 5s/epoch - 1ms/step
# Epoch 42/50
# 3983/3983 - 6s - loss: 5.3227e-06 - mean_squared_error: 5.3227e-06 - val_loss: 1.6649e-06 - val_mean_squared_error: 1.6649e-06 - 6s/epoch - 1ms/step
# Epoch 43/50
# 3983/3983 - 6s - loss: 5.2603e-06 - mean_squared_error: 5.2603e-06 - val_loss: 2.3486e-06 - val_mean_squared_error: 2.3486e-06 - 6s/epoch - 1ms/step
# Epoch 44/50
# 3983/3983 - 5s - loss: 5.7577e-06 - mean_squared_error: 5.7577e-06 - val_loss: 3.8393e-06 - val_mean_squared_error: 3.8393e-06 - 5s/epoch - 1ms/step
# Epoch 45/50
# 3983/3983 - 5s - loss: 4.8102e-06 - mean_squared_error: 4.8102e-06 - val_loss: 2.8918e-06 - val_mean_squared_error: 2.8918e-06 - 5s/epoch - 1ms/step
# Epoch 46/50
# 3983/3983 - 5s - loss: 5.2154e-06 - mean_squared_error: 5.2154e-06 - val_loss: 1.9843e-06 - val_mean_squared_error: 1.9843e-06 - 5s/epoch - 1ms/step
# Epoch 47/50
# 3983/3983 - 5s - loss: 3.8410e-06 - mean_squared_error: 3.8410e-06 - val_loss: 1.0048e-06 - val_mean_squared_error: 1.0048e-06 - 5s/epoch - 1ms/step
# Epoch 48/50
# 3983/3983 - 5s - loss: 4.6018e-06 - mean_squared_error: 4.6018e-06 - val_loss: 2.4746e-06 - val_mean_squared_error: 2.4746e-06 - 5s/epoch - 1ms/step
# Epoch 49/50
# 3983/3983 - 5s - loss: 4.3503e-06 - mean_squared_error: 4.3503e-06 - val_loss: 1.6634e-06 - val_mean_squared_error: 1.6634e-06 - 5s/epoch - 1ms/step
# Epoch 50/50
# 3983/3983 - 8s - loss: 4.3744e-06 - mean_squared_error: 4.3744e-06 - val_loss: 5.4155e-06 - val_mean_squared_error: 5.4155e-06 - 8s/epoch - 2ms/step

# %% [markdown]
# Find best epoch:

# %%
val_mse_per_epoch = history.history['val_mean_squared_error']
best_epoch = val_mse_per_epoch.index(min(val_mse_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 47

# %% [markdown]
# Re-instantiate the hypermodel and train it with the optimal number of epochs from above.

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
history = hypermodel.fit(trainX, trainY, epochs=best_epoch, batch_size=1, validation_data = (validX, validY)).history
# Out:
# Epoch 1/47
# 3983/3983 [==============================] - 10s 2ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 3.5437e-04 - val_mean_squared_error: 3.5437e-04
# Epoch 2/47
# 3983/3983 [==============================] - 12s 3ms/step - loss: 1.6120e-04 - mean_squared_error: 1.6120e-04 - val_loss: 7.4966e-05 - val_mean_squared_error: 7.4966e-05
# Epoch 3/47
# 3983/3983 [==============================] - 9s 2ms/step - loss: 4.2990e-05 - mean_squared_error: 4.2990e-05 - val_loss: 3.4013e-05 - val_mean_squared_error: 3.4013e-05
# Epoch 4/47
# 3983/3983 [==============================] - 7s 2ms/step - loss: 2.4547e-05 - mean_squared_error: 2.4547e-05 - val_loss: 1.4857e-05 - val_mean_squared_error: 1.4857e-05
# Epoch 5/47
# 3983/3983 [==============================] - 6s 2ms/step - loss:
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.yscale('log')

plt.subplot(122)
plt.plot(history['val_loss'])
plt.title('Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.yscale('log')
plt.tight_layout()

plt.savefig("plots/tdnn_loss.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/lorenzo/Desktop/Magistrale/cns/cns_lab/Lab3_1/Bonus_Track_1/tdnn_MG17.ipynb Cell 23 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/lorenzo/Desktop/Magistrale/cns/cns_lab/Lab3_1/Bonus_Track_1/tdnn_MG17.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize = (15,5))
#       <a href='vscode-notebook-cell:/home/lorenzo/Desktop/Magistrale/cns/cns_lab/Lab3_1/Bonus_Track_1/tdnn_MG17.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> plt.subplot(121)
#       <a href='vscode-notebook-cell:/home/lorenzo/Desktop/Magistrale/cns/cns_lab/Lab3_1/Bonus_Track_1/tdnn_MG17.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a> plt.plot(history['loss'])
#
# NameError: name 'plt' is not defined

# %% [markdown]
# Save the model

# %%
hypermodel.save('keras_model_tdnn')
# Out:
# 2023-05-05 17:56:49.245575: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_4_input}}]]
# 2023-05-05 17:56:49.276570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_4_input}}]]
# 2023-05-05 17:56:49.287584: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-05 17:56:49.298224: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_4_input}}]]
# 2023-05-05 17:56:49.307899: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-05 17:56:49.317851: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_4_input}}]]
# 2023-05-05 17:56:49.326544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-05 17:56:49.334549: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,90]
# 	 [[{{node inputs}}]]
# 2023-05-05 17:56:49.346168: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-05 17:56:49.354606: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-05 17:56:49.408464: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_4_input}}]]
# 2023-05-05 17:56:49.422231: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-05 17:56:49.432488: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-05 17:56:49.516602: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-05 17:56:49.544903: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,90]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 2023-05-05 17:56:49.600622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'serving_default_dense_4_input' with dtype float and shape [?,1,17]
# 	 [[{{node serving_default_dense_4_input}}]]
# INFO:tensorflow:Assets written to: keras_model_tdnn/assets
# INFO:tensorflow:Assets written to: keras_model_tdnn/assets

# %% [markdown]
# Command to (eventually) load the saved model:

# %%
#hypermodel = keras.models.load_model('keras_model_tdnn')

# %% [markdown]
# ### Plots of target and output signals over time

# %%
#training
y = hypermodel.predict(trainX)
mse = hypermodel.evaluate(trainX, trainY, batch_size=1)[0]
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'training - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,trainY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.xlabel('timesteps')

plt.subplot(212)
plt.title('training (first 200 timesteps)')
plt.plot(t[:200],y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t[:200],trainY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.xlabel('timesteps')
plt.savefig("plots/tdnn_training.pdf")

#validation
y = hypermodel.predict(validX)
mse = hypermodel.evaluate(validX, validY, batch_size=1)[0]
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'validation - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,validY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('validation (first 200 timesteps)')
plt.plot(t[:200],y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t[:200],validY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig("plots/tdnn_validation.pdf")

#test
y = hypermodel.predict(testX)
mse = hypermodel.evaluate(testX, testY, batch_size=1)[0]
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'test - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,testY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('test (first 200 timesteps)')
plt.plot(t[:200],y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t[:200],testY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig("plots/tdnn_test.pdf")
# Out:
# 125/125 [==============================] - 0s 1ms/step
# 3983/3983 [==============================] - 4s 1ms/step - loss: 1.0746e-06 - mean_squared_error: 1.0746e-06
# 31/31 [==============================] - 0s 1ms/step
# 983/983 [==============================] - 1s 1ms/step - loss: 1.3807e-06 - mean_squared_error: 1.3807e-06
# 156/156 [==============================] - 0s 1ms/step
# 4982/4982 [==============================] - 5s 1ms/step - loss: 1.2403e-06 - mean_squared_error: 1.2403e-06
