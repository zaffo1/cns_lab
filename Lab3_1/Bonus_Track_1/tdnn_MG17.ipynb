# %% [markdown]
# # Bonus-track Assignment 1: Mackey-Glass 17 task
# ## RNN
# Note: as a reference for keras tuner I used the documentation: https://www.tensorflow.org/tutorials/keras/keras_tuner

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
import keras_tuner as kt
# Out:
# 2023-05-06 15:50:59.331059: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-06 15:50:59.388506: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-06 15:50:59.389141: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-06 15:51:00.544834: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Load the dataset

# %%
#load the data
data = np.loadtxt("MG17.csv", delimiter=",")

#organize input and target 
x = data[:-1]
y = data[1:]
print(data)
# Out:
# [ 0.032164  0.040426  0.057861 ... -0.19556  -0.1368   -0.082192]

# %%
#split the dataset into training, validation and test
x_train = x[:4000]
x_valid = x[4000:5000] #validation
x_test = x[5000:]

y_train = y[:4000]
y_valid = y[4000:5000]
y_test = y[5000:]

#plot the data
t=np.arange(start=0,stop=len(x), step=1)
plt.figure(figsize = (25,7))
ax1 = plt.subplot(211)
plt.title('Input', fontsize=18)
ax1.plot(t,x, color = 'b', linewidth= 0.5)
ax1.axvline(x = 4000, color = 'black', linestyle= '--')
ax1.axvline(x = 5000, color = 'black', linestyle= '--')

ax2 = plt.subplot(212, sharex = ax1)
plt.title('Target', fontsize=18)
ax2.plot(t,y, color = 'r', linewidth = 0.5)
ax2.axvline(x = 4000, color = 'black', linestyle= '--')
ax2.axvline(x = 5000, color = 'black', linestyle= '--')
plt.xlabel('Timesteps', fontsize=14)
plt.tight_layout()

# %%
#size of the window we use to buffer the input
window_size = 17 #fix this value at 10 since we know it's the optimal value from theory

# %% [markdown]
# Prepare the dataset to implement the tdnn:

# %%
# Prepare the input X and target Y in order to implement the tdnn
def get_XY(x, y, window):
    # Remove the first "window" elements from y array
    Y = y[window:]
    # X will be an array containing "len(Y)" arrays created using the sliding window
    X = []
    rows_x = len(Y)
    j = 0
    for i in range(rows_x):
        X = np.append(X,x[j:j+window])
        j = j + 1

    #reshape X so it can be fed to the Dense layer
    X =  np.reshape(X, (rows_x, 1, window)) 
    return X, Y 


#prepare the data
trainX, trainY = get_XY(x_train, y_train, window_size)
validX, validY = get_XY(x_valid, y_valid, window_size)
testX, testY = get_XY(x_test, y_test, window_size)

#check shape
print(trainX.shape,trainY.shape)
# Out:
# (3983, 1, 17) (3983,)

# %% [markdown]
# ### Create the model
# To do model selection, we actually create the "hypermodel", defining the hyperparameter search space as well as the architecture of the model.

# %%
def model_architecture(hidden_units, activation_h, activation_d, lr):
    model = Sequential()
    input_shape = (1, window_size) 
    model.add(Dense(units=hidden_units,input_shape=input_shape, activation=activation_h))
    model.add(Dense(units=1, activation=activation_d))
    model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=lr),metrics=['mean_squared_error'])
    return model


def create_model(hp):

    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 10-250
    hidden_units = hp.Int('units',  min_value=10, max_value=250, step=10)

    #Tune the activation function of the hidden layer
    activation_h = hp.Choice("activation_h", ["linear","relu", "tanh"])
    #Tune the activation function of the last layer
    activation_d = hp.Choice("activation_d", ["linear","relu"])

    # Tune the learning rate for the optimizer
    lr = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])


    # call model-building code with the hyperparameter values.
    model = model_architecture(
        hidden_units=hidden_units, activation_d=activation_d, activation_h=activation_h, lr=lr
    )
    return model

# %% [markdown]
# Instantiate hyperparameter tuner

# %%
# use random search to find optimal hyperparameters
tuner = kt.RandomSearch(
                     hypermodel =create_model,
                     objective='val_mean_squared_error',
                     max_trials=25,
                     overwrite=True,
                     directory='tuner',
                     project_name='tuner_tdnn'
                     )

tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 10, 'max_value': 250, 'step': 10, 'sampling': 'linear'}
# activation_h (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu', 'tanh'], 'ordered': False}
# activation_d (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu'], 'ordered': False}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %% [markdown]
# Create a callback to stop training early after reaching a certain value for the validation loss.

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(trainX, trainY, epochs=20, batch_size=1, validation_data = (validX, validY), callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
Completed hyperparameters search.\n
Otimal number of units of hidden layer = {best_hps.get('units')} \n
Optimal learning rate for the optimizer = {best_hps.get('learning_rate')} \n
Optimal activation function for the hidden layer = {best_hps.get('activation_h')} \n
Optimal activation function for the dense layer = {best_hps.get('activation_d')}
""")
# Out:
# Trial 25 Complete [00h 00m 29s]
# val_mean_squared_error: 0.05136428400874138
#
# Best val_mean_squared_error So Far: 3.24534244100505e-06
# Total elapsed time: 00h 43m 28s
# INFO:tensorflow:Oracle triggered exit
#
# Completed hyperparameters search.
#
# Otimal number of units of hidden layer = 110
#
# Optimal learning rate for the optimizer = 0.0001
#
# Optimal activation function for the hidden layer = relu
#
# Optimal activation function for the dense layer = linear

# %% [markdown]
# Find the optimal number of epochs

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
model.summary()
history = model.fit(trainX, trainY, epochs=50, batch_size=1, verbose=2, validation_data = (validX, validY))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1, 110)            1980
#
#  dense_3 (Dense)             (None, 1, 1)              111
#
# =================================================================
# Total params: 2,091
# Trainable params: 2,091
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 3983/3983 - 5s - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 2.6132e-04 - val_mean_squared_error: 2.6132e-04 - 5s/epoch - 1ms/step
# Epoch 2/50
# 3983/3983 - 5s - loss: 1.0384e-04 - mean_squared_error: 1.0384e-04 - val_loss: 5.5208e-05 - val_mean_squared_error: 5.5208e-05 - 5s/epoch - 1ms/step
# Epoch 3/50
# 3983/3983 - 5s - loss: 3.6111e-05 - mean_squared_error: 3.6111e-05 - val_loss: 3.0647e-05 - val_mean_squared_error: 3.0647e-05 - 5s/epoch - 1ms/step
# Epoch 4/50
# 3983/3983 - 5s - loss: 2.1073e-05 - mean_squared_error: 2.1073e-05 - val_loss: 1.4184e-05 - val_mean_squared_error: 1.4184e-05 - 5s/epoch - 1ms/step
# Epoch 5/50
# 3983/3983 - 5s - loss: 1.5889e-05 - mean_squared_error: 1.5889e-05 - val_loss: 2.3027e-05 - val_mean_squared_error: 2.3027e-05 - 5s/epoch - 1ms/step
# Epoch 6/50
# 3983/3983 - 5s - loss: 1.3761e-05 - mean_squared_error: 1.3761e-05 - val_loss: 8.3009e-06 - val_mean_squared_error: 8.3009e-06 - 5s/epoch - 1ms/step
# Epoch 7/50
# 3983/3983 - 5s - loss: 1.1379e-05 - mean_squared_error: 1.1379e-05 - val_loss: 7.0168e-06 - val_mean_squared_error: 7.0168e-06 - 5s/epoch - 1ms/step
# Epoch 8/50
# 3983/3983 - 5s - loss: 1.0184e-05 - mean_squared_error: 1.0184e-05 - val_loss: 5.6712e-06 - val_mean_squared_error: 5.6712e-06 - 5s/epoch - 1ms/step
# Epoch 9/50
# 3983/3983 - 6s - loss: 9.0882e-06 - mean_squared_error: 9.0882e-06 - val_loss: 4.8972e-06 - val_mean_squared_error: 4.8972e-06 - 6s/epoch - 1ms/step
# Epoch 10/50
# 3983/3983 - 6s - loss: 9.0518e-06 - mean_squared_error: 9.0518e-06 - val_loss: 8.8993e-06 - val_mean_squared_error: 8.8993e-06 - 6s/epoch - 1ms/step
# Epoch 11/50
# 3983/3983 - 6s - loss: 7.9509e-06 - mean_squared_error: 7.9509e-06 - val_loss: 1.0865e-05 - val_mean_squared_error: 1.0865e-05 - 6s/epoch - 2ms/step
# Epoch 12/50
# 3983/3983 - 7s - loss: 8.1301e-06 - mean_squared_error: 8.1301e-06 - val_loss: 2.6310e-06 - val_mean_squared_error: 2.6310e-06 - 7s/epoch - 2ms/step
# Epoch 13/50
# 3983/3983 - 6s - loss: 8.7693e-06 - mean_squared_error: 8.7693e-06 - val_loss: 1.8640e-05 - val_mean_squared_error: 1.8640e-05 - 6s/epoch - 1ms/step
# Epoch 14/50
# 3983/3983 - 4s - loss: 8.3434e-06 - mean_squared_error: 8.3434e-06 - val_loss: 9.6824e-06 - val_mean_squared_error: 9.6824e-06 - 4s/epoch - 962us/step
# Epoch 15/50
# 3983/3983 - 4s - loss: 6.1696e-06 - mean_squared_error: 6.1696e-06 - val_loss: 3.1947e-06 - val_mean_squared_error: 3.1947e-06 - 4s/epoch - 929us/step
# Epoch 16/50
# 3983/3983 - 4s - loss: 6.8561e-06 - mean_squared_error: 6.8561e-06 - val_loss: 6.9848e-06 - val_mean_squared_error: 6.9848e-06 - 4s/epoch - 1ms/step
# Epoch 17/50
# 3983/3983 - 4s - loss: 6.1398e-06 - mean_squared_error: 6.1398e-06 - val_loss: 1.7111e-05 - val_mean_squared_error: 1.7111e-05 - 4s/epoch - 999us/step
# Epoch 18/50
# 3983/3983 - 4s - loss: 8.5437e-06 - mean_squared_error: 8.5437e-06 - val_loss: 3.5822e-06 - val_mean_squared_error: 3.5822e-06 - 4s/epoch - 972us/step
# Epoch 19/50
# 3983/3983 - 4s - loss: 7.9894e-06 - mean_squared_error: 7.9894e-06 - val_loss: 8.8489e-06 - val_mean_squared_error: 8.8489e-06 - 4s/epoch - 992us/step
# Epoch 20/50
# 3983/3983 - 4s - loss: 6.9919e-06 - mean_squared_error: 6.9919e-06 - val_loss: 3.7835e-06 - val_mean_squared_error: 3.7835e-06 - 4s/epoch - 1ms/step
# Epoch 21/50
# 3983/3983 - 4s - loss: 6.6155e-06 - mean_squared_error: 6.6155e-06 - val_loss: 2.6708e-05 - val_mean_squared_error: 2.6708e-05 - 4s/epoch - 997us/step
# Epoch 22/50
# 3983/3983 - 4s - loss: 7.3400e-06 - mean_squared_error: 7.3400e-06 - val_loss: 6.1611e-06 - val_mean_squared_error: 6.1611e-06 - 4s/epoch - 931us/step
# Epoch 23/50
# 3983/3983 - 4s - loss: 6.8037e-06 - mean_squared_error: 6.8037e-06 - val_loss: 2.7011e-06 - val_mean_squared_error: 2.7011e-06 - 4s/epoch - 900us/step
# Epoch 24/50
# 3983/3983 - 4s - loss: 6.0296e-06 - mean_squared_error: 6.0296e-06 - val_loss: 8.3349e-06 - val_mean_squared_error: 8.3349e-06 - 4s/epoch - 938us/step
# Epoch 25/50
# 3983/3983 - 4s - loss: 7.0617e-06 - mean_squared_error: 7.0617e-06 - val_loss: 3.4686e-06 - val_mean_squared_error: 3.4686e-06 - 4s/epoch - 922us/step
# Epoch 26/50
# 3983/3983 - 4s - loss: 6.0683e-06 - mean_squared_error: 6.0683e-06 - val_loss: 3.6530e-06 - val_mean_squared_error: 3.6530e-06 - 4s/epoch - 931us/step
# Epoch 27/50
# 3983/3983 - 4s - loss: 6.1524e-06 - mean_squared_error: 6.1524e-06 - val_loss: 4.2905e-06 - val_mean_squared_error: 4.2905e-06 - 4s/epoch - 921us/step
# Epoch 28/50
# 3983/3983 - 4s - loss: 6.1961e-06 - mean_squared_error: 6.1961e-06 - val_loss: 4.6221e-06 - val_mean_squared_error: 4.6221e-06 - 4s/epoch - 902us/step
# Epoch 29/50
# 3983/3983 - 4s - loss: 6.0477e-06 - mean_squared_error: 6.0477e-06 - val_loss: 2.9460e-06 - val_mean_squared_error: 2.9460e-06 - 4s/epoch - 923us/step
# Epoch 30/50
# 3983/3983 - 4s - loss: 6.1935e-06 - mean_squared_error: 6.1935e-06 - val_loss: 2.4161e-06 - val_mean_squared_error: 2.4161e-06 - 4s/epoch - 892us/step
# Epoch 31/50
# 3983/3983 - 4s - loss: 4.9763e-06 - mean_squared_error: 4.9763e-06 - val_loss: 3.3282e-06 - val_mean_squared_error: 3.3282e-06 - 4s/epoch - 919us/step
# Epoch 32/50
# 3983/3983 - 4s - loss: 6.6341e-06 - mean_squared_error: 6.6341e-06 - val_loss: 1.7147e-06 - val_mean_squared_error: 1.7147e-06 - 4s/epoch - 898us/step
# Epoch 33/50
# 3983/3983 - 4s - loss: 6.6388e-06 - mean_squared_error: 6.6388e-06 - val_loss: 5.2424e-05 - val_mean_squared_error: 5.2424e-05 - 4s/epoch - 894us/step
# Epoch 34/50
# 3983/3983 - 4s - loss: 4.9152e-06 - mean_squared_error: 4.9152e-06 - val_loss: 2.8442e-06 - val_mean_squared_error: 2.8442e-06 - 4s/epoch - 898us/step
# Epoch 35/50
# 3983/3983 - 4s - loss: 4.7629e-06 - mean_squared_error: 4.7629e-06 - val_loss: 9.4189e-06 - val_mean_squared_error: 9.4189e-06 - 4s/epoch - 923us/step
# Epoch 36/50
# 3983/3983 - 4s - loss: 7.6688e-06 - mean_squared_error: 7.6688e-06 - val_loss: 2.2146e-06 - val_mean_squared_error: 2.2146e-06 - 4s/epoch - 907us/step
# Epoch 37/50
# 3983/3983 - 4s - loss: 6.0669e-06 - mean_squared_error: 6.0669e-06 - val_loss: 6.0919e-06 - val_mean_squared_error: 6.0919e-06 - 4s/epoch - 915us/step
# Epoch 38/50
# 3983/3983 - 4s - loss: 5.5573e-06 - mean_squared_error: 5.5573e-06 - val_loss: 7.4457e-06 - val_mean_squared_error: 7.4457e-06 - 4s/epoch - 934us/step
# Epoch 39/50
# 3983/3983 - 4s - loss: 5.0790e-06 - mean_squared_error: 5.0790e-06 - val_loss: 1.6312e-06 - val_mean_squared_error: 1.6312e-06 - 4s/epoch - 910us/step
# Epoch 40/50
# 3983/3983 - 4s - loss: 5.8494e-06 - mean_squared_error: 5.8494e-06 - val_loss: 1.4565e-05 - val_mean_squared_error: 1.4565e-05 - 4s/epoch - 915us/step
# Epoch 41/50
# 3983/3983 - 4s - loss: 5.4863e-06 - mean_squared_error: 5.4863e-06 - val_loss: 6.5287e-06 - val_mean_squared_error: 6.5287e-06 - 4s/epoch - 909us/step
# Epoch 42/50
# 3983/3983 - 4s - loss: 5.1178e-06 - mean_squared_error: 5.1178e-06 - val_loss: 1.1851e-06 - val_mean_squared_error: 1.1851e-06 - 4s/epoch - 909us/step
# Epoch 43/50
# 3983/3983 - 4s - loss: 5.8081e-06 - mean_squared_error: 5.8081e-06 - val_loss: 7.6061e-06 - val_mean_squared_error: 7.6061e-06 - 4s/epoch - 904us/step
# Epoch 44/50
# 3983/3983 - 4s - loss: 5.1555e-06 - mean_squared_error: 5.1555e-06 - val_loss: 1.1434e-06 - val_mean_squared_error: 1.1434e-06 - 4s/epoch - 914us/step
# Epoch 45/50
# 3983/3983 - 4s - loss: 5.4180e-06 - mean_squared_error: 5.4180e-06 - val_loss: 2.6108e-06 - val_mean_squared_error: 2.6108e-06 - 4s/epoch - 908us/step
# Epoch 46/50
# 3983/3983 - 4s - loss: 6.8465e-06 - mean_squared_error: 6.8465e-06 - val_loss: 2.2803e-06 - val_mean_squared_error: 2.2803e-06 - 4s/epoch - 893us/step
# Epoch 47/50
# 3983/3983 - 4s - loss: 5.2674e-06 - mean_squared_error: 5.2674e-06 - val_loss: 4.7945e-06 - val_mean_squared_error: 4.7945e-06 - 4s/epoch - 919us/step
# Epoch 48/50
# 3983/3983 - 4s - loss: 3.9824e-06 - mean_squared_error: 3.9824e-06 - val_loss: 3.4659e-06 - val_mean_squared_error: 3.4659e-06 - 4s/epoch - 912us/step
# Epoch 49/50
# 3983/3983 - 4s - loss: 4.9009e-06 - mean_squared_error: 4.9009e-06 - val_loss: 3.7583e-06 - val_mean_squared_error: 3.7583e-06 - 4s/epoch - 911us/step
# Epoch 50/50
# 3983/3983 - 4s - loss: 5.0273e-06 - mean_squared_error: 5.0273e-06 - val_loss: 1.3183e-06 - val_mean_squared_error: 1.3183e-06 - 4s/epoch - 911us/step

# %% [markdown]
# Find best epoch:

# %%
val_mse_per_epoch = history.history['val_mean_squared_error']
best_epoch = val_mse_per_epoch.index(min(val_mse_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 44

# %% [markdown]
# Re-instantiate the hypermodel and train it with the optimal number of epochs from above.

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
history = hypermodel.fit(trainX, trainY, epochs=best_epoch, batch_size=1, validation_data = (validX, validY)).history
# Out:
# Epoch 1/44
# 3983/3983 [==============================] - 6s 1ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 2.3489e-04 - val_mean_squared_error: 2.3489e-04
# Epoch 2/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 1.0194e-04 - mean_squared_error: 1.0194e-04 - val_loss: 6.8217e-05 - val_mean_squared_error: 6.8217e-05
# Epoch 3/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 3.8252e-05 - mean_squared_error: 3.8252e-05 - val_loss: 2.5919e-05 - val_mean_squared_error: 2.5919e-05
# Epoch 4/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 2.1686e-05 - mean_squared_error: 2.1686e-05 - val_loss: 1.4370e-05 - val_mean_squared_error: 1.4370e-05
# Epoch 5/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 1.7671e-05 - mean_squared_error: 1.7671e-05 - val_loss: 9.5505e-05 - val_mean_squared_error: 9.5505e-05
# Epoch 6/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 1.2930e-05 - mean_squared_error: 1.2930e-05 - val_loss: 1.6009e-05 - val_mean_squared_error: 1.6009e-05
# Epoch 7/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 1.0952e-05 - mean_squared_error: 1.0952e-05 - val_loss: 1.2684e-05 - val_mean_squared_error: 1.2684e-05
# Epoch 8/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 1.1565e-05 - mean_squared_error: 1.1565e-05 - val_loss: 5.8374e-06 - val_mean_squared_error: 5.8374e-06
# Epoch 9/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 1.0615e-05 - mean_squared_error: 1.0615e-05 - val_loss: 4.2760e-06 - val_mean_squared_error: 4.2760e-06
# Epoch 10/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 9.0054e-06 - mean_squared_error: 9.0054e-06 - val_loss: 5.8342e-06 - val_mean_squared_error: 5.8342e-06
# Epoch 11/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 1.0067e-05 - mean_squared_error: 1.0067e-05 - val_loss: 6.3542e-06 - val_mean_squared_error: 6.3542e-06
# Epoch 12/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 8.6882e-06 - mean_squared_error: 8.6882e-06 - val_loss: 1.1770e-05 - val_mean_squared_error: 1.1770e-05
# Epoch 13/44
# 3983/3983 [==============================] - 6s 1ms/step - loss: 8.1356e-06 - mean_squared_error: 8.1356e-06 - val_loss: 4.6675e-06 - val_mean_squared_error: 4.6675e-06
# Epoch 14/44
# 3983/3983 [==============================] - 6s 1ms/step - loss: 8.0878e-06 - mean_squared_error: 8.0878e-06 - val_loss: 2.6094e-05 - val_mean_squared_error: 2.6094e-05
# Epoch 15/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 8.1529e-06 - mean_squared_error: 8.1529e-06 - val_loss: 2.5967e-06 - val_mean_squared_error: 2.5967e-06
# Epoch 16/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 8.5053e-06 - mean_squared_error: 8.5053e-06 - val_loss: 4.1434e-06 - val_mean_squared_error: 4.1434e-06
# Epoch 17/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 7.1302e-06 - mean_squared_error: 7.1302e-06 - val_loss: 4.5962e-06 - val_mean_squared_error: 4.5962e-06
# Epoch 18/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 7.5856e-06 - mean_squared_error: 7.5856e-06 - val_loss: 3.8270e-06 - val_mean_squared_error: 3.8270e-06
# Epoch 19/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 7.5033e-06 - mean_squared_error: 7.5033e-06 - val_loss: 2.5086e-06 - val_mean_squared_error: 2.5086e-06
# Epoch 20/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 8.5007e-06 - mean_squared_error: 8.5007e-06 - val_loss: 2.6051e-06 - val_mean_squared_error: 2.6051e-06
# Epoch 21/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 7.7180e-06 - mean_squared_error: 7.7180e-06 - val_loss: 5.9573e-06 - val_mean_squared_error: 5.9573e-06
# Epoch 22/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 6.6238e-06 - mean_squared_error: 6.6238e-06 - val_loss: 4.9495e-06 - val_mean_squared_error: 4.9495e-06
# Epoch 23/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 7.4254e-06 - mean_squared_error: 7.4254e-06 - val_loss: 4.7832e-06 - val_mean_squared_error: 4.7832e-06
# Epoch 24/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 6.8207e-06 - mean_squared_error: 6.8207e-06 - val_loss: 6.5780e-06 - val_mean_squared_error: 6.5780e-06
# Epoch 25/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 7.6689e-06 - mean_squared_error: 7.6689e-06 - val_loss: 3.6704e-06 - val_mean_squared_error: 3.6704e-06
# Epoch 26/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 7.1353e-06 - mean_squared_error: 7.1353e-06 - val_loss: 1.8095e-05 - val_mean_squared_error: 1.8095e-05
# Epoch 27/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 6.7462e-06 - mean_squared_error: 6.7462e-06 - val_loss: 2.8148e-06 - val_mean_squared_error: 2.8148e-06
# Epoch 28/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 6.1073e-06 - mean_squared_error: 6.1073e-06 - val_loss: 1.8535e-06 - val_mean_squared_error: 1.8535e-06
# Epoch 29/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 5.8192e-06 - mean_squared_error: 5.8192e-06 - val_loss: 6.9785e-06 - val_mean_squared_error: 6.9785e-06
# Epoch 30/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 7.3536e-06 - mean_squared_error: 7.3536e-06 - val_loss: 1.9206e-06 - val_mean_squared_error: 1.9206e-06
# Epoch 31/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 5.6135e-06 - mean_squared_error: 5.6135e-06 - val_loss: 1.8121e-05 - val_mean_squared_error: 1.8121e-05
# Epoch 32/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 6.0279e-06 - mean_squared_error: 6.0279e-06 - val_loss: 3.1415e-06 - val_mean_squared_error: 3.1415e-06
# Epoch 33/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 5.7074e-06 - mean_squared_error: 5.7074e-06 - val_loss: 2.5139e-06 - val_mean_squared_error: 2.5139e-06
# Epoch 34/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 5.3501e-06 - mean_squared_error: 5.3501e-06 - val_loss: 2.9123e-06 - val_mean_squared_error: 2.9123e-06
# Epoch 35/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 5.9824e-06 - mean_squared_error: 5.9824e-06 - val_loss: 2.0424e-06 - val_mean_squared_error: 2.0424e-06
# Epoch 36/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 6.6919e-06 - mean_squared_error: 6.6919e-06 - val_loss: 1.3897e-05 - val_mean_squared_error: 1.3897e-05
# Epoch 37/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 6.5151e-06 - mean_squared_error: 6.5151e-06 - val_loss: 8.7566e-06 - val_mean_squared_error: 8.7566e-06
# Epoch 38/44
# 3983/3983 [==============================] - 5s 1ms/step - loss: 5.0689e-06 - mean_squared_error: 5.0689e-06 - val_loss: 1.2286e-06 - val_mean_squared_error: 1.2286e-06
# Epoch 39/44
# 3983/3983 [==============================] - 4s 1ms/step - loss: 7.8169e-06 - mean_squared_error: 7.8169e-06 - val_loss: 2.9040e-06 - val_mean_squared_error: 2.9040e-06
# Epoch 40/44
# 3983/3983 [==============================] - 4s 1ms/step - loss: 4.3769e-06 - mean_squared_error: 4.3769e-06 - val_loss: 3.8966e-06 - val_mean_squared_error: 3.8966e-06
# Epoch 41/44
# 3983/3983 [==============================] - 4s 1ms/step - loss: 6.1042e-06 - mean_squared_error: 6.1042e-06 - val_loss: 4.5582e-06 - val_mean_squared_error: 4.5582e-06
# Epoch 42/44
# 3983/3983 [==============================] - 4s 1ms/step - loss: 5.1360e-06 - mean_squared_error: 5.1360e-06 - val_loss: 1.4557e-06 - val_mean_squared_error: 1.4557e-06
# Epoch 43/44
# 3983/3983 [==============================] - 4s 1ms/step - loss: 5.5172e-06 - mean_squared_error: 5.5172e-06 - val_loss: 1.3334e-06 - val_mean_squared_error: 1.3334e-06
# Epoch 44/44
# 3983/3983 [==============================] - 4s 1ms/step - loss: 5.6031e-06 - mean_squared_error: 5.6031e-06 - val_loss: 3.8566e-06 - val_mean_squared_error: 3.8566e-06

# %% [markdown]
# ### Make plots of the loss and validation loss

# %%
plt.figure(figsize = (15,5))

plt.subplot(121)
plt.plot(history['loss'])
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.yscale('log')

plt.subplot(122)
plt.plot(history['val_loss'])
plt.title('Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.yscale('log')
plt.tight_layout()

plt.savefig("plots/tdnn_loss.pdf")
plt.show()

# %% [markdown]
# Save the model

# %%
hypermodel.save('keras_model_tdnn')
# Out:
# 2023-05-06 16:41:53.957170: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_4_input}}]]
# 2023-05-06 16:41:53.978703: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_4_input}}]]
# 2023-05-06 16:41:53.987724: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-06 16:41:53.994964: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_4_input}}]]
# 2023-05-06 16:41:54.002588: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-06 16:41:54.010425: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_4_input}}]]
# 2023-05-06 16:41:54.016242: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-06 16:41:54.022212: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,110]
# 	 [[{{node inputs}}]]
# 2023-05-06 16:41:54.030042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-06 16:41:54.036880: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-06 16:41:54.074912: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_4_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_4_input}}]]
# 2023-05-06 16:41:54.086010: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-06 16:41:54.093197: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-06 16:41:54.151454: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-06 16:41:54.172265: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,110]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: keras_model_tdnn/assets
# 2023-05-06 16:41:54.215235: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'serving_default_dense_4_input' with dtype float and shape [?,1,17]
# 	 [[{{node serving_default_dense_4_input}}]]
# INFO:tensorflow:Assets written to: keras_model_tdnn/assets

# %% [markdown]
# Command to (eventually) load the saved model:

# %%
#hypermodel = keras.models.load_model('keras_model_tdnn')

# %% [markdown]
# ### Plots of target and output signals over time

# %%
#training
y = hypermodel.predict(trainX)
mse = hypermodel.evaluate(trainX, trainY, batch_size=1)[0]
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'training - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,trainY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.xlabel('timesteps')

plt.subplot(212)
plt.title('training (first 200 timesteps)')
plt.plot(t[:200],y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t[:200],trainY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.xlabel('timesteps')
plt.savefig("plots/tdnn_training.pdf")

#validation
y = hypermodel.predict(validX)
mse = hypermodel.evaluate(validX, validY, batch_size=1)[0]
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'validation - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,validY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('validation (first 200 timesteps)')
plt.plot(t[:200],y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t[:200],validY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig("plots/tdnn_validation.pdf")

#test
y = hypermodel.predict(testX)
mse = hypermodel.evaluate(testX, testY, batch_size=1)[0]
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'test - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,testY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('test (first 200 timesteps)')
plt.plot(t[:200],y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t[:200],testY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig("plots/tdnn_test.pdf")
# Out:
# 125/125 [==============================] - 0s 913us/step
# 3983/3983 [==============================] - 3s 778us/step - loss: 3.3783e-06 - mean_squared_error: 3.3783e-06
# 31/31 [==============================] - 0s 862us/step
# 983/983 [==============================] - 1s 803us/step - loss: 3.8566e-06 - mean_squared_error: 3.8566e-06
# 156/156 [==============================] - 0s 885us/step
# 4982/4982 [==============================] - 4s 784us/step - loss: 3.6360e-06 - mean_squared_error: 3.6360e-06
