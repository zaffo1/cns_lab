# %% [markdown]
# # Bonus-track Assignment 1: Mackey-Glass 17 task
# ## RNN
# Note: as a reference for keras tuner I used the documentation: https://www.tensorflow.org/tutorials/keras/keras_tuner

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
import keras_tuner as kt
import pandas as pd

# %% [markdown]
# ### Load the dataset

# %%
#load the data
data = np.loadtxt("MG17.csv", delimiter=",")

#organize input and target 
x = data[:-1]
y = data[1:]
print(data)
# Out:
# [ 0.032164  0.040426  0.057861 ... -0.19556  -0.1368   -0.082192]

# %%
#split the dataset into training, validation and test
x_train = x[:4000]
x_valid = x[4000:5000] #validation
x_test = x[5000:]

y_train = y[:4000]
y_valid = y[4000:5000]
y_test = y[5000:]

#plot the data
t=np.arange(start=0,stop=len(x), step=1)
plt.figure(figsize = (25,7))
ax1 = plt.subplot(211)
plt.title('Input', fontsize=18)
ax1.plot(t,x, color = 'b', linewidth= 0.5)
ax1.axvline(x = 4000, color = 'black', linestyle= '--')
ax1.axvline(x = 5000, color = 'black', linestyle= '--')

ax2 = plt.subplot(212, sharex = ax1)
plt.title('Target', fontsize=18)
ax2.plot(t,y, color = 'r', linewidth = 0.5)
ax2.axvline(x = 4000, color = 'black', linestyle= '--')
ax2.axvline(x = 5000, color = 'black', linestyle= '--')
plt.xlabel('Timesteps', fontsize=14)
plt.tight_layout()

# %%
#size of the window we use to buffer the input
window_size = 17 #fix this value at 10 since we know it's the optimal value from theory

# %% [markdown]
# Prepare the dataset to implement the tdnn:

# %%
# Prepare the input X and target Y in order to implement the tdnn
def get_XY(x, y, window):
    # Remove the first "window" elements from y array
    Y = y[window:]
    # X will be an array containing "len(Y)" arrays created using the sliding window
    X = []
    rows_x = len(Y)
    j = 0
    for i in range(rows_x):
        X = np.append(X,x[j:j+window])
        j = j + 1

    #reshape X so it can be fed to the Dense layer
    X =  np.reshape(X, (rows_x, 1, window)) 
    return X, Y 


#prepare the data
trainX, trainY = get_XY(x_train, y_train, window_size)
validX, validY = get_XY(x_valid, y_valid, window_size)
testX, testY = get_XY(x_test, y_test, window_size)

#check shape
print(trainX.shape,trainY.shape)
# Out:
# (3983, 1, 17) (3983,)

# %% [markdown]
# ### Create the model
# To do model selection, we actually create the "hypermodel", defining the hyperparameter search space as well as the architecture of the model.

# %%
def model_architecture(hidden_units, activation_h, activation_d, lr):
    model = Sequential()
    input_shape = (1, window_size) 
    model.add(Dense(units=hidden_units,input_shape=input_shape, activation=activation_h))
    model.add(Dense(units=1, activation=activation_d))
    model.compile(loss='mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=lr),metrics=['mean_squared_error'])
    return model


def create_model(hp):

    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 10-250
    hidden_units = hp.Int('units',  min_value=10, max_value=250, step=10)

    #Tune the activation function of the hidden layer
    activation_h = hp.Choice("activation_h", ["linear","relu", "tanh"])
    #Tune the activation function of the last layer
    activation_d = hp.Choice("activation_d", ["linear","relu"])

    # Tune the learning rate for the optimizer
    lr = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])


    # call model-building code with the hyperparameter values.
    model = model_architecture(
        hidden_units=hidden_units, activation_d=activation_d, activation_h=activation_h, lr=lr
    )
    return model

# %% [markdown]
# Instantiate hyperparameter tuner

# %%
# use random search to find optimal hyperparameters
tuner = kt.RandomSearch(
                     hypermodel =create_model,
                     objective='val_mean_squared_error',
                     max_trials=25,
                     #overwrite=True,
                     directory='tuner',
                     project_name='tuner_tdnn'
                     )

tuner.search_space_summary()
# Out:
# INFO:tensorflow:Reloading Tuner from tuner/tuner_tdnn/tuner0.json
# Search space summary
# Default search space size: 4
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 10, 'max_value': 250, 'step': 10, 'sampling': 'linear'}
# activation_h (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu', 'tanh'], 'ordered': False}
# activation_d (Choice)
# {'default': 'linear', 'conditions': [], 'values': ['linear', 'relu'], 'ordered': False}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %% [markdown]
# Create a callback to stop training early after reaching a certain value for the validation loss.

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(trainX, trainY, epochs=20, batch_size=1, validation_data = (validX, validY), callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
Completed hyperparameters search.\n
Otimal number of units of hidden layer = {best_hps.get('units')} \n
Optimal learning rate for the optimizer = {best_hps.get('learning_rate')} \n
Optimal activation function for the hidden layer = {best_hps.get('activation_h')} \n
Optimal activation function for the dense layer = {best_hps.get('activation_d')}
""")
# Out:
# INFO:tensorflow:Oracle triggered exit
#
# Completed hyperparameters search.
#
# Otimal number of units of hidden layer = 110
#
# Optimal learning rate for the optimizer = 0.0001
#
# Optimal activation function for the hidden layer = relu
#
# Optimal activation function for the dense layer = linear

# %% [markdown]
# Find the optimal number of epochs

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
model.summary()
history = model.fit(trainX, trainY, epochs=50, batch_size=1, verbose=2, validation_data = (validX, validY))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1, 110)            1980
#
#  dense_1 (Dense)             (None, 1, 1)              111
#
# =================================================================
# Total params: 2,091
# Trainable params: 2,091
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 3983/3983 - 10s - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 1.6078e-04 - val_mean_squared_error: 1.6078e-04 - 10s/epoch - 2ms/step
# Epoch 2/50
# 3983/3983 - 8s - loss: 6.9155e-05 - mean_squared_error: 6.9155e-05 - val_loss: 5.6421e-05 - val_mean_squared_error: 5.6421e-05 - 8s/epoch - 2ms/step
# Epoch 3/50
# 3983/3983 - 9s - loss: 3.2847e-05 - mean_squared_error: 3.2847e-05 - val_loss: 2.5565e-05 - val_mean_squared_error: 2.5565e-05 - 9s/epoch - 2ms/step
# Epoch 4/50
# 3983/3983 - 8s - loss: 2.0790e-05 - mean_squared_error: 2.0790e-05 - val_loss: 2.1084e-05 - val_mean_squared_error: 2.1084e-05 - 8s/epoch - 2ms/step
# Epoch 5/50
# 3983/3983 - 8s - loss: 1.6873e-05 - mean_squared_error: 1.6873e-05 - val_loss: 3.1457e-05 - val_mean_squared_error: 3.1457e-05 - 8s/epoch - 2ms/step
# Epoch 6/50
# 3983/3983 - 8s - loss: 1.5426e-05 - mean_squared_error: 1.5426e-05 - val_loss: 2.0398e-05 - val_mean_squared_error: 2.0398e-05 - 8s/epoch - 2ms/step
# Epoch 7/50
# 3983/3983 - 8s - loss: 1.2808e-05 - mean_squared_error: 1.2808e-05 - val_loss: 8.5381e-06 - val_mean_squared_error: 8.5381e-06 - 8s/epoch - 2ms/step
# Epoch 8/50
# 3983/3983 - 8s - loss: 1.1879e-05 - mean_squared_error: 1.1879e-05 - val_loss: 7.7716e-06 - val_mean_squared_error: 7.7716e-06 - 8s/epoch - 2ms/step
# Epoch 9/50
# 3983/3983 - 8s - loss: 1.0697e-05 - mean_squared_error: 1.0697e-05 - val_loss: 5.5424e-06 - val_mean_squared_error: 5.5424e-06 - 8s/epoch - 2ms/step
# Epoch 10/50
# 3983/3983 - 9s - loss: 1.0070e-05 - mean_squared_error: 1.0070e-05 - val_loss: 1.2610e-05 - val_mean_squared_error: 1.2610e-05 - 9s/epoch - 2ms/step
# Epoch 11/50
# 3983/3983 - 8s - loss: 1.0882e-05 - mean_squared_error: 1.0882e-05 - val_loss: 4.2164e-06 - val_mean_squared_error: 4.2164e-06 - 8s/epoch - 2ms/step
# Epoch 12/50
# 3983/3983 - 12s - loss: 9.1566e-06 - mean_squared_error: 9.1566e-06 - val_loss: 1.7873e-05 - val_mean_squared_error: 1.7873e-05 - 12s/epoch - 3ms/step
# Epoch 13/50
# 3983/3983 - 8s - loss: 9.6507e-06 - mean_squared_error: 9.6507e-06 - val_loss: 1.5714e-05 - val_mean_squared_error: 1.5714e-05 - 8s/epoch - 2ms/step
# Epoch 14/50
# 3983/3983 - 7s - loss: 8.5953e-06 - mean_squared_error: 8.5953e-06 - val_loss: 7.7491e-06 - val_mean_squared_error: 7.7491e-06 - 7s/epoch - 2ms/step
# Epoch 15/50
# 3983/3983 - 7s - loss: 8.3549e-06 - mean_squared_error: 8.3549e-06 - val_loss: 3.8209e-06 - val_mean_squared_error: 3.8209e-06 - 7s/epoch - 2ms/step
# Epoch 16/50
# 3983/3983 - 8s - loss: 8.0550e-06 - mean_squared_error: 8.0550e-06 - val_loss: 1.4055e-05 - val_mean_squared_error: 1.4055e-05 - 8s/epoch - 2ms/step
# Epoch 17/50
# 3983/3983 - 8s - loss: 8.5322e-06 - mean_squared_error: 8.5322e-06 - val_loss: 1.1778e-05 - val_mean_squared_error: 1.1778e-05 - 8s/epoch - 2ms/step
# Epoch 18/50
# 3983/3983 - 7s - loss: 7.6867e-06 - mean_squared_error: 7.6867e-06 - val_loss: 1.1652e-05 - val_mean_squared_error: 1.1652e-05 - 7s/epoch - 2ms/step
# Epoch 19/50
# 3983/3983 - 10s - loss: 8.0372e-06 - mean_squared_error: 8.0372e-06 - val_loss: 4.3138e-06 - val_mean_squared_error: 4.3138e-06 - 10s/epoch - 2ms/step
# Epoch 20/50
# 3983/3983 - 7s - loss: 7.0097e-06 - mean_squared_error: 7.0097e-06 - val_loss: 2.7171e-06 - val_mean_squared_error: 2.7171e-06 - 7s/epoch - 2ms/step
# Epoch 21/50
# 3983/3983 - 7s - loss: 8.1629e-06 - mean_squared_error: 8.1629e-06 - val_loss: 5.1181e-06 - val_mean_squared_error: 5.1181e-06 - 7s/epoch - 2ms/step
# Epoch 22/50
# 3983/3983 - 8s - loss: 6.4481e-06 - mean_squared_error: 6.4481e-06 - val_loss: 1.3802e-05 - val_mean_squared_error: 1.3802e-05 - 8s/epoch - 2ms/step
# Epoch 23/50
# 3983/3983 - 9s - loss: 7.8275e-06 - mean_squared_error: 7.8275e-06 - val_loss: 4.9399e-06 - val_mean_squared_error: 4.9399e-06 - 9s/epoch - 2ms/step
# Epoch 24/50
# 3983/3983 - 7s - loss: 7.4914e-06 - mean_squared_error: 7.4914e-06 - val_loss: 3.9524e-06 - val_mean_squared_error: 3.9524e-06 - 7s/epoch - 2ms/step
# Epoch 25/50
# 3983/3983 - 8s - loss: 6.6766e-06 - mean_squared_error: 6.6766e-06 - val_loss: 4.4922e-06 - val_mean_squared_error: 4.4922e-06 - 8s/epoch - 2ms/step
# Epoch 26/50
# 3983/3983 - 9s - loss: 6.6718e-06 - mean_squared_error: 6.6718e-06 - val_loss: 2.9309e-05 - val_mean_squared_error: 2.9309e-05 - 9s/epoch - 2ms/step
# Epoch 27/50
# 3983/3983 - 8s - loss: 7.8974e-06 - mean_squared_error: 7.8974e-06 - val_loss: 5.2000e-06 - val_mean_squared_error: 5.2000e-06 - 8s/epoch - 2ms/step
# Epoch 28/50
# 3983/3983 - 8s - loss: 6.3006e-06 - mean_squared_error: 6.3006e-06 - val_loss: 2.8275e-06 - val_mean_squared_error: 2.8275e-06 - 8s/epoch - 2ms/step
# Epoch 29/50
# 3983/3983 - 8s - loss: 7.1999e-06 - mean_squared_error: 7.1999e-06 - val_loss: 6.2852e-06 - val_mean_squared_error: 6.2852e-06 - 8s/epoch - 2ms/step
# Epoch 30/50
# 3983/3983 - 8s - loss: 6.6257e-06 - mean_squared_error: 6.6257e-06 - val_loss: 2.4637e-06 - val_mean_squared_error: 2.4637e-06 - 8s/epoch - 2ms/step
# Epoch 31/50
# 3983/3983 - 8s - loss: 6.0717e-06 - mean_squared_error: 6.0717e-06 - val_loss: 2.3547e-06 - val_mean_squared_error: 2.3547e-06 - 8s/epoch - 2ms/step
# Epoch 32/50
# 3983/3983 - 8s - loss: 7.7567e-06 - mean_squared_error: 7.7567e-06 - val_loss: 1.7277e-06 - val_mean_squared_error: 1.7277e-06 - 8s/epoch - 2ms/step
# Epoch 33/50
# 3983/3983 - 9s - loss: 6.0586e-06 - mean_squared_error: 6.0586e-06 - val_loss: 2.4779e-06 - val_mean_squared_error: 2.4779e-06 - 9s/epoch - 2ms/step
# Epoch 34/50
# 3983/3983 - 8s - loss: 5.6783e-06 - mean_squared_error: 5.6783e-06 - val_loss: 4.7475e-06 - val_mean_squared_error: 4.7475e-06 - 8s/epoch - 2ms/step
# Epoch 35/50
# 3983/3983 - 8s - loss: 6.0295e-06 - mean_squared_error: 6.0295e-06 - val_loss: 2.1945e-06 - val_mean_squared_error: 2.1945e-06 - 8s/epoch - 2ms/step
# Epoch 36/50
# 3983/3983 - 8s - loss: 5.8986e-06 - mean_squared_error: 5.8986e-06 - val_loss: 2.6312e-06 - val_mean_squared_error: 2.6312e-06 - 8s/epoch - 2ms/step
# Epoch 37/50
# 3983/3983 - 8s - loss: 6.1260e-06 - mean_squared_error: 6.1260e-06 - val_loss: 1.6860e-06 - val_mean_squared_error: 1.6860e-06 - 8s/epoch - 2ms/step
# Epoch 38/50
# 3983/3983 - 8s - loss: 5.3725e-06 - mean_squared_error: 5.3725e-06 - val_loss: 4.5686e-06 - val_mean_squared_error: 4.5686e-06 - 8s/epoch - 2ms/step
# Epoch 39/50
# 3983/3983 - 10s - loss: 6.5426e-06 - mean_squared_error: 6.5426e-06 - val_loss: 1.7394e-06 - val_mean_squared_error: 1.7394e-06 - 10s/epoch - 2ms/step
# Epoch 40/50
# 3983/3983 - 8s - loss: 6.1922e-06 - mean_squared_error: 6.1922e-06 - val_loss: 3.8871e-06 - val_mean_squared_error: 3.8871e-06 - 8s/epoch - 2ms/step
# Epoch 41/50
# 3983/3983 - 8s - loss: 7.4731e-06 - mean_squared_error: 7.4731e-06 - val_loss: 1.6897e-06 - val_mean_squared_error: 1.6897e-06 - 8s/epoch - 2ms/step
# Epoch 42/50
# 3983/3983 - 8s - loss: 4.6190e-06 - mean_squared_error: 4.6190e-06 - val_loss: 1.6595e-05 - val_mean_squared_error: 1.6595e-05 - 8s/epoch - 2ms/step
# Epoch 43/50
# 3983/3983 - 8s - loss: 5.6115e-06 - mean_squared_error: 5.6115e-06 - val_loss: 6.0594e-06 - val_mean_squared_error: 6.0594e-06 - 8s/epoch - 2ms/step
# Epoch 44/50
# 3983/3983 - 9s - loss: 6.7415e-06 - mean_squared_error: 6.7415e-06 - val_loss: 2.1516e-06 - val_mean_squared_error: 2.1516e-06 - 9s/epoch - 2ms/step
# Epoch 45/50
# 3983/3983 - 9s - loss: 5.9478e-06 - mean_squared_error: 5.9478e-06 - val_loss: 3.8174e-06 - val_mean_squared_error: 3.8174e-06 - 9s/epoch - 2ms/step
# Epoch 46/50
# 3983/3983 - 8s - loss: 5.2191e-06 - mean_squared_error: 5.2191e-06 - val_loss: 6.3052e-06 - val_mean_squared_error: 6.3052e-06 - 8s/epoch - 2ms/step
# Epoch 47/50
# 3983/3983 - 9s - loss: 5.3197e-06 - mean_squared_error: 5.3197e-06 - val_loss: 6.1434e-06 - val_mean_squared_error: 6.1434e-06 - 9s/epoch - 2ms/step
# Epoch 48/50
# 3983/3983 - 8s - loss: 5.0412e-06 - mean_squared_error: 5.0412e-06 - val_loss: 2.3404e-06 - val_mean_squared_error: 2.3404e-06 - 8s/epoch - 2ms/step
# Epoch 49/50
# 3983/3983 - 8s - loss: 4.8057e-06 - mean_squared_error: 4.8057e-06 - val_loss: 2.3072e-06 - val_mean_squared_error: 2.3072e-06 - 8s/epoch - 2ms/step
# Epoch 50/50
# 3983/3983 - 8s - loss: 5.4233e-06 - mean_squared_error: 5.4233e-06 - val_loss: 4.5226e-06 - val_mean_squared_error: 4.5226e-06 - 8s/epoch - 2ms/step

# %% [markdown]
# Find best epoch:

# %%
val_mse_per_epoch = history.history['val_mean_squared_error']
best_epoch = val_mse_per_epoch.index(min(val_mse_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 37

# %% [markdown]
# Re-instantiate the hypermodel and train it with the optimal number of epochs from above.

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
history = hypermodel.fit(trainX, trainY, epochs=best_epoch, batch_size=1, validation_data = (validX, validY)).history
# Out:
# Epoch 1/37
# 3983/3983 [==============================] - 10s 2ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 2.0462e-04 - val_mean_squared_error: 2.0462e-04
# Epoch 2/37
# 3983/3983 [==============================] - 9s 2ms/step - loss: 1.0006e-04 - mean_squared_error: 1.0006e-04 - val_loss: 5.6967e-05 - val_mean_squared_error: 5.6967e-05
# Epoch 3/37
# 3983/3983 [==============================] - 9s 2ms/step - loss: 3.6519e-05 - mean_squared_error: 3.6519e-05 - val_loss: 5.0710e-05 - val_mean_squared_error: 5.0710e-05
# Epoch 4/37
# 3983/3983 [==============================] - 9s 2ms/step - loss: 2.2061e-05 - mean_squared_error: 2.2061e-05 - val_loss: 2.2216e-05 - val_mean_squared_error: 2.2216e-05
# Epoch 5/37
# 3983/3983 [==============================] - 8s 2ms/step - loss: 1.6170e-05 - mean_squared_error: 1.6170e-05 - val_loss: 1.0110e-05 - val_mean_squared_error: 1.0110e-05
# Epoch 6/37
# 3983/3983 [==============================] - 8s 2ms/step - loss: 1.2248e-05 - mean_squared_error: 1.2248e-05 - val_loss: 1.9574e-05 - val_mean_squared_error: 1.9574e-05
# Epoch 7/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 1.1909e-05 - mean_squared_error: 1.1909e-05 - val_loss: 7.3604e-06 - val_mean_squared_error: 7.3604e-06
# Epoch 8/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 1.0174e-05 - mean_squared_error: 1.0174e-05 - val_loss: 5.6844e-06 - val_mean_squared_error: 5.6844e-06
# Epoch 9/37
# 3983/3983 [==============================] - 8s 2ms/step - loss: 9.2615e-06 - mean_squared_error: 9.2615e-06 - val_loss: 1.1597e-05 - val_mean_squared_error: 1.1597e-05
# Epoch 10/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 1.0087e-05 - mean_squared_error: 1.0087e-05 - val_loss: 6.9697e-06 - val_mean_squared_error: 6.9697e-06
# Epoch 11/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 8.3701e-06 - mean_squared_error: 8.3701e-06 - val_loss: 2.8919e-06 - val_mean_squared_error: 2.8919e-06
# Epoch 12/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 7.5032e-06 - mean_squared_error: 7.5032e-06 - val_loss: 5.5222e-06 - val_mean_squared_error: 5.5222e-06
# Epoch 13/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 7.9805e-06 - mean_squared_error: 7.9805e-06 - val_loss: 5.8940e-06 - val_mean_squared_error: 5.8940e-06
# Epoch 14/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 8.1021e-06 - mean_squared_error: 8.1021e-06 - val_loss: 2.3824e-06 - val_mean_squared_error: 2.3824e-06
# Epoch 15/37
# 3983/3983 [==============================] - 8s 2ms/step - loss: 7.6929e-06 - mean_squared_error: 7.6929e-06 - val_loss: 7.9493e-06 - val_mean_squared_error: 7.9493e-06
# Epoch 16/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 8.9393e-06 - mean_squared_error: 8.9393e-06 - val_loss: 2.5626e-06 - val_mean_squared_error: 2.5626e-06
# Epoch 17/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 7.4192e-06 - mean_squared_error: 7.4192e-06 - val_loss: 4.6064e-06 - val_mean_squared_error: 4.6064e-06
# Epoch 18/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 7.3703e-06 - mean_squared_error: 7.3703e-06 - val_loss: 5.5145e-06 - val_mean_squared_error: 5.5145e-06
# Epoch 19/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 6.7957e-06 - mean_squared_error: 6.7957e-06 - val_loss: 6.0233e-06 - val_mean_squared_error: 6.0233e-06
# Epoch 20/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 7.0243e-06 - mean_squared_error: 7.0243e-06 - val_loss: 5.8779e-06 - val_mean_squared_error: 5.8779e-06
# Epoch 21/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 5.9849e-06 - mean_squared_error: 5.9849e-06 - val_loss: 4.9691e-05 - val_mean_squared_error: 4.9691e-05
# Epoch 22/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 6.4288e-06 - mean_squared_error: 6.4288e-06 - val_loss: 3.0153e-06 - val_mean_squared_error: 3.0153e-06
# Epoch 23/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 6.0666e-06 - mean_squared_error: 6.0666e-06 - val_loss: 1.3730e-05 - val_mean_squared_error: 1.3730e-05
# Epoch 24/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 5.9787e-06 - mean_squared_error: 5.9787e-06 - val_loss: 3.5130e-06 - val_mean_squared_error: 3.5130e-06
# Epoch 25/37
# 3983/3983 [==============================] - 8s 2ms/step - loss: 5.5935e-06 - mean_squared_error: 5.5935e-06 - val_loss: 9.7725e-06 - val_mean_squared_error: 9.7725e-06
# Epoch 26/37
# 3983/3983 [==============================] - 7s 2ms/step - loss: 6.2936e-06 - mean_squared_error: 6.2936e-06 - val_loss: 1.8115e-05 - val_mean_squared_error: 1.8115e-05
# Epoch 27/37
# 3983/3983 [==============================] - 6s 2ms/step - loss: 5.3789e-06 - mean_squared_error: 5.3789e-06 - val_loss: 2.4734e-06 - val_mean_squared_error: 2.4734e-06
# Epoch 28/37
# 3983/3983 [==============================] - 5s 1ms/step - loss: 5.6825e-06 - mean_squared_error: 5.6825e-06 - val_loss: 4.7951e-06 - val_mean_squared_error: 4.7951e-06
# Epoch 29/37
# 3983/3983 [==============================] - 5s 1ms/step - loss: 5.7081e-06 - mean_squared_error: 5.7081e-06 - val_loss: 3.2582e-06 - val_mean_squared_error: 3.2582e-06
# Epoch 30/37
# 3983/3983 [==============================] - 5s 1ms/step - loss: 5.3657e-06 - mean_squared_error: 5.3657e-06 - val_loss: 2.0883e-06 - val_mean_squared_error: 2.0883e-06
# Epoch 31/37
# 3983/3983 [==============================] - 4s 1ms/step - loss: 6.5277e-06 - mean_squared_error: 6.5277e-06 - val_loss: 1.9572e-06 - val_mean_squared_error: 1.9572e-06
# Epoch 32/37
# 3983/3983 [==============================] - 4s 1ms/step - loss: 5.6808e-06 - mean_squared_error: 5.6808e-06 - val_loss: 2.4379e-06 - val_mean_squared_error: 2.4379e-06
# Epoch 33/37
# 3983/3983 [==============================] - 5s 1ms/step - loss: 5.0563e-06 - mean_squared_error: 5.0563e-06 - val_loss: 2.6661e-06 - val_mean_squared_error: 2.6661e-06
# Epoch 34/37
# 3983/3983 [==============================] - 5s 1ms/step - loss: 5.2577e-06 - mean_squared_error: 5.2577e-06 - val_loss: 1.2792e-06 - val_mean_squared_error: 1.2792e-06
# Epoch 35/37
# 3983/3983 [==============================] - 4s 1ms/step - loss: 5.0705e-06 - mean_squared_error: 5.0705e-06 - val_loss: 1.4896e-05 - val_mean_squared_error: 1.4896e-05
# Epoch 36/37
# 3983/3983 [==============================] - 4s 1ms/step - loss: 5.2059e-06 - mean_squared_error: 5.2059e-06 - val_loss: 3.5897e-06 - val_mean_squared_error: 3.5897e-06
# Epoch 37/37
# 3983/3983 [==============================] - 4s 1ms/step - loss: 5.2495e-06 - mean_squared_error: 5.2495e-06 - val_loss: 4.0551e-06 - val_mean_squared_error: 4.0551e-06

# %% [markdown]
# ### Make plots of the loss and validation loss

# %%
plt.figure(figsize = (15,5))

plt.subplot(121)
plt.plot(history['loss'])
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.yscale('log')

plt.subplot(122)
plt.plot(history['val_loss'])
plt.title('Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.yscale('log')
plt.tight_layout()

plt.savefig("plots/tdnn_loss.pdf")
plt.show()

# %% [markdown]
# Save history data

# %%
hist_df = pd.DataFrame(history) 
# save to json:  
hist_json_file = f'history_RNN.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# %% [markdown]
# To load history data use:

# %%
#history = pd.read_json('history_RNN.json')

# %% [markdown]
# Save the model

# %%
hypermodel.save('keras_model_tdnn')
# Out:
# 2023-05-12 11:55:34.985270: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_2_input}}]]
# 2023-05-12 11:55:35.022546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_2_input}}]]
# 2023-05-12 11:55:35.037112: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-12 11:55:35.049187: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_2_input}}]]
# 2023-05-12 11:55:35.059238: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-12 11:55:35.070123: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_2_input}}]]
# 2023-05-12 11:55:35.079825: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-12 11:55:35.087830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,110]
# 	 [[{{node inputs}}]]
# 2023-05-12 11:55:35.101830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-12 11:55:35.113544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-12 11:55:35.168895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'dense_2_input' with dtype float and shape [?,1,17]
# 	 [[{{node dense_2_input}}]]
# 2023-05-12 11:55:35.182744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-12 11:55:35.191103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-12 11:55:35.289455: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,17]
# 	 [[{{node inputs}}]]
# 2023-05-12 11:55:35.322036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,110]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# 2023-05-12 11:55:35.391487: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'serving_default_dense_2_input' with dtype float and shape [?,1,17]
# 	 [[{{node serving_default_dense_2_input}}]]
# INFO:tensorflow:Assets written to: keras_model_tdnn/assets
# INFO:tensorflow:Assets written to: keras_model_tdnn/assets

# %% [markdown]
# Command to (eventually) load the saved model:

# %%
#hypermodel = keras.models.load_model('keras_model_tdnn')

# %% [markdown]
# ### Plots of target and output signals over time

# %%
#training
y = hypermodel.predict(trainX)
mse = hypermodel.evaluate(trainX, trainY, batch_size=1)[0]
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'training - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,trainY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.xlabel('timesteps')

plt.subplot(212)
plt.title('training (first 200 timesteps)')
plt.plot(t[:200],y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t[:200],trainY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.xlabel('timesteps')
plt.savefig("plots/tdnn_training.pdf")

#validation
y = hypermodel.predict(validX)
mse = hypermodel.evaluate(validX, validY, batch_size=1)[0]
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'validation - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,validY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('validation (first 200 timesteps)')
plt.plot(t[:200],y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t[:200],validY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig("plots/tdnn_validation.pdf")

#test
y = hypermodel.predict(testX)
mse = hypermodel.evaluate(testX, testY, batch_size=1)[0]
t=np.arange(start=0,stop=len(y), step=1)
plt.figure(figsize = (25,10))
plt.subplot(211)
plt.title(f'test - MSE = {mse:e}')
plt.plot(t,y.ravel(), color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t,testY.ravel(), color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')

plt.subplot(212)
plt.title('test (first 200 timesteps)')
plt.plot(t[:200],y.ravel()[:200], color = 'b', linewidth= 0.4, label = 'output')
plt.plot(t[:200],testY.ravel()[:200], color = 'r', linewidth= 0.4, linestyle = '--', label = 'target')
plt.savefig("plots/tdnn_test.pdf")
# Out:
# 125/125 [==============================] - 0s 1ms/step
# 3983/3983 [==============================] - 6s 1ms/step - loss: 4.1689e-06 - mean_squared_error: 4.1689e-06
# 31/31 [==============================] - 0s 1ms/step
# 983/983 [==============================] - 1s 1ms/step - loss: 4.0551e-06 - mean_squared_error: 4.0551e-06
# 156/156 [==============================] - 0s 2ms/step
# 4982/4982 [==============================] - 7s 1ms/step - loss: 4.1260e-06 - mean_squared_error: 4.1260e-06
